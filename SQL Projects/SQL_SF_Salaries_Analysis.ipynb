# %% [markdown]
# # Analysis of salaries of SF city (of year 2011 and 2012) using SQL

# %% [markdown]
# ### Problem Statements
# #### 1. Unique Job titles
# #### 2. Job titles with overtime pay greater than 50,000
# #### 3. Average base pay for all employees
# #### 4. Top 10 highest paid employees
# #### 5. All employees with BasePay < 50,000 and TotalPay > 100,000
# #### 6. Total Pay Benefits of Job Title "Director"
# #### 7. Total Pay Benefits of All
# #### 8. Job Titles with average Base Pay of at least 100,000

# %%
# %load_ext sql

# %%
# %sql mysql://root:root@localhost/salaries

# %%
# %%sql
# show tables
# Out:
#  * mysql://root:***@localhost/salaries
# 1 rows affected.
# [('salaries_data',)]

# %%
# %%sql
#
# Select *
# From salaries_data
# Limit 10
# Out:
#  * mysql://root:***@localhost/salaries
# 10 rows affected.
# [(1, 'NATHANIEL FORD', 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', 167411.18, 0.0, 400184.25, '', 567595.43, 567595.43, 2011, '', 'San Francisco', ''),
#  (2, 'GARY JIMENEZ', 'CAPTAIN III (POLICE DEPARTMENT)', 155966.02, 245131.88, 137811.38, '', 538909.28, 538909.28, 2011, '', 'San Francisco', ''),
#  (3, 'ALBERT PARDINI', 'CAPTAIN III (POLICE DEPARTMENT)', 212739.13, 106088.18, 16452.6, '', 335279.91, 335279.91, 2011, '', 'San Francisco', ''),
#  (4, 'CHRISTOPHER CHONG', 'WIRE ROPE CABLE MAINTENANCE MECHANIC', 77916.0, 56120.71, 198306.9, '', 332343.61, 332343.61, 2011, '', 'San Francisco', ''),
#  (5, 'PATRICK GARDNER', 'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)', 134401.6, 9737.0, 182234.59, '', 326373.19, 326373.19, 2011, '', 'San Francisco', ''),
#  (6, 'DAVID SULLIVAN', 'ASSISTANT DEPUTY CHIEF II', 118602.0, 8601.0, 189082.74, '', 316285.74, 316285.74, 2011, '', 'San Francisco', ''),
#  (7, 'ALSON LEE', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 92492.01, 89062.9, 134426.14, '', 315981.05, 315981.05, 2011, '', 'San Francisco', ''),
#  (8, 'DAVID KUSHNER', 'DEPUTY DIRECTOR OF INVESTMENTS', 256576.96, 0.0, 51322.5, '', 307899.46, 307899.46, 2011, '', 'San Francisco', ''),
#  (9, 'MICHAEL MORRIS', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 176932.64, 86362.68, 40132.23, '', 303427.55, 303427.55, 2011, '', 'San Francisco', ''),
#  (10, 'JOANNE HAYES-WHITE', 'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)', 285262.0, 0.0, 17115.73, '', 302377.73, 302377.73, 2011, '', 'San Francisco', '')]

# %% [markdown]
# #### 1. Displaying unique job titles in the table:

# %%
# %%sql
#
# Select distinct JobTitle
# From salaries_data
# Out:
#  * mysql://root:***@localhost/salaries
# 1500 rows affected.
# [('GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',),
#  ('CAPTAIN III (POLICE DEPARTMENT)',),
#  ('WIRE ROPE CABLE MAINTENANCE MECHANIC',),
#  ('DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)',),
#  ('ASSISTANT DEPUTY CHIEF II',),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)',),
#  ('DEPUTY DIRECTOR OF INVESTMENTS',),
#  ('CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',),
#  ('ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',),
#  ('EXECUTIVE CONTRACT EMPLOYEE',),
#  ('DEPARTMENT HEAD V',),
#  ('COMMANDER III, (POLICE DEPARTMENT)',),
#  ('CAPTAIN, EMERGENCYCY MEDICAL SERVICES',),
#  ('ASSISTANT MEDICAL EXAMINER',),
#  ('CAPTAIN, FIRE SUPPRESSION',),
#  ('CHIEF OF POLICE',),
#  ('DEPUTY CHIEF III (POLICE DEPARTMENT)',),
#  ('INSPECTOR III, (POLICE DEPARTMENT)',),
#  ('ELECTRONIC MAINTENANCE TECHNICIAN',),
#  ('ADMINISTRATOR, SFGH MEDICAL CENTER',),
#  ('LIEUTENANT III (POLICE DEPARTMENT)',),
#  ('FIREFIGHTER',),
#  ('NURSING SUPERVISOR PSYCHIATRIC',),
#  ('MAYOR',),
#  ('LIEUTENANT, FIRE DEPARTMENT',),
#  ('INCIDENT SUPPORT SPECIALIST',),
#  ('ANESTHETIST',),
#  ('DISTRICT ATTORNEY',),
#  ('ELECTRICAL TRANSIT MECHANIC, ASSISTANT SUPERVISOR',),
#  ('PORT DIRECTOR',),
#  ('LIEUTENANT, BUREAU OF FIRE PREVENTION AND PUBLIC S',),
#  ('SENIOR PHYSICIAN SPECIALIST',),
#  ('FIRE FIGHTER PARAMEDIC',),
#  ('MANAGER VII',),
#  ('TRANSIT SUPERVISOR',),
#  ('INSPECTOR, BUREAU OF FIRE PREVENTION AND PUBLIC SA',),
#  ('MANAGER VIII',),
#  ('DEPUTY DIRECTOR II - MUNICIPAL TRANSPORTATION AG',),
#  ('NURSING SUPERVISOR',),
#  ('POLICE OFFICER III',),
#  ("SHERIFF'S LIEUTENANT",),
#  ('DEPUTY DIRECTOR V',),
#  ('SUPERVISING PHYSICIAN SPECIALIST',),
#  ('DEPARTMENT HEAD IV',),
#  ('FORENSIC TOXICOLOGIST',),
#  ('CONFIDENTIAL CHIEF ATTORNEY II (CIVIL & CRIMINAL)',),
#  ('SERGEANT III (POLICE DEPARTMENT)',),
#  ('DEPUTY SHERIFF',),
#  ('NURSE MANAGER',),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC',),
#  ('CITY ATTORNEY',),
#  ('MARINE ENGINEER OF FIRE BOATS',),
#  ('CHIEF ATTORNEY I (CIVIL & CRIMINAL)',),
#  ('CAPTAIN, BUREAU OF FIRE PREVENTION AND PUBLIC SAFE',),
#  ('ELECTRICAL TRANSIT SHOP SUPERVISOR I',),
#  ('POLICE OFFICER I',),
#  ('POLICE OFFICER II',),
#  ('SERGEANT I (POLICE DEPARTMENT)',),
#  ('SPECIAL ASSISTANT XXII',),
#  ('DEPUTY DIRECTOR IV',),
#  ('WIRE ROPE CABLE MAINTENANCE SUPERVISOR',),
#  ('PUBLIC DEFENDER',),
#  ('SHERIFF',),
#  ('HUMAN RESOURCES DIRECTOR',),
#  ('INVESTIGATOR, BUREAU OF FIRE INVESTIGATION',),
#  ('ASSISTANT CHIEF ATTORNEY II',),
#  ('DEPUTY DIRECTOR III',),
#  ('PHARMACIST',),
#  ('TRANSIT OPERATIONS SPECIALIST',),
#  ('DEPARTMENT HEAD III',),
#  ('CHIEF PROBATION OFFICER, JUVENILE COURT',),
#  ("SHERIFF'S SERGEANT",),
#  ('ASSISTANT INSPECTOR (POLICE DEPARTMENT)',),
#  ('DIAGNOSTIC IMAGING TECH II',),
#  ('DIAGNOSTIC IMAGING TECH III',),
#  ('CHIEF ADULT PROBATION OFFICER',),
#  ('MANAGER VI',),
#  ('FIRE SAFETY INSPECTOR II',),
#  ('MAINTENANCE MACHINIST',),
#  ('ASSISTANT INSPECTOR III (POLICE DEPARTMENT)',),
#  ('DEPUTY DIRECTOR I - MUNICIPAL TRANSPORTATION AGE',),
#  ('DIRECTOR, EMPLOYEE RELATIONS DIVISION',),
#  ('ASSISTANT CHIEF ATTORNEY I',),
#  ('TRAIN CONTROLLER',),
#  ('PHYSICIAN ASSISTANT',),
#  ('PHYSICIAN SPECIALIST',),
#  ('AUTOMOTIVE MECHANIC SUPERVISOR I',),
#  ('ATTORNEY (CIVIL/CRIMINAL)',),
#  ('SERGEANT II (POLICE DEPARTMENT)',),
#  ('ELECTRICIAN',),
#  ('NURSE PRACTITIONER',),
#  ('MECHANICAL SHOP AND EQUIPMENT SUPERINTENDENT',),
#  ('HEAD ATTORNEY, CIVIL AND CRIMINAL',),
#  ('PRINCIPAL CIVIL ENGINEER',),
#  ('ASSOCIATE ENGINEER',),
#  ('PROJECT MANAGER IV',),
#  ('PILOT OF FIRE BOATS',),
#  ('DEPARTMENT HEAD I',),
#  ('SENIOR ENGINEER',),
#  ('COURT EXECUTIVE OFFICER',),
#  ('ENGINEER',),
#  ('ASSISTANT SHERIFF',),
#  ('BUILDINGS AND GROUNDS MAINTENANCE SUPERINTENDENT',),
#  ('ELECTRONIC MAINTENANCE TECHNICIAN ASSISTANT SUPERV',),
#  ('CLINICAL PHARMACIST',),
#  ('DEPARTMENT HEAD II',),
#  ('CLINICAL NURSE SPECIALIST',),
#  ('NURSE MIDWIFE',),
#  ('ELECTRICAL TRANSIT MECHANIC SUPERVISOR I',),
#  ('MANAGER V',),
#  ('ATTORNEY FOR THE PUBLIC ADMINISTRATOR',),
#  ('CHIEF DEPUTY SHERIFF',),
#  ('SENIOR DEPUTY SHERIFF',),
#  ('PROJECT MANAGER III',),
#  ('TRACK MAINTENANCE WORKER SUPERVISOR I',),
#  ('MAYORAL STAFF XVII',),
#  ('MANAGER VII - MUNICIPAL TRANSPORTATION AGENCY',),
#  ('HEATING AND VENTILATING INSPECTOR',),
#  ('ASST. CHIEF PROBATION OFFICER-JUVENILE PROBATION',),
#  ('DIRECTOR, INFORMATION TECHNOLOGY GROUP',),
#  ('UTILITY PLUMBER SUPERVISOR II',),
#  ('COMMUNICATIONS LINE WORKER SUPERVISOR II',),
#  ('ASSISTANT INSPECTOR II (POLICE DEPARTMENT)',),
#  ('ASSESSOR',),
#  ('MANAGER VIII - MUNICIPAL TRANSPORTATION AGENCY',),
#  ('MANAGER IV',),
#  ('INSPECTOR, (POLICE DEPARTMENT)',),
#  ('IS ENGINEER - PRINCIPAL',),
#  ('REGISTERED NURSE',),
#  ('SPECIAL NURSE',),
#  ('INFORMATION SERVICES MANAGER',),
#  ('TRANSMISSION LINE SUPERVISOR I',),
#  ('SUPERVISING PHARMACIST',),
#  ('SEWAGE TREATMENT PLANT SUPERINTENDENT',),
#  ('TREASURER',),
#  ('SENIOR POWER GENERATION TECHNICIAN',),
#  ('DEPUTY DIRECTOR II',),
#  ("CHIEF DISTRICT ATTORNEY'S INVESTIGATOR",),
#  ('LANDSCAPE ARCHITECTURAL ASSOCIATE II',),
#  ('ARCHITECTURAL ASSOCIATE  I',),
#  ('LANDSCAPE ARCHITECT',),
#  ('ARCHITECT',),
#  ('STATIONARY ENGINEER',),
#  ('PLUMBING INSPECTOR',),
#  ('AUTOMOTIVE MECHANIC',),
#  ('CHIEF STATIONARY ENGINEER',),
#  ('SENIOR COURT STAFF ATTORNEY',),
#  ('HEAD PARK PATROL OFFICER',),
#  ('UNDERSHERIFF',),
#  ('ASSISTANT ELECTRONIC MAINTENANCE TECHNICIAN',),
#  ("SHERIFF'S CAPTAIN",),
#  ('MANAGER III',),
#  ('BOARD SECRETARY - MUNICIPAL TRANSPORTATION AGENC',),
#  ('WATER CONSTRUCTION AND MAINTENANCE SUPERINTENDENT',),
#  ('LIEUTENANT I, (POLICE DEPARTMENT)',),
#  ('LIEUTENANT II (POLICE DEPARTMENT)',),
#  ('DIAGNOSTIC IMAGING TECH I',),
#  ('MANAGER II - MUNICIPAL TRANSPORTATION AGENCY',),
#  ('MANAGER VI - MUNICIPAL TRANSPORTATION AGENCY',),
#  ('ATTORNEY, TAX COLLECTOR',),
#  ('COURT COMMISSIONER',),
#  ('PRINCIPAL ADMINISTRATIVE ANALYST',),
#  ('SENIOR RADIO TECHNICIAN',),
#  ('ADMINISTRATIVE ENGINEER',),
#  ('BUILDING INSPECTOR',),
#  ('CHIEF WATER SERVICE INSPECTOR',),
#  ('POWER GENERATION SUPERVISOR',),
#  ('TRANSIT OPERATOR',),
#  ('UTILITY PLUMBER SUPERVISOR I',),
#  ('RADIOLOGIC TECHNOLOGIST SUPERVISOR',),
#  ('DENTIST',),
#  ('BUILDING PLANS ENGINEER',),
#  ('INSPECTOR II, (POLICE DEPARTMENT)',),
#  ('TELECOMMUNICATIONS TECHNICIAN SUPERVISOR',),
#  ('SUPERVISING ELECTRONIC MAINTENANCE TECHNICIAN',),
#  ('INSTITUTIONAL POLICE SERGEANT',),
#  ('TRANSIT POWER LINE SUPERVISOR I',),
#  ('SENIOR COUNSELOR, JUVENILE HALL',),
#  ('COURT ADMINISTRATOR',),
#  ('PLUMBER SUPERVISOR I',),
#  ('COURT COMPUTER SYSTEMS MANAGER',),
#  ('SENIOR CONSTRUCTION INSPECTOR',),
#  ('CRIMINALIST III',),
#  ('TRANSIT POWER LINE WORKER',),
#  ('SEWER REPAIR SUPERVISOR',),
#  ('SENIOR LIGHT RAIL VEHICLE EQUIPMENT ENGINEER',),
#  ('TRANSMISSION AND DISTRIBUTION LINE WORKER',),
#  ('MANAGER II',),
#  ('ARCHITECTURAL ASSOCIATE II',),
#  ('AUTOMOTIVE TRANSIT SHOP SUPERVISOR I',),
#  ('MANAGER V - MUNICIPAL TRANSPORTATION AGENCY',),
#  ('IS PROJECT DIRECTOR',),
#  ('TRANSIT CAR CLEANER',),
#  ('CHIEF STATIONARY ENGINEER, WATER TREATMENT PLANT',),
#  ('PLUMBER',),
#  ('DISABILITY ACCESS COORDINATOR',),
#  ('AUTOMOTIVE MECHANIC ASSISTANT SUPERVISOR',),
#  ('AUTOMOTIVE MACHINIST ASSISTANT SUPERVISOR',),
#  ('LAW LIBRARIAN',),
#  ('PROJECT MANAGER II',),
#  ('SENIOR STATIONARY ENGINEER',),
#  ('TRANSIT POWER LINE WORKER SUPERVISOR II',),
#  ('ASST. CHIEF, BUREAU OF CLAIMS INVEST. & ADMIN',),
#  ('IS BUSINESS ANALYST - PRINCIPAL',),
#  ('POWER GENERATION TECHNICIAN II',),
#  ('CABLE SPLICER',),
#  ('CONSTRUCTION INSPECTOR',),
#  ('IS ENGINEER - SENIOR',),
#  ('PLANNER V',),
#  ('CRIME LABORATORY MANAGER',),
#  ('SHEET METAL WORKER SUPERVISOR II',),
#  ('COMMUNICATIONS SYSTEMS TECHNICIAN',),
#  ('IS ENGINEER - JOURNEY',),
#  ('SUPERINTENDENT OF WATER TREATMENT FACILITIES',),
#  ('STATION AGENT, MUNICIPAL RAILWAY',),
#  ('STRUCTURAL ENGINEER',),
#  ('PUBLIC HEALTH NURSE',),
#  ('COURT STAFF ATTORNEY II',),
#  ('HEAD AIRPORT ELECTRICIAN',),
#  ('ASSISTANT DIRECTOR OF CLINICAL SERVICES II',),
#  ('FIRE PROTECTION ENGINEER',),
#  ('SPECIAL ASSISTANT XVI',),
#  ('ASSISTANT DEPUTY DIRECTOR, PORT',),
#  ('FIRE RESCUE PARAMEDIC',),
#  ('DIRECTOR, FISCAL SERVICES',),
#  ("DISTRICT ATTORNEY'S INVESTIGATOR",),
#  ('TRANSIT PAINT SHOP SUPERVISOR I',),
#  ('ELECTRICIAN SUPERVISOR II',),
#  ("PRINCIPAL DISTRICT ATTORNEY'S INVESTIGATOR",),
#  ('BUILDINGS AND GROUNDS MAINTENANCE SUPERVISOR',),
#  ('SENIOR WATER SERVICE INSPECTOR',),
#  ('IS BUSINESS ANALYST - SENIOR',),
#  ('MAINTENANCE CONTROLLER',),
#  ('ELECTRICIAN SUPERVISOR I',),
#  ('MANAGER, EMPLOYEE RELATIONS DIV',),
#  ('TRAFFIC HEARING OFFICER',),
#  ('ASSISTANT ENGINEER',),
#  ('LANDSCAPE ARCHITECTURAL ASSOCIATE I',),
#  ('CHIEF BUILDING INSPECTOR',),
#  ('MAINTENANCE MACHINIST SUPERVISOR I',),
#  ('MANAGER IV - MUNICIPAL TRANSPORTATION AGENCY',),
#  ('UTILITY PLUMBER',),
#  ('SENIOR ELECTRICAL INSPECTOR',),
#  ('ELECTRICAL INSPECTOR',),
#  ('SENIOR STATIONARY ENGINEER, WATER TREATMENT PLANT',),
#  ('COMMUNICATION LINE SUPERVISOR I',),
#  ('ELECTRICAL LINE WORKER',),
#  ('MAYORAL STAFF XVI',),
#  ('AIRPORT MECHANICAL MAINTENANCE SUPERVISOR',),
#  ('COURT REPORTER COORDINATOR',),
#  ('CHIEF PLUMBING INSPECTOR',),
#  ('OPERATING ROOM NURSE',),
#  ('WELDER',),
#  ('MENTAL HEALTH TREATMENT SPECIALIST',),
#  ('TRANSPORTATION SAFETY SPECIALIST',),
#  ('SENIOR POLICE COMMUNICATIONS DISPATCHER',),
#  ('UTILITY SPECIALIST',),
#  ('CEMENT FINISHER SUPERVISOR II',),
#  ('ASSISTANT COURT REPORTER COORDINATOR',),
#  ('PRINCIPAL REAL PROPERTY OFFICER',),
#  ('RESEARCH PSYCHOLOGIST',),
#  ('LOCKSMITH SUPERVISOR I',),
#  ('SUPERVISING CHEMIST',),
#  ('SENIOR PLUMBING INSPECTOR',),
#  ('OPERATING ENGINEER, UNIVERSAL',),
#  ('LABORATORY SERVICES MANAGER',),
#  ('MANAGER I',),
#  ('MANAGER, UNIFIED FAMILY COURT SERVICES',),
#  ('DIRECTOR, HUMAN RESOURCES',),
#  ('SENIOR BUILDING INSPECTOR',),
#  ('TRANSIT MANAGER II',),
#  ('PLANNER IV',),
#  ('EMERGENCY MEDICAL SERVICES AGENCY SPECIALIST',),
#  ('PUBLIC SAFETY COMMUNICATIONS DISPATCHER',),
#  ('WATER OPERATIONS ANALYST',),
#  ('CHIEF ELECTRICAL INSPECTOR',),
#  ('TRAFFIC SIGNAL ELECTRICIAN',),
#  ('AUTOMOTIVE BODY AND FENDER WORKER',),
#  ('APPRENTICE STATIONARY ENGINEER',),
#  ('AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I',),
#  ('AUTOMOTIVE MACHINIST',),
#  ('SUPERVISING PURCHASER',),
#  ('CHIEF STATIONARY ENGINEER, SEWAGE PLANT',),
#  ('COURT COMPUTER FACILITIES COORDINATOR',),
#  ('PLUMBER SUPERVISOR II',),
#  ('MANAGER III - MUNICIPAL TRANSPORTATION AGENCY',),
#  ('CLAIMS INVESTIGATOR',),
#  ('STEAMFITTER',),
#  ('PROTECTIVE SERVICES SUPERVISOR',),
#  ('CARPENTER SUPERVISOR I',),
#  ('MAYORAL STAFF XV',),
#  ('COUNSELOR, LOG CABIN RANCH',),
#  ('CHIEF HOUSING INSPECTOR',),
#  ("MEDICAL EXAMINER'S INVESTIGATOR II",),
#  ('DIRECTOR, JUVENILE HALL',),
#  ('IS PROGRAMMER ANALYST - PRINCIPAL',),
#  ('TRAF SIGNAL ELECTRICIAN SUP II',),
#  ('IS ADMINISTRATOR III',),
#  ("ASSISTANT CHIEF DISTRICT ATTORNEY'S INVESTIGATOR",),
#  ('STEAMFITTER ASSISTANT SUPERVISOR',),
#  ('SENIOR STATIONARY ENGINEER, SEWAGE PLANT',),
#  ('COURT REPORTER',),
#  ('AIRPORT ELECTRICIAN',),
#  ('AIRPORT ELECTRICIAN SUPERVISOR',),
#  ('COURT MANAGER',),
#  ('HEALTH PROGRAM COORDINATOR III',),
#  ('SUPERVISING WASTEWATER CONTROL INSPECTOR',),
#  ('TRAF SIGNAL ELECTRICIAN SUP I',),
#  ('LINE INSPECTOR',),
#  ('PRINCIPAL ADMINISTRATIVE ANAYLST II',),
#  ('WATER SERVICE INSPECTOR',),
#  ('PUBLIC RELATIONS MANAGER',),
#  ('SENIOR ENVIRONMENTAL HEALTH INSPECTOR',),
#  ('CONTRACT COMPLIANCE OFFICER II',),
#  ('SENIOR INDUSTRIAL HYGIENIST DEPT OF PUBLIC HEALTH',),
#  ('SAFETY OFFICER',),
#  ('AUTOMOTIVE MACHINIST SUPERVISOR I',),
#  ('PLANNER IV-ENVIRONMENTAL REVIEW',),
#  ('DIVISION DIRECTOR ADULT PROBATION',),
#  ('PROTECTIVE SERVICES WORKER',),
#  ("MEDICAL EXAMINER'S INVESTIGATOR III",),
#  ('AUTOMOTIVE SERVICE WORKER',),
#  ('DIRECTOR, PROBATE',),
#  ('IS ADMINISTRATOR - SUPERVISOR',),
#  ('SENIOR HOUSING INSPECTOR',),
#  ('SEWER SERVICE WORKER',),
#  ('STREET REPAIR SUPERVISOR II',),
#  ('ELECTRIC MOTOR REPAIRER',),
#  ('COMMUNICATIONS DIRECTOR',),
#  ('COURT COMPUTER APPLICATIONS PROGRAMMER',),
#  ('DIAGNOSTIC IMAGING TECH IV',),
#  ('PROJECT MANAGER I',),
#  ('ASPHALT FINISHER SUPERVISOR I',),
#  ('TRANSIT MANAGER I',),
#  ('CRIMINALIST II',),
#  ('CHIEF MICROBIOLOGIST',),
#  ('CHIEF SURVEYOR',),
#  ('SENIOR ADMINISTRATIVE ANALYST',),
#  ('PSYCHIATRIC TECHNICIAN',),
#  ('SUPERVISING BIOLOGIST',),
#  ('AIRPORT OPERATIONS SUPERVISOR',),
#  ('TRANSIT PLANNER IV',),
#  ('MEDIA/SECURITY SYSTEMS SUPERVISOR',),
#  ("SENIOR DISTRICT ATTORNEY'S INVESTIGATOR",),
#  ('PRINCIPAL PERSONNEL ANALYST',),
#  ('SENIOR PHYSICAL THERAPIST',),
#  ('SENIOR OCCUPATIONAL THERAPIST',),
#  ('SHELTER VETERINARIAN',),
#  ('CHIEF FIRE ALARM DISPATCHER',),
#  ('DEPUTY DIRECTOR I',),
#  ('EXECUTIVE ASSISTANT TO THE GENERAL MANAGER, RETIRE',),
#  ('AIRPORT ECONOMIC PLANNER',),
#  ('SWITCH REPAIRER',),
#  ('POWER HOUSE ELECTRICIAN SUPERVISOR I',),
#  ('SAFETY ANALYST',),
#  ('BIOLOGIST III',),
#  ('PARKING ENFORCEMENT ADMINISTRATOR',),
#  ('PRINCIPAL ENVIRONMENTAL HEALTH INSPECTOR',),
#  ('SENIOR EMPLOYEE RELATIONS REPRESENTATIVE',),
#  ('PAINTER SUPERVISOR I',),
#  ('SENIOR SYSTEMS ACCOUNTANT',),
#  ('COUNSELOR, FAMILY COURT SERVICE',),
#  ('GOVERNMENT AND PUBLIC AFFAIRS MANAGER',),
#  ('ELECTRONIC INSTRUMENTATION TECHNICIAN,WTR PLTNCN',),
#  ('CAR AND AUTO PAINTER',),
#  ('PERFORMANCE ANALYST III - PROJECT MANAGER',),
#  ('UTILITY PLUMBER APPRENTICE',),
#  ('PRINCIPAL MANAGEMENT ANALYST',),
#  ('LOCKSMITH',),
#  ('SENIOR AIRPORT COMMUNICATIONS DISPATCHER',),
#  ('SENIOR PROPERTY MANAGER, PORT',),
#  ('HEAVY EQUIPMENT OPERATIONS SUPERVISOR',),
#  ('MAINTENANCE PLANNER',),
#  ('SENIOR STREET INSPECTOR',),
#  ('SENIOR REAL PROPERTY OFFICER',),
#  ('ASSISTANT DIRECTOR OF CLINICAL SERVICES I',),
#  ('TRUCK DRIVER',),
#  ('DIRECTOR, PROBATION SERVICES',),
#  ('SENIOR CLAIMS INVESTIGATOR',),
#  ('TRACK MAINTENANCE WORKER',),
#  ('WATER AND POWER MAINTENANCE SUPERVISOR I',),
#  ('ASSOCIATE AFFIRMATIVE ACTION COORDINATOR',),
#  ('POLICE COMMUNICATIONS SHIFT SUPERVISOR',),
#  ('STREET ENVIRONMENTAL SERVICES OPERATIONS SUPERVI',),
#  ('ASSISTANT LAW LIBRARIAN',),
#  ('CEMENT FINISHER SUPERVISOR I',),
#  ('SENIOR PLAN CHECKER',),
#  ('STATIONARY ENGINEER, WATER TREATMENT PLANT',),
#  ('MAINTENANCE MANAGER',),
#  ('CLERK',),
#  ('CRANE MECHANIC SUPERVISOR',),
#  ('AIRPORT COMMUNICATIONS OPERATOR',),
#  ('MANAGER I - MUNICIPAL TRANSPORTATION AGENCY',),
#  ('SUPERVISING CLINICAL PSYCHOLOGIST',),
#  ('CHEMIST III',),
#  ('ARCHITECTURAL ADMINISTRATOR',),
#  ('PRINCIPAL REAL PROPERTY APPRAISER',),
#  ('GENERAL LABORER SUPERVISOR I',),
#  ('SUPERVISING PARTS STOREKEEPER',),
#  ('CITY SHOPS ASSISTANT SUPERINTENDENT',),
#  ('INDUSTRIAL HYGIENIST',),
#  ('HOUSING INSPECTOR',),
#  ('MATERIALS COORDINATOR',),
#  ('PRINCIPAL PERSONAL PROPERTY AUDITOR',),
#  ('STATIONARY ENGINEER, SEWAGE PLANT',),
#  ('LICENSED VOCATIONAL NURSE',),
#  ('MARITIME MARKETING REPRESENTATIVE',),
#  ('COURT COMPUTER SYSTEMS ENGINEER II',),
#  ('COURT COMPUTER APPLICATIONS ANALYST',),
#  ('SENIOR HUMAN RESOURCES ANALYST',),
#  ('PRINCIPAL ENVIRONMENTAL SPECIALIST',),
#  ('SUPERVISING ADULT PROBATION OFFICER',),
#  ('SUPERVISING PROBATION OFFICER, JUVENILE COURT',),
#  ('SUPERVISING AUDITOR',),
#  ('CLAIMS ADJUSTER',),
#  ('ELEVATOR AND CRANE TECHNICIAN',),
#  ('COURT SUPERVISOR II',),
#  ('MEMBER, BOARD OF SUPERVISORS',),
#  ('PARTS STOREKEEPER',),
#  ('WATER CONSERVATION ADMINISTRATOR',),
#  ('TRANSIT CAR CLEANER ASSISTANT SUPERVISOR',),
#  ('SHEET METAL SUPERVISOR I',),
#  ('MAYORAL STAFF XIII',),
#  ("SENIOR CLAIMS INVESTIGATOR,CITY ATTORNEY'S OFFICE",),
#  ('SENIOR MAINTENANCE CONTROLLER',),
#  ('GLAZIER',),
#  ('FISCAL SERVICES COORDINATOR',),
#  ('SECRETARY TO THE PRESIDING JUDGE',),
#  ('HEALTH WORKER IV',),
#  ('POWER PLANT SUPERVISOR I',),
#  ('OCCUPATIONAL THERAPIST',),
#  ('SURVEY ASSOCIATE',),
#  ('AUTOMOTIVE SERVICE WORKER ASSISTANT SUPERVISOR',),
#  ('SENIOR COMMUNITY DEVELOPMENT SPECIALIST I',),
#  ('CHIEF VICTIM/WITNESS INVESTIGATOR',),
#  ('MEDIA/SECURITY SYSTEMS SPECIALIST',),
#  ('MAYORAL STAFF XIV',),
#  ('GENERAL LABORER',),
#  ('DEPUTY PROBATION OFFICER',),
#  ('CARPENTER',),
#  ('PARK PATROL OFFICER',),
#  ('EXECUTIVE DIRECTOR, SOUTHEAST COMMUNITY FACILITY',),
#  ('PHYSICAL THERAPIST',),
#  ('SENIOR POWER HOUSE OPERATOR',),
#  ('PARKING CONTROL OFFICER',),
#  ('SENIOR PERSONNEL ANALYST',),
#  ('INSTITUTIONAL POLICE OFFICER',),
#  ('PHARMACY TECHNICIAN',),
#  ('AUDIOLOGIST',),
#  ('ELIGIBILITY WORKER',),
#  ('ASSISTANT SUPERINTENDENT RECREATION',),
#  ('SHEET METAL WORKER',),
#  ('ASPHALT PLANT SUPERVISOR I',),
#  ('SENIOR ACCOUNT CLERK',),
#  ('COURT INVESTIGATOR',),
#  ('STAGE ELECTRICIAN',),
#  ('SECURITY ANALYST',),
#  ('PRINCIPAL PAYROLL AND PERSONNEL CLERK',),
#  ('SENIOR COMMUNITY DEVELOPMENT SPECIALIST II',),
#  ('TRAFFIC SIGN MANAGER',),
#  ('ELECTRIC MOTOR REPAIR SUPERVISOR I',),
#  ('TRANSIT PLANNER III',),
#  ('REGULATORY SPECIALIST',),
#  ('PROBATE EXAMINER',),
#  ('HOSPITAL ELIGIBILITY WORKER SUPERVISOR',),
#  ('COURT ASSISTANT - SENIOR, SUPERIOR COURT',),
#  ('MUNICIPAL STADIUM GROUNDSKEEPER',),
#  ('BRICKLAYER',),
#  ('PLANNER III-ENVIRONMENTAL REVIEW',),
#  ('ASSISTANT FORENSIC TOXICOLOGIST I',),
#  ('FARE INSPECTIONS SUPERVISOR/INVESTIGATOR',),
#  ('EMPLOYMENT AND TRAINING SPECIALIST VI',),
#  ('PIPE WELDER',),
#  ('PARK SECTION SUPERVISOR',),
#  ('ENVIRONMENTAL HEALTH INSPECTOR',),
#  ('PRINCIPAL FARE COLLECTIONS RECEIVER',),
#  ('AIRPORT SAFETY OFFICER',),
#  ('MARRIAGE, FAMILY & CHILD COUNSELOR (MFCC)',),
#  ('COORDINATOR OF CITIZEN INVOLVEMENT',),
#  ('TREE TOPPER SUPERVISOR I',),
#  ('COURT INTERPRETER SUPERVISOR',),
#  ('SURGICAL PROCEDURES TECHNICIAN',),
#  ('PLANNER III',),
#  ('MENTAL HEALTH REHABILITATION WORKER',),
#  ('PATIENT ACCOUNTS SUPERVISOR',),
#  ('STREET INSPECTION SUPERVISOR',),
#  ('COMMUNICATIONS DISPATCHER II',),
#  ('POWER HOUSE OPERATOR',),
#  ('SENIOR MICROBIOLOGIST',),
#  ('IS ENGINEER - ASSISTANT',),
#  ('ELECTRICAL LINE HELPER',),
#  ('ASSISTANT MATERIALS COORDINATOR',),
#  ("WORKER'S COMPENSATION SUPERVISOR I",),
#  ('ASSISTANT TO THE DIRECTOR, PUBLIC AFFAIRS       RS',),
#  ('CLAIMS INVESTIGATOR CITY ATTORNEYS OFFICE',),
#  ('IS TRAINER - SENIOR',),
#  ('SPEECH PATHOLOGIST',),
#  ('NURSING ASSISTANT',),
#  ('COURT TRAINING SPECIALIST',),
#  ('ENGINEERING ASSOCIATE II',),
#  ('CLINICAL PSYCHOLOGIST',),
#  ('IS BUSINESS ANALYST',),
#  ('GARDENER',),
#  ('AIRPORT PROPERTY SPECIALIST I',),
#  ('BOARD/COMMISSION SECRETARY III',),
#  ('BENEFITS SUPERVISOR',),
#  ('LEGISLATIVE ASSISTANT',),
#  ('CEMENT MASON',),
#  ('LIBRARIAN III',),
#  ('REAL PROPERTY OFFICER',),
#  ('ASSISTANT RENTAL MANAGER, PORT',),
#  ('ORNAMENTAL IRON WORKER SUPERVISOR I',),
#  ('FUSION WELDER',),
#  ('SUPERVISING WELFARE FRAUD INVESTIGATOR',),
#  ('TRAINING COORDINATOR',),
#  ('PAINTER',),
#  ('SENIOR PARKING CONTROL OFFICER',),
#  ('SENIOR PURCHASER',),
#  ('PROGRAM SUPPORT ANALYST',),
#  ('FOOD SERVICE MANAGER ADMINISTRATOR',),
#  ('CONTRACT COMPLIANCE OFFICER I',),
#  ('MEDICAL SOCIAL WORK SUPERVISOR',),
#  ('WATERSHED FORESTER MANAGER',),
#  ('HEAVY EQUIPMENT OPERATIONS ASSISTANT SUPERVISOR',),
#  ('ADMINISTRATIVE ANALYST III',),
#  ('MOBILE EQUIPMENT SUPERVISOR',),
#  ('GENERAL UTILITY MECHANIC',),
#  ('ASSOCIATE AUDITOR',),
#  ('COURT SUPERVISOR I',),
#  ('APPRENTICE STATIONARY ENGINEER, SEWAGE PLANT',),
#  ('TRACK MAINTENANCE SUPERINTENDENT,MUNICIPAL RAILWAY',),
#  ('PATTERN MAKER',),
#  ('EXECUTIVE ASSISTANT TO THE ADMINISTRATOR, S.F.G.H.',),
#  ('IS PROGRAMMER ANALYST - SENIOR',),
#  ('ASSISTANT CLERK, BOARD OF SUPERVISORS',),
#  ('SENIOR REAL PROPERTY APPRAISER',),
#  ('EPIDEMIOLOGIST II',),
#  ('ADMINISTRATIVE SERVICES MANAGER',),
#  ('PILEDRIVER SUPERVISOR I',),
#  ('PERSONNEL PAYROLL REPRESENTATIVE',),
#  ('STREET INSPECTOR',),
#  ('WASTEWATER CONTROL INSPECTOR',),
#  ('SENIOR PERSONAL PROPERTY AUDITOR',),
#  ('BIOLOGIST I/II',),
#  ('SENIOR PSYCHIATRIC SOCIAL WORKER',),
#  ('SENIOR HEALTH PROGRAM PLANNER',),
#  ('SENIOR ENVIRONMENT SPECIALIST',),
#  ("SENIOR INVESTIGATOR, OFFICE OF CITIZEN'S COMPLAINT",),
#  ('HEALTH CARE ANALYST',),
#  ('SENIOR PAYROLL AND PERSONNEL CLERK',),
#  ('SECRETARY I',),
#  ('SOFT FLOOR COVERER SUPERVISOR',),
#  ('APPRENTICE STATIONARY ENGINEER,WATER TREATMENT PLN',),
#  ('SECRETARY, COMMISSION ON THE ENVIRONMENT',),
#  ('PSYCHIATRIC SOCIAL WORKER',),
#  ('MAINTENANCE MACHINIST ASSISTANT SUPERVISOR',),
#  ('SENIOR SOCIAL WORKER',),
#  ('COORDINATOR, HUMAN RIGHTS COMMISSION',),
#  ('SENIOR HEALTH EDUCATOR',),
#  ('CURATOR IV',),
#  ('COUNSELOR II',),
#  ('MUSEUM SECURITY SUPERVISOR',),
#  ('SUPERVISOR, TRAFFIC AND STREET SIGNS',),
#  ('SENIOR CLERK',),
#  ('PRINCIPAL ACCOUNTANT',),
#  ('FEASIBILITY ANALYST, PORT',),
#  ('AIRPORT POLICE SERVICES AIDE',),
#  ("MAYOR'S PROGRAM MANAGER",),
#  ('PILEDRIVER ENGINE OPERATOR',),
#  ("SENIOR PUBLIC DEFENDER'S INVESTIGATOR",),
#  ('PILE WORKER',),
#  ('MENTAL HEALTH HEARING OFFICER',),
#  ('ASSISTANT CHIEF VICTIM/WITNESS INVESTIGATOR',),
#  ('CHEMIST I/II',),
#  ('PARKING METER REPAIRER SUPERVISOR I',),
#  ('CONSERVATORSHIP/CASE MGNT SUPV',),
#  ('DEPUTY COURT CLERK III',),
#  ('AIRPORT COMMUNICATIONS SUPERVISOR',),
#  ('PRINCIPAL CLERK',),
#  ('PAINTER SUPERVISOR II',),
#  ('AREA SUPERVISOR, PARKS, SQUARES AND FACILITIES',),
#  ('FORESTER',),
#  ('PUBLIC RELATIONS OFFICER',),
#  ('EXECUTIVE SECRETARY III',),
#  ('CIVIL ENGINEERING ASSOCIATE I',),
#  ('AIRPORT EMERGENCY PLANNING COORDINATOR',),
#  ('MOBILE EQUIPMENT ASSISTANT SUPERVISOR',),
#  ('IS OPERATOR - SUPERVISOR',),
#  ('PERSONNEL ANALYST',),
#  ('CARPENTER SUPERVISOR II',),
#  ('EMPLOYMENT AND TRAINING SPECIALIST V',),
#  ('PARKING HEARING EXAMINER',),
#  ('GLAZIER SUPERVISOR I',),
#  ('SECRETARY, LIBRARY COMMISSION',),
#  ('EXECUTIVE SECRETARY TO THE CONTROLLER',),
#  ('ASSISTANT CONSTRUCTION INSPECTOR',),
#  ('SUPERVISING COURT ADMINISTRATIVE SECRETARY',),
#  ('SENIOR PARTS STOREKEEPER',),
#  ('ELIGIBILITY WORKER SUPERVISOR',),
#  ('MUSEUM GUARD',),
#  ('WELFARE FRAUD INVESTIGATOR',),
#  ('PRINCIPAL PARTS STOREKEEPER',),
#  ('SENIOR MANAGEMENT ASSISTANT',),
#  ('ASSOCIATE PERFORMANCE AUDITOR',),
#  ('MAINTENANCE ESTIMATOR AND SCHEDULER',),
#  ('PATIENT ACCOUNTS MANAGER',),
#  ('MARKET RESEARCH SPECIALISTS, PORT',),
#  ('SPECIAL ASSISTANT XV',),
#  ('SENIOR MARRIAGE, FAMILY & CHILD COUNSELOR (MFCC)',),
#  ('TRAINING OFFICER',),
#  ('NUTRITIONIST',),
#  ('LIBRARIAN II',),
#  ('SENIOR GENERAL UTILITY MECHANIC',),
#  ('WATER QUALITY TECHNICIAN I/II',),
#  ('X-RAY LABORATORY AIDE',),
#  ('EMERGENCY PROTECTIVE ORDERS COMMISSIONER',),
#  ('SENIOR MEDICAL SOCIAL WORKER',),
#  ('HEALTH EDUCATOR',),
#  ('IS ADMINISTRATOR I',),
#  ('CHIEF NURSERY SPECIALIST',),
#  ('POWERHOUSE ELECTRICIAN SUPERVISOR II',),
#  ('PROGRAM SPECIALIST SUPERVISOR',),
#  ('PORTER',),
#  ('IS ADMINISTRATOR II',),
#  ('SENIOR CENTRAL PROCESSING AND DISTRIBUTION TECHNIC',),
#  ('PAYROLL SUPERVISOR',),
#  ('TRIAL DELAY REDUCTION COORDINATOR',),
#  ('BUILDING SERVICES TECHNICIAN',),
#  ('SENIOR FISCAL TECHNICIAN',),
#  ('IS TECHNICIAN - SUPERVISOR',),
#  ('EMPLOYMENT & TRAINING SPECIALIST IV',),
#  ('PUBLIC HEALTH TEAM LEADER',),
#  ('PRINCIPAL INVESTIGATOR, TAX COLLECTOR',),
#  ('MICROBIOLOGIST',),
#  ('CENTRAL PROCESSING AND DISTRIBUTION TECHNICIAN',),
#  ('SIGN WORKER',),
#  ('MEDIA TRAINING SPECIALIST',),
#  ('MEDICAL RECORDS TECHNICIAN SUPERVISOR',),
#  ('CUSTODIAL ASSISTANT SUPERVISOR',),
#  ('SENIOR EMPLOYEE ASSISTANCE COUNSELOR',),
#  ('MEDIA PRODUCTION SUPERVISOR',),
#  ('COMMERCIAL DIVISION ASSISTANT SUPERVISOR',),
#  ('CHILD SUPPORT OFFICER III',),
#  ('CRIMINAL JUSTICE SPECIALIST II',),
#  ('DENTAL HYGIENIST',),
#  ('ROOFER SUPERVISOR I',),
#  ('JUNIOR ENGINEER',),
#  ('COURT AD RESOLUTION COORDINATOR',),
#  ('PATIENT ACCOUNTS ASSISTANT SUPERVISOR',),
#  ('TRAINING TECHNICIAN',),
#  ('TREE TOPPER SUPERVISOR II',),
#  ('VICTIM/WITNESS INVESTIGATOR III',),
#  ('PHYSICAL THERAPIST ASSISTANT',),
#  ('ORNAMENTAL IRON WORKER',),
#  ('HEALTH PROGRAM COORDINATOR II',),
#  ('INVESTIGATOR, OFFICE OF CITIZEN COMPLAINTS',),
#  ('ARCHITECTURAL ASSISTANT II',),
#  ('HEALTH PROGRAM PLANNER',),
#  ('CONFIDENTIAL SECRETARY TO DISTRICT ATTORNEY',),
#  ('ASSOCIATE HUMAN RESOURCES ANALYST',),
#  ('ASSISTANT DIRECTOR, LOG CABIN RANCH',),
#  ('MEDICAL RECORDS TECHNICIAN',),
#  ('MEDICAL SOCIAL WORKER',),
#  ('SENIOR ESTATE INVESTIGATOR',),
#  ('SECURITY GUARD',),
#  ("PUBLIC DEFENDER'S INVESTIGATOR",),
#  ('INVESTIGATOR, TAXI & ACCESS SVCS',),
#  ('SENIOR FARE COLLECTIONS RECEIVER',),
#  ('CHIEF DIETITIAN',),
#  ('SURVEY ASSISTANT II',),
#  ('PUBLIC SERVICE TRAINEE',),
#  ('LIBRARIAN II - ASIAN ARTS',),
#  ('DEPUTY COURT CLERK II',),
#  ('ASSISTANT STOREKEEPER',),
#  ('REAL PROPERTY APPRAISER',),
#  ('REPRESENTATIVE, HUMAN RIGHTS COMMISSION',),
#  ('COUNSELOR, JUVENILE HALL',),
#  ('TRANSIT PLANNER II',),
#  ('RETIREMENT ANALYST',),
#  ('PLANNER II',),
#  ('ASSISTANT INDUSTRIAL HYGIENIST',),
#  ('EMPLOYEE ASSISTANCE COUNSELOR',),
#  ('ADMINISTRATIVE ANALYST',),
#  ('SPECIALIST IN AGING II',),
#  ('REHABILITATION SERVICES COORDINATOR',),
#  ('AFFIRMATIVE ACTION SPECIALIST',),
#  ('POWER GENERATION TECHNICIAN I',),
#  ('TREE TOPPER',),
#  ('WATER QUALITY TECHNICIAN III',),
#  ('EMPLOYEE RELATIONS REPRESENTATIVE',),
#  ('STATION OFFICER',),
#  ('REPRESENTATIVE, COMMISSION ON THE STATUS OF WOMEN',),
#  ('METAL FABRICATOR',),
#  ('EXECUTIVE SECRETARY II',),
#  ('WATERSHED KEEPER SUPERVISOR',),
#  ('MAYORAL STAFF XII',),
#  ('MEDICAL STAFF SERVICES DEPARTMENT ANALYST',),
#  ('UNIT CLERK',),
#  ('ASSISTANT HEALTH EDUCATOR',),
#  ('UTILITY ANALYST',),
#  ('ENVIRONMENT SPECIALIST',),
#  ('LEGAL ASSISTANT',),
#  ('INVESTIGATOR, TAX COLLECTOR',),
#  ('SENIOR ELIGIBILITY WORKER',),
#  ('SOCIAL WORK SUPERVISOR',),
#  ('CONFIDENTIAL SECRETARY CITY ATTORNEY',),
#  ('IS TRAINER - JOURNEY',),
#  ('MEDICAL EVALUATIONS ASSISTANT',),
#  ('HEALTH CARE BILLING CLERK II',),
#  ('PERSONAL PROPERTY AUDITOR',),
#  ('NURSES STAFFING ASSISTANT',),
#  ('PURCHASER',),
#  ('PROGRAM SPECIALIST',),
#  ('COURT ASSISTANT, SUPERIOR COURT',),
#  ('EMERGENCY PLANNING COORDINATOR',),
#  ('PEST CONTROL SPECIALIST',),
#  ('ROOFER',),
#  ('DIRECTOR OF ACTIVITIES, THERAPY AND VOLUNTEER SERV',),
#  ('COOK',),
#  ('SECRETARY, HEALTH COMMISSION',),
#  ('LIBRARIAN I',),
#  ('SURVEY ASSISTNAT I',),
#  ('COURT CLERK',),
#  ('SEWER MAINTENANCE WORKER',),
#  ('CHIEF PAYROLL AND PERSONNEL CLERK',),
#  ('PORTER SUPERVISOR I',),
#  ('EMPLOYMENT AND TRAINING SPECIALIST III',),
#  ('CIVIL ENGINEERING ASSISTANT',),
#  ("WORKER'S COMPENSATION ADJUSTER",),
#  ('FARE COLLECTIONS RECEIVER',),
#  ('PRINCIPAL PERMIT AND CITATION CLERK',),
#  ('CUSTOMER SERVICE AGENT SUPERVISOR',),
#  ('RECREATION SUPERVISOR',),
#  ('IS OPERATOR - SENIOR',),
#  ('ESTATE INVESTIGATOR',),
#  ('IS BUSINESS ANALYST - ASSISTANT',),
#  ('ADMINISTRATIVE ANALYST II',),
#  ('TRAFFIC SURVEY TECHNICIAN',),
#  ('JANITORIAL SERVICES ASSISTANT SUPERVISOR',),
#  ('HODCARRIER',),
#  ('IS TECHNICIAN - SENIOR',),
#  ('LEGAL SECRETARY II',),
#  ('ASSISTANT GENERAL SERVICES MANAGER',),
#  ('WHARFINGER II',),
#  ('DIETITIAN',),
#  ('CURATOR III',),
#  ('SENIOR TRANSIT TRAFFIC CHECKER',),
#  ('WATERSHED KEEPER',),
#  ('EMPLOYMENT & TRAINING SPECIALIST II',),
#  ('IS PROGRAMMER ANALYST',),
#  ('ELECTRICAL ENGINEERING ASSOCIATE I',),
#  ('SOCIAL WORK SPECIALIST',),
#  ('WATER METER REPAIRER',),
#  ('ILLUSTRATOR AND ART DESIGNER',),
#  ('COURT INTERPRETER',),
#  ('VOLUNTEER/OUTREACH COORDINATOR',),
#  ('PERSONNEL TECHNICIAN',),
#  ('COMMUNICATIONS DISPATCHER I',),
#  ('REHABILITATION COUNSELOR',),
#  ('PAYROLL CLERK',),
#  ('CHIEF CLERK',),
#  ('RENT BOARD SUPERVISOR',),
#  ('ANIMAL CARE SUPERVISOR',),
#  ('TILE SETTER',),
#  ('ARCHITECTURAL ASSISTANT  I',),
#  ('CHEF',),
#  ('LEGISLATION CLERK',),
#  ('MAYORAL STAFF IX',),
#  ('SECRETARY II',),
#  ('TRANSIT FARE INSPECTOR',),
#  ('ASSOCIATE MUSEUM CONSERVATOR, ASIAN ART MUSEUM',),
#  ('SENIOR CUSTOMER SERVICE AGENT',),
#  ('MANAGEMENT ASSISTANT',),
#  ('PUBLIC INFORMATION OFFICER',),
#  ('SENIOR ACCOUNTANT',),
#  ('ASSISTANT PURCHASER',),
#  ('ASSISTANT RETIREMENT ANALYST',),
#  ('EPIDEMIOLOGIST I',),
#  ('STATISTICIAN',),
#  ('PERFORMING ARTS CENTER AIDE',),
#  ('NURSERY SPECIALIST',),
#  ('ASPHALT FINISHER',),
#  ('LEGAL RESEARCH ASSISTANT',),
#  ('SENIOR MUSEUM REGISTRAR',),
#  ('PRINCIPAL ACCOUNT CLERK',),
#  ('FOOD SERVICE SUPERVISOR',),
#  ('MAIL AND REPRODUCTION SERVICE SUPERVISOR',),
#  ('CHIEF DEPUTY ADULT PROBATION OFFICER',),
#  ('FISCAL TECHNICIAN',),
#  ('FORENSIC LABORATORY TECHNICIAN',),
#  ('FINGERPRINT TECHNICIAN III',),
#  ('COMMUNITY DEVELOPMENT SPECIALIST',),
#  ('MATERIALS TESTING TECHNICIAN',),
#  ('CUSTODIAL SUPERVISOR',),
#  ('PARKING METER REPAIRER',),
#  ('HOSPITAL ELIGIBILITY WORKER',),
#  ('HEALTH PROGRAM COORDINATOR I',),
#  ('LIBRARY TECHNICAL ASSISTANT II',),
#  ('EXECUTIVE SECRETARY I',),
#  ('MEDICAL RECORDS CLERK',),
#  ('STOREKEEPER',),
#  ('SENIOR FOOD SERVICE SUPERVISOR',),
#  ("DISTRICT ATTORNEY'S INVESTIGATIVE ASSISTANT",),
#  ('POLICE SERVICES AIDE',),
#  ('WINDOW CLEANER',),
#  ('CITIZENS COMPLAINT OFFICER',),
#  ('FIELD SERVICES ASSISTANT SUPERVISOR',),
#  ('SOFT FLOOR COVERER',),
#  ('MATERIALS TESTING AIDE',),
#  ('SENIOR PSYCHIATRIC ORDERLY',),
#  ('CURATOR II',),
#  ('VICTIM/WITNESS INVESTIGATOR II',),
#  ('LEGAL SECRETARY I',),
#  ('TRANSIT TRAFFIC CHECKER',),
#  ('JANITORIAL SERVICES SUPERVISOR',),
#  ('CHILD SUPPORT OFFICER II',),
#  ('PRINCIPAL WATER SERVICES CLERK',),
#  ('METALSMITH',),
#  ('PLANNER I',),
#  ('IS OPERATOR - ANALYST',),
#  ('HEAD PHOTOGRAPHER',),
#  ('SENIOR LEGAL PROCESS CLERK',),
#  ('WINDOW CLEANER SUPERVISOR',),
#  ('SENIOR COLLECTIONS OFFICER',),
#  ('INVENTORY CLERK',),
#  ('ACUPUNCTURIST',),
#  ('PHYSICAL THERAPY AIDE',),
#  ('IS PROGRAMMER ANALYST - ASSISTANT',),
#  ('FORENSIC AUTOPSY TECHNICIAN',),
#  ('DOCUMENT EXAMINER TECHNICIAN',),
#  ('SENIOR PERMIT AND CITATION CLERK',),
#  ('MEDIA PROGRAMMING SPECIALIST',),
#  ('FOOD SERVICE WORKER',),
#  ('MAYORAL STAFF X',),
#  ('ZOO CURATOR',),
#  ('SENIOR SWIMMING INSTRUCTOR',),
#  ('SENIOR TRANSIT INFORMATION CLERK',),
#  ('FINGERPRINT TECHNICIAN II',),
#  ('PHARMACY HELPER',),
#  ('LIBRARY TECHNICAL ASSISTANT I',),
#  ('BENEFITS ANALYST',),
#  ('DISEASE CONTROL INVESTIGATOR',),
#  ('STORES AND EQUIPMENT ASSISTANT SUPERVISOR',),
#  ('SENIOR LAUNDRY WORKER',),
#  ('ASSISTANT COUNSELOR',),
#  ('IS TECHNICIAN - JOURNEY',),
#  ('CUSTODIAN',),
#  ('CITY PLANNING GRAPHICS SUPERVISOR',),
#  ('COURT ADMINISTRATIVE SECRETARY',),
#  ('ACCOUNTANT',),
#  ('SENIOR BOOK REPAIRER',),
#  ('WHARFINGER I',),
#  ('HEALTH WORKER II',),
#  ('BAKER',),
#  ('SENIOR WATER SERVICES CLERK',),
#  ('SENIOR STOREKEEPER',),
#  ('URBAN FORESTRY INSPECTOR',),
#  ("MEDICAL EXAMINER'S INVESTIGATOR I",),
#  ('ENVIRONMENTAL ASSISTANT',),
#  ('ASPHALT WORKER',),
#  ('SENIOR CLERK TYPIST',),
#  ('PATIENT ACCOUNTS CLERK',),
#  ('SECRETARY, BUILDING INSPECTION COMMISSION',),
#  ('SENIOR MORGUE ATTENDANT',),
#  ('IS TRAINER - ASSISTANT',),
#  ('TRANSIT INFORMATION CLERK',),
#  ('ANIMAL CONTROL OFFICER',),
#  ('PERMIT AND CITATION CLERK',),
#  ('ELECTROENCEPHALOGRAPH TECHNICIAN I',),
#  ('ANIMAL KEEPER',),
#  ('ENVIRONMENTAL HEALTH TECHNICIAN I',),
#  ('SHELTER OFFICE SUPERVISOR',),
#  ('DENTAL AIDE',),
#  ('MAYORAL STAFF VII',),
#  ('HEALTH WORKER III',),
#  ('VICTIM/WITNESS INVESTIGATOR I',),
#  ('CASHIER II',),
#  ('AIRPORT NOISE ABATEMENT SPECIALIST',),
#  ('JUNIOR MANAGEMENT ASSISTANT',),
#  ('RESEARCH ASSISTANT',),
#  ('COURT ALTERNATIVE SPECIALIST I',),
#  ('SENIOR PERSONNEL CLERK',),
#  ('INDUSTRIAL INJURY INVESTIGATOR',),
#  ('COURT PARALEGAL',),
#  ('SPECIAL ASSISTANT XVIII',),
#  ('CLERK TYPIST',),
#  ('LEGISLATIVE CALENDAR CLERK',),
#  ('BUILDING AND GROUNDS PATROL OFFICER',),
#  ('SOCIAL WORKER',),
#  ('ACCOUNT CLERK',),
#  ('ARTS PROGRAM ASSISTANT',),
#  ('HUMAN SERVICES TECHNICIAN',),
#  ('ORTHOPEDIC TECHNICIAN II',),
#  ('ENVIRONMENT HEALTH TECHNICIAN II',),
#  ('IS OPERATOR - JOURNEY',),
#  ('SENIOR OPERATIONS MANAGER',),
#  ('SENIOR MEDICAL TRANSCRIBER TYPIST',),
#  ('VENDOR',),
#  ('HEALTH WORKER I',),
#  ('MEDICAL TRANSCRIBER TYPIST',),
#  ('SENIOR UNIT CLERK',),
#  ('EMPLOYMENT AND TRAINING SPECIALIST I',),
#  ('MEDICAL STAFF SERVICES DEPARTMENT SPECIALIST',),
#  ('JUNIOR ADMINISTRATIVE ANALYST',),
#  ('COLLECTIONS OFFICER',),
#  ('METER READER',),
#  ('ELECTIONS WORKER',),
#  ('SENIOR PHARMACY HELPER',),
#  ('ASSISTANT COOK',),
#  ('SENIOR TELEPHONE OPERATOR',),
#  ('INSTITUTIONAL POLICE LIEUTENANT',),
#  ('DEPUTY SEALER OF WEIGHTS AND MEASURES',),
#  ('CASHIER III',),
#  ('OFFSET MACHINE OPERATOR',),
#  ('ACCOUNTANT INTERN',),
#  ('SHELTER SERVICE REPRESENTATIVE',),
#  ('MEDIA PRODUCTION TECHNICIAN',),
#  ('RECREATION COORDINATOR',),
#  ('AGRICULTURAL INSPECTOR',),
#  ('PATIENT SERVICES FINANCE TECHNICIAN',),
#  ('RESPIRATORY CARE PRACTITIONER',),
#  ('INSPECTOR OF WEIGHTS AND MEASURES',),
#  ('ANIMAL CARE ATTENDANT',),
#  ('BEAUTICIAN',),
#  ("LEGISLATIVE ASSISTANT, CITY ATTORNEY'S OFFICE",),
#  ('CURATOR I',),
#  ('MUSEUM REGISTRAR',),
#  ('LIGHTING FIXTURE MAINTENANCE WORKER',),
#  ('BACTERIOLOGICAL LABORATORY ASSISTANT',),
#  ('ASSISTANT POWER HOUSE OPERATOR',),
#  ('COMMUNITY DEVELOPMENT ASSISTANT',),
#  ('ASSISTANT RECREATION DIRECTOR',),
#  ('SHELTER OFFICE ASSISTANT SUPERVISOR',),
#  ('LIBRARY ASSISTANT',),
#  ('ANIMAL CARE ASSISTANT SUPERVISOR',),
#  ('SUPERVISING BUILDING AND GROUNDS PATROL OFFICER',),
#  ('GRAPHIC ARTIST',),
#  ('FINGERPRINT TECHNICIAN I',),
#  ('PHOTOGRAPHER',),
#  ("SHERIFF'S CADET",),
#  ('RECREATION SPECIALIST',),
#  ('HEALTH CARE BILLING CLERK I',),
#  ('BENEFITS TECHNICIAN',),
#  ('MARINA ASSISTANT MANAGER',),
#  ('SENIOR MICROPHOTO/IMAGING TECHNICIAN',),
#  ('SENIOR FOOD SERVICE WORKER',),
#  ('SENIOR ASSESSMENT CLERK',),
#  ('SENIOR MUSEUM PREPARATOR',),
#  ('SENIOR MATERIALS AND SUPPLIES SUPERVISOR',),
#  ('ELECTIONS CLERK',),
#  ('PLANNER TECHNICIAN',),
#  ('PORTER ASSISTANT SUPERVISOR',),
#  ('SENIOR OFFSET MACHINE OPERATOR',),
#  ('CRAFTS INSTRUCTOR',),
#  ('YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS',),
#  ('TRANSCRIBER TYPIST',),
#  ('PERSONNEL CLERK',),
#  ('STABLE ATTENDANT',),
#  ('CASHIER I',),
#  ('LEGAL PROCESS CLERK',),
#  ('DIETETIC TECHNICIAN',),
#  ('BRAILLIST',),
#  ('SHADE AND DRAPERY WORKER',),
#  ('TELEPHONE OPERATOR',),
#  ('SIGNAL AND SYSTEMS ENGINEER',),
#  ('VICTIM & WITNESS TECHNICIAN',),
#  ('BOOK REPAIRER',),
#  ('SPECIAL ASSISTANT III',),
#  ('REAL PROPERTY APPRAISER TRAINEE',),
#  ('LABORATORY HELPER',),
#  ('FARMER',),
#  ('ASSESSMENT CLERK',),
#  ('MUSEUM PREPARATOR',),
#  ('SWIMMING INSTRUCTOR/POOL LIFEGUARD',),
#  ('ASSOCIATE MUSEUM REGISTRAR',),
#  ('INSTITUTION UTILITY WORKER',),
#  ('SECRETARY,JUVENILE PROBATION COMMISSION',),
#  ('HOUSEKEEPER/FOOD SERVICE CLEANER',),
#  ('CLAIMS PROCESS CLERK',),
#  ('PUBLIC SERVICE AIDE-ASSOCIATE TO PROFESSIONALS',),
#  ('CHIEF TELEPHONE OPERATOR',),
#  ('CUSTOMER SERVICE AGENT TRAINEE',),
#  ('HOME HEALTH AIDE',),
#  ('MAYORAL STAFF IV',),
#  ('MATERIALS AND SUPPLIES SUPERVISOR',),
#  ('SUPPLY ROOM ATTENDENT',),
#  ('SENIOR SUPERVISING PROBATION OFFICER, JUVENILE POU',),
#  ('STUDENT DESIGN TRAINEE 2/ARC-ENG-PLNG',),
#  ('PUBLIC RELATIONS ASSISTANT',),
#  ('DEPUTY COURT CLERK I',),
#  ('STUDENT DESIGN TRAINEE 1/ARC-ENG-PLNG',),
#  ('LIBRARY PAGE',),
#  ('JUNIOR CLERK TYPIST',),
#  ('JUNIOR CLERK',),
#  ('CHILD CARE SPECIALIST',),
#  ('PUBLIC SERVICE AIDE-SPECIAL PROGRAMS',),
#  ('MORGUE ATTENDANT',),
#  ('MICROPHOTO/IMAGING TECHNICIAN',),
#  ('ENVIRONMENTAL SERVICE WORKER',),
#  ('PRINCIPAL RECREATION SUPERVISOR',),
#  ...]

# %%
# %%sql
# #count of unique Job Titles in table
# Select count(distinct JobTitle) as number_of_Job_titles
# From salaries_data
# Out:
#  * mysql://root:***@localhost/salaries
# 1 rows affected.
# [(1500,)]

# %% [markdown]
# #### 2. Job titles with overtime pay greater than 50,000

# %%
# %%sql
#
# Select JobTitle , OvertimePay
# From salaries_data
# Where OvertimePay > 50000
# Order by OvertimePay Desc
# Out:
#  * mysql://root:***@localhost/salaries
# 925 rows affected.
# [('CAPTAIN III (POLICE DEPARTMENT)', 245131.88),
#  ('Lieutenant, Fire Suppression', 220909.48),
#  ('EMT/Paramedic/Firefighter', 192424.49),
#  ('Firefighter', 160418.47),
#  ('Electronic Maintenance Tech', 146415.32),
#  ('Firefighter', 139260.09),
#  ('ELECTRONIC MAINTENANCE TECHNICIAN', 139102.95),
#  ('Transit Supervisor', 137462.8),
#  ('TRANSIT SUPERVISOR', 135159.38),
#  ('EMT/Paramedic/Firefighter', 133645.42),
#  ('Firefighter', 133355.19),
#  ('Firefighter', 130268.39),
#  ('Transit Supervisor', 129414.28),
#  ('TRANSIT SUPERVISOR', 126778.88),
#  ('TRANSIT SUPERVISOR', 126725.82),
#  ('Captain, Fire Suppression', 125868.06),
#  ('Battlion Chief, Fire Suppressi', 124413.13),
#  ('Incident Support Specialist', 123729.82),
#  ('Lieutenant, Fire Suppression', 120550.52),
#  ('TRANSIT SUPERVISOR', 119951.72),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 119407.7),
#  ('CAPTAIN, EMERGENCYCY MEDICAL SERVICES', 119397.26),
#  ('ELECTRICAL TRANSIT MECHANIC, ASSISTANT SUPERVISOR', 118949.93),
#  ('Firefighter', 118346.08),
#  ('Transit Supervisor', 118250.68),
#  ('Battlion Chief, Fire Suppressi', 118215.58),
#  ('Captain, Fire Suppression', 115673.73),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 115239.98),
#  ('Firefighter', 114847.47),
#  ('EMT/Paramedic/Firefighter', 114613.5),
#  ('Captain, Fire Suppression', 114513.29),
#  ('TRANSIT SUPERVISOR', 114105.85),
#  ('EMT/Paramedic/Firefighter', 113864.58),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 113729.55),
#  ('Captain, Fire Suppression', 113372.94),
#  ('Battlion Chief, Fire Suppressi', 112731.28),
#  ('Firefighter', 112415.38),
#  ('DEPUTY SHERIFF', 112320.96),
#  ('Firefighter', 112211.85),
#  ('Firefighter', 111834.58),
#  ('FIREFIGHTER', 111729.65),
#  ('TRANSIT SUPERVISOR', 111323.49),
#  ('TRANSIT SUPERVISOR', 111199.78),
#  ('EMT/Paramedic/Firefighter', 110423.84),
#  ('Firefighter', 110253.41),
#  ('Lieutenant, Fire Suppression', 110241.31),
#  ('Firefighter', 109506.2),
#  ('Lieutenant, Fire Suppression', 108989.99),
#  ('Firefighter', 108781.84),
#  ('EMT/Paramedic/Firefighter', 108598.97),
#  ('TRANSIT SUPERVISOR', 107913.65),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 106701.58),
#  ('Transit Supervisor', 106319.68),
#  ('CAPTAIN III (POLICE DEPARTMENT)', 106088.18),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 105953.61),
#  ('Transit Supervisor', 105674.81),
#  ('INCIDENT SUPPORT SPECIALIST', 105028.94),
#  ('INCIDENT SUPPORT SPECIALIST', 104632.95),
#  ('TRANSIT SUPERVISOR', 104568.19),
#  ('MAINTENANCE MACHINIST', 103370.89),
#  ('Transit Supervisor', 103342.39),
#  ('Lieutenant, Fire Suppression', 102878.98),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 102454.79),
#  ('DEPUTY SHERIFF', 102118.8),
#  ('TRANSIT SUPERVISOR', 101652.14),
#  ('Firefighter', 101537.25),
#  ('Firefighter', 100967.38),
#  ('Firefighter', 100642.03),
#  ('Firefighter', 100597.63),
#  ('Transit Supervisor', 99914.35),
#  ('Battlion Chief, Fire Suppressi', 99623.51),
#  ('LIEUTENANT, FIRE DEPARTMENT', 99584.94),
#  ('Firefighter', 99175.19),
#  ('FIREFIGHTER', 98534.35),
#  ('CAPTAIN, FIRE SUPPRESSION', 97868.77),
#  ('TRANSIT SUPERVISOR', 97858.62),
#  ('TRANSIT SUPERVISOR', 97729.16),
#  ('Transit Supervisor', 97531.05),
#  ('Lieutenant, Fire Suppression', 97474.3),
#  ('FIREFIGHTER', 97395.59),
#  ('Firefighter', 97173.04),
#  ('Transit Supervisor', 97083.1),
#  ('FIREFIGHTER', 96611.56),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 96304.47),
#  ('FIREFIGHTER', 96154.33),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 96103.91),
#  ('Firefighter', 95499.07),
#  ('Firefighter', 95458.63),
#  ('Firefighter', 94938.18),
#  ('EMT/Paramedic/Firefighter', 94661.81),
#  ('Firefighter', 94582.05),
#  ('Transit Supervisor', 94436.17),
#  ('DEPUTY SHERIFF', 94362.36),
#  ('MAINTENANCE MACHINIST', 93952.0),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 93921.49),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 93700.89),
#  ('Electronic Maintenance Tech', 93639.89),
#  ('Lieutenant, Fire Suppression', 93296.0),
#  ('CAPTAIN, FIRE SUPPRESSION', 93200.58),
#  ('EMT/Paramedic/Firefighter', 93158.31),
#  ('FIRE FIGHTER PARAMEDIC', 92767.41),
#  ('EMT/Paramedic/Firefighter', 92637.89),
#  ('Transit Supervisor', 92565.96),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 92213.11),
#  ('Transit Supervisor', 92166.52),
#  ('Firefighter', 91905.09),
#  ('TRANSIT SUPERVISOR', 91422.49),
#  ('TRANSIT SUPERVISOR', 91198.76),
#  ('Lieutenant, Fire Suppression', 90819.83),
#  ('Transit Supervisor', 90768.42),
#  ('Lieutenant, Fire Suppression', 90736.2),
#  ('LIEUTENANT, FIRE DEPARTMENT', 90593.53),
#  ('Lieutenant, Fire Suppression', 90571.12),
#  ('EMT/Paramedic/Firefighter', 90560.04),
#  ('Firefighter', 90513.91),
#  ('FIREFIGHTER', 90329.62),
#  ('TRANSIT SUPERVISOR', 90023.99),
#  ("SHERIFF'S LIEUTENANT", 89920.21),
#  ('LIEUTENANT, FIRE DEPARTMENT', 89856.01),
#  ('FIREFIGHTER', 89773.95),
#  ('Firefighter', 89676.35),
#  ('FIREFIGHTER', 89485.44),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 89331.76),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)', 89062.9),
#  ('EMT/Paramedic/Firefighter', 88819.1),
#  ('Firefighter', 88575.21),
#  ('Firefighter', 88419.45),
#  ('Lieutenant, Fire Suppression', 88418.36),
#  ('Incident Support Specialist', 88182.07),
#  ('FIREFIGHTER', 87642.33),
#  ('CAPTAIN III (POLICE DEPARTMENT)', 87082.62),
#  ('Firefighter', 87049.3),
#  ('Police Officer 3', 87019.65),
#  ('Wire Rope Cable Maint Sprv', 86853.43),
#  ('FIRE FIGHTER PARAMEDIC', 86719.38),
#  ('FIREFIGHTER', 86551.38),
#  ('Firefighter', 86492.64),
#  ('Firefighter', 86381.68),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)', 86362.68),
#  ('Lieutenant, Fire Suppression', 86249.98),
#  ('Firefighter', 86051.23),
#  ('ELECTRONIC MAINTENANCE TECHNICIAN', 85978.1),
#  ('TRANSIT OPERATIONS SPECIALIST', 85752.59),
#  ('Asst Chf of Dept (Fire Dept)', 85503.16),
#  ('FIREFIGHTER', 85454.77),
#  ('Lieutenant, Fire Suppression', 85351.58),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 84767.48),
#  ('Transit Supervisor', 84753.82),
#  ('LIEUTENANT, FIRE DEPARTMENT', 84547.16),
#  ('Firefighter', 84499.96),
#  ('Electr Maint Tech Asst Sprv', 84408.59),
#  ('Captain, Emergency Med Svcs', 84399.91),
#  ('Police Officer 3', 84217.07),
#  ('Lieutenant, Fire Suppression', 84177.9),
#  ('FIREFIGHTER', 84172.44),
#  ('Firefighter', 84165.89),
#  ('DEPUTY SHERIFF', 83945.39),
#  ('Firefighter', 83918.68),
#  ('Electrical Transit System Mech', 83782.31),
#  ('FIREFIGHTER', 83670.04),
#  ('Firefighter', 83564.33),
#  ('TRANSIT SUPERVISOR', 83345.77),
#  ('Lieutenant, Fire Suppression', 83318.15),
#  ('TRACK MAINTENANCE WORKER SUPERVISOR I', 82703.33),
#  ('Captain, Fire Suppression', 82566.67),
#  ('Electrical Transit System Mech', 82545.61),
#  ('CAPTAIN, EMERGENCYCY MEDICAL SERVICES', 82428.76),
#  ('FIREFIGHTER', 82384.96),
#  ('Police Officer 2', 82328.48),
#  ('Transit Supervisor', 82216.25),
#  ('FIREFIGHTER', 82170.36),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 82162.63),
#  ('FIREFIGHTER', 82132.06),
#  ('Lieutenant, Fire Suppression', 82119.08),
#  ('Police Officer 3', 82054.1),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 82044.45),
#  ('Firefighter', 81794.45),
#  ('Lieutenant, Fire Suppression', 81788.41),
#  ('TRANSIT SUPERVISOR', 81671.14),
#  ('Firefighter', 81580.79),
#  ('Transit Supervisor', 81505.73),
#  ('Transit Supervisor', 81486.19),
#  ('Firefighter', 81416.24),
#  ('Automotive Mechanic', 81281.03),
#  ('Firefighter', 81038.55),
#  ('Firefighter', 80886.02),
#  ('Captain, Fire Suppression', 80789.33),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)', 80706.88),
#  ('Firefighter', 80423.7),
#  ('CAPTAIN, EMERGENCYCY MEDICAL SERVICES', 80411.9),
#  ('Lieutenant, Fire Suppression', 80376.57),
#  ('Transit Supervisor', 80234.32),
#  ('FIREFIGHTER', 79964.69),
#  ('EMT/Paramedic/Firefighter', 79924.84),
#  ('Firefighter', 79905.21),
#  ('FIRE FIGHTER PARAMEDIC', 79721.87),
#  ('Firefighter', 79531.34),
#  ('Heating/Ventilating Inspector', 79484.01),
#  ('Firefighter', 78764.07),
#  ('TRANSIT SUPERVISOR', 78645.12),
#  ('Firefighter', 78635.6),
#  ('FIRE FIGHTER PARAMEDIC', 78532.26),
#  ('MAINTENANCE MACHINIST', 78531.85),
#  ('FIREFIGHTER', 78258.7),
#  ('Transit Supervisor', 78126.28),
#  ('Lieutenant, Fire Suppression', 78045.38),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 78026.28),
#  ('CAPTAIN, FIRE SUPPRESSION', 77937.25),
#  ('Transit Supervisor', 77916.7),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)', 77896.14),
#  ('TRANSIT OPERATOR', 77780.85),
#  ('Firefighter', 77715.13),
#  ('EMT/Paramedic/Firefighter', 77626.2),
#  ('INSPECTOR III, (POLICE DEPARTMENT)', 77595.99),
#  ('Firefighter', 77565.0),
#  ('Firefighter', 77422.97),
#  ('LIEUTENANT, FIRE DEPARTMENT', 77259.53),
#  ('Firefighter', 77112.33),
#  ('MAINTENANCE MACHINIST', 77109.94),
#  ('TRAIN CONTROLLER', 77081.46),
#  ('Captain, Fire Suppression', 77043.41),
#  ('Transit Supervisor', 76907.24),
#  ('Electrl Trnst Mech, Asst Sprv', 76877.14),
#  ('Police Officer 3', 76873.8),
#  ('FIREFIGHTER', 76867.18),
#  ('FIREFIGHTER', 76726.73),
#  ('Battlion Chief, Fire Suppressi', 76624.1),
#  ('LIEUTENANT III (POLICE DEPARTMENT)', 76614.78),
#  ('Lieutenant, Fire Suppression', 76530.73),
#  ('Sr Power Generation Tech', 76518.39),
#  ('Firefighter', 76356.91),
#  ('Captain, Emergency Med Svcs', 76318.3),
#  ('TRANSIT SUPERVISOR', 76075.17),
#  ('FIREFIGHTER', 76012.89),
#  ('Transit Supervisor', 75959.92),
#  ('Sergeant 3', 75954.15),
#  ('Firefighter', 75902.64),
#  ('TRANSIT SUPERVISOR', 75883.5),
#  ('FIREFIGHTER', 75817.75),
#  ('Firefighter', 75785.88),
#  ('Train Controller', 75736.58),
#  ('Lieutenant, Fire Suppression', 75650.23),
#  ('Transit Operator', 75242.51),
#  ('Police Officer 3', 75105.4),
#  ('Firefighter', 75095.51),
#  ('Head Park Patrol Officer', 74984.28),
#  ('Firefighter', 74926.82),
#  ('FIREFIGHTER', 74925.98),
#  ('TRANSIT SUPERVISOR', 74882.87),
#  ('Firefighter', 74745.86),
#  ('TRANSIT SUPERVISOR', 74599.57),
#  ('Firefighter', 74485.71),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 74434.5),
#  ('Firefighter', 74353.63),
#  ('Firefighter', 74342.21),
#  ('Track Maint Wrk Sprv 1', 74319.47),
#  ('LIEUTENANT, FIRE DEPARTMENT', 74266.87),
#  ('Battlion Chief, Fire Suppressi', 74246.62),
#  ('TRANSIT OPERATOR', 74204.21),
#  ('Firefighter', 74183.47),
#  ('TRANSIT SUPERVISOR', 74164.4),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)', 74050.3),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 74019.99),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 73972.5),
#  ('Transit Supervisor', 73922.72),
#  ('ELECTRONIC MAINTENANCE TECHNICIAN', 73696.27),
#  ('FIREFIGHTER', 73625.33),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 73539.45),
#  ('TRANSIT CAR CLEANER', 73528.24),
#  ('Transit Supervisor', 73515.28),
#  ('COMMANDER III, (POLICE DEPARTMENT)', 73478.2),
#  ('ELECTRONIC MAINTENANCE TECHNICIAN', 73458.28),
#  ('Firefighter', 73449.7),
#  ('Lieutenant, Fire Suppression', 73422.09),
#  ('TRANSIT OPERATOR', 73359.89),
#  ('FIREFIGHTER', 73298.91),
#  ('Sergeant 3', 73292.13),
#  ('CAPTAIN, FIRE SUPPRESSION', 73207.61),
#  ('FIREFIGHTER', 73178.82),
#  ('FIREFIGHTER', 73130.52),
#  ('TRANSIT OPERATOR', 73087.41),
#  ('FIREFIGHTER', 73036.51),
#  ('Transit Supervisor', 72980.39),
#  ('Inspector 3', 72885.66),
#  ('FIRE FIGHTER PARAMEDIC', 72836.43),
#  ('Firefighter', 72695.58),
#  ('Transit Supervisor', 72656.57),
#  ('TRANSIT SUPERVISOR', 72630.66),
#  ('TRANSIT SUPERVISOR', 72516.08),
#  ('Firefighter', 72493.42),
#  ('FIREFIGHTER', 72451.83),
#  ('FIREFIGHTER', 72308.94),
#  ('Police Officer 3', 72221.19),
#  ('FIRE FIGHTER PARAMEDIC', 72093.79),
#  ('FIREFIGHTER', 71960.12),
#  ('TRANSIT SUPERVISOR', 71916.16),
#  ('EMT/Paramedic/Firefighter', 71906.72),
#  ('FIRE FIGHTER PARAMEDIC', 71862.8),
#  ('FIREFIGHTER', 71837.3),
#  ('Sergeant 3', 71748.62),
#  ('EMT/Paramedic/Firefighter', 71726.35),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 71725.36),
#  ('Firefighter', 71698.74),
#  ('Battlion Chief, Fire Suppressi', 71643.89),
#  ('FIRE FIGHTER PARAMEDIC', 71499.83),
#  ('FIREFIGHTER', 71448.55),
#  ('FIREFIGHTER', 71373.32),
#  ('ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)', 71344.88),
#  ('Lieutenant, Fire Suppression', 71284.0),
#  ('Transit Supervisor', 71238.74),
#  ('STATIONARY ENGINEER', 71106.68),
#  ('EMT/Paramedic/Firefighter', 71035.16),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 70959.92),
#  ('Firefighter', 70950.68),
#  ('Firefighter', 70850.83),
#  ('FIREFIGHTER', 70824.16),
#  ('FIREFIGHTER', 70730.5),
#  ('TRANSIT OPERATOR', 70666.18),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 70367.54),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 70358.67),
#  ('FIREFIGHTER', 70333.26),
#  ('FIREFIGHTER', 70312.13),
#  ('Police Officer 3', 69980.98),
#  ('Firefighter', 69946.88),
#  ('TRANSIT SUPERVISOR', 69910.69),
#  ('Police Officer 3', 69696.26),
#  ('Electrical Transit System Mech', 69637.07),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)', 69626.12),
#  ('FIREFIGHTER', 69602.62),
#  ('Electrical Transit System Mech', 69579.82),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 69489.99),
#  ('FIREFIGHTER', 69419.29),
#  ("SHERIFF'S SERGEANT", 69382.3),
#  ('MECHANICAL SHOP AND EQUIPMENT SUPERINTENDENT', 69317.08),
#  ('Firefighter', 69273.27),
#  ('Transit Operator', 69054.76),
#  ('FIREFIGHTER', 69005.06),
#  ('FIREFIGHTER', 68980.44),
#  ('FIRE FIGHTER PARAMEDIC', 68861.18),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 68852.91),
#  ('TRACK MAINTENANCE WORKER SUPERVISOR I', 68615.06),
#  ('Wire Rope Cable Maint Mechanic', 68565.2),
#  ('FIREFIGHTER', 68438.92),
#  ('Firefighter', 68372.15),
#  ('EMT/Paramedic/Firefighter', 68365.53),
#  ('Lieutenant, Fire Suppression', 68286.7),
#  ('TRANSIT OPERATOR', 68183.5),
#  ('DEPUTY SHERIFF', 68004.76),
#  ('LIEUTENANT, FIRE DEPARTMENT', 67899.46),
#  ('Automotive Mechanic Sprv 1', 67888.58),
#  ('Battlion Chief, Fire Suppressi', 67875.53),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 67853.69),
#  ('Firefighter', 67848.4),
#  ('FIRE FIGHTER PARAMEDIC', 67825.92),
#  ('FIREFIGHTER', 67825.38),
#  ('Station Agent, Muni Railway', 67819.35),
#  ('ELECTRONIC MAINTENANCE TECHNICIAN', 67796.89),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 67791.53),
#  ('TRANSIT SUPERVISOR', 67731.55),
#  ('Firefighter', 67679.84),
#  ('SENIOR COUNSELOR, JUVENILE HALL', 67659.84),
#  ('ELECTRICAL TRANSIT MECHANIC, ASSISTANT SUPERVISOR', 67624.42),
#  ('Police Officer 3', 67533.51),
#  ('LIEUTENANT, FIRE DEPARTMENT', 67514.41),
#  ('Train Controller', 67402.48),
#  ('Firefighter', 67372.59),
#  ('TRANSIT SUPERVISOR', 67362.26),
#  ('TRANSIT OPERATIONS SPECIALIST', 67332.92),
#  ('TRANSIT OPERATOR', 67266.58),
#  ('FIREFIGHTER', 67188.81),
#  ('Electrical Transit System Mech', 67124.19),
#  ('FIREFIGHTER', 67067.31),
#  ('TRANSIT SUPERVISOR', 67042.02),
#  ('Firefighter', 67009.5),
#  ('Police Officer 3', 66993.86),
#  ('LIEUTENANT III (POLICE DEPARTMENT)', 66977.63),
#  ('Chief Stationary Engineer', 66974.96),
#  ('Electrical Transit System Mech', 66856.53),
#  ('FIREFIGHTER', 66708.34),
#  ('Electrical Transit System Mech', 66643.37),
#  ('Sergeant 3', 66619.51),
#  ('CAPTAIN, FIRE SUPPRESSION', 66596.28),
#  ('Electrical Transit System Mech', 66593.88),
#  ('Firefighter', 66567.84),
#  ('EMT/Paramedic/Firefighter', 66472.6),
#  ('LIEUTENANT, FIRE DEPARTMENT', 66447.73),
#  ('Firefighter', 66347.23),
#  ('Police Officer', 66259.96),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)', 66199.23),
#  ('WIRE ROPE CABLE MAINTENANCE SUPERVISOR', 66164.73),
#  ('TRANSIT SUPERVISOR', 66113.15),
#  ('LIEUTENANT, FIRE DEPARTMENT', 66083.91),
#  ('Electrical Transit System Mech', 66060.59),
#  ('Lieutenant, Fire Suppression', 65924.39),
#  ('FIRE FIGHTER PARAMEDIC', 65886.39),
#  ('Firefighter', 65857.51),
#  ('FIRE FIGHTER PARAMEDIC', 65829.32),
#  ('FIREFIGHTER', 65765.11),
#  ('Firefighter', 65707.11),
#  ('FIREFIGHTER', 65587.13),
#  ('Transit Operator', 65581.66),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 65542.19),
#  ('Firefighter', 65531.3),
#  ('Lieutenant, Fire Suppression', 65409.12),
#  ('Inspector 3', 65229.56),
#  ('Firefighter', 65175.64),
#  ('Firefighter', 65110.24),
#  ('FIRE FIGHTER PARAMEDIC', 65069.19),
#  ('Firefighter', 65021.35),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)', 64985.85),
#  ('Track Maint Wrk Sprv 1', 64958.18),
#  ('Firefighter', 64914.13),
#  ('Sergeant 3', 64913.69),
#  ('Lieutenant, Fire Suppression', 64905.0),
#  ('FIRE FIGHTER PARAMEDIC', 64862.06),
#  ('Transit Operator', 64797.87),
#  ('TRANSIT SUPERVISOR', 64762.0),
#  ('Track Maint Wrk Sprv 1', 64740.14),
#  ('Captain, Emergency Med Svcs', 64739.17),
#  ('FIREFIGHTER', 64725.94),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 64707.92),
#  ('Firefighter', 64674.87),
#  ('Automotive Body & Fender Wrk', 64557.66),
#  ('LIEUTENANT, FIRE DEPARTMENT', 64525.66),
#  ('EMT/Paramedic/Firefighter', 64474.29),
#  ('SENIOR DEPUTY SHERIFF', 64426.82),
#  ('FIREFIGHTER', 64386.13),
#  ('Firefighter', 64363.98),
#  ('Firefighter', 64346.35),
#  ('DEPUTY SHERIFF', 64338.09),
#  ('EMT/Paramedic/Firefighter', 64247.33),
#  ('Firefighter', 64137.72),
#  ('Lieutenant, Fire Suppression', 64030.28),
#  ('Firefighter', 64006.79),
#  ('ELECTRONIC MAINTENANCE TECHNICIAN ASSISTANT SUPERV', 64003.88),
#  ('Firefighter', 63933.92),
#  ('TRANSIT SUPERVISOR', 63929.7),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 63880.86),
#  ('LIEUTENANT, FIRE DEPARTMENT', 63856.44),
#  ('HEATING AND VENTILATING INSPECTOR', 63835.87),
#  ('Insp, Fire Dept', 63761.59),
#  ('Firefighter', 63685.53),
#  ('Lieutenant, Fire Suppression', 63594.31),
#  ('Firefighter', 63577.08),
#  ('Police Officer 3', 63557.26),
#  ('TRANSIT SUPERVISOR', 63414.81),
#  ('Sergeant 3', 63408.21),
#  ('TRANSIT OPERATOR', 63390.8),
#  ('Police Officer 3', 63333.06),
#  ('TRANSIT SUPERVISOR', 63327.85),
#  ('Firefighter', 63300.99),
#  ('Transit Supervisor', 63217.15),
#  ("SHERIFF'S SERGEANT", 63138.82),
#  ('Battlion Chief, Fire Suppressi', 63116.25),
#  ('ELECTRICIAN', 63115.82),
#  ('ELECTRICAL TRANSIT MECHANIC SUPERVISOR I', 63114.86),
#  ('Electrical Transit System Mech', 63094.85),
#  ('Lieutenant, Fire Suppression', 63034.63),
#  ('FIREFIGHTER', 63019.63),
#  ('MAINTENANCE MACHINIST', 62937.3),
#  ('FIREFIGHTER', 62854.45),
#  ('Police Officer 3', 62805.66),
#  ('FIREFIGHTER', 62776.35),
#  ('EMT/Paramedic/Firefighter', 62748.33),
#  ('TRANSIT SUPERVISOR', 62715.08),
#  ('Electronic Maintenance Tech', 62713.02),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 62672.24),
#  ('Firefighter', 62637.71),
#  ('Transit Power Line Worker', 62612.79),
#  ('INSPECTOR III, (POLICE DEPARTMENT)', 62600.83),
#  ('Lieutenant, Fire Suppression', 62540.98),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 62461.61),
#  ('Firefighter', 62446.65),
#  ('Transit Supervisor', 62373.39),
#  ('Firefighter', 62352.49),
#  ('CAPTAIN, FIRE SUPPRESSION', 62283.7),
#  ('Firefighter', 62274.9),
#  ('Transit Operator', 62260.81),
#  ('FIREFIGHTER', 62182.73),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 62098.79),
#  ('Firefighter', 62085.93),
#  ('FIREFIGHTER', 62047.83),
#  ('TRANSIT OPERATOR', 62014.57),
#  ('DEPUTY SHERIFF', 62010.44),
#  ('EMT/Paramedic/Firefighter', 61993.52),
#  ('Firefighter', 61987.34),
#  ('Firefighter', 61983.17),
#  ('FIREFIGHTER', 61896.0),
#  ('Captain, Fire Suppression', 61857.99),
#  ('STATIONARY ENGINEER', 61806.15),
#  ('SENIOR POWER GENERATION TECHNICIAN', 61747.92),
#  ('Firefighter', 61732.36),
#  ('EMT/Paramedic/Firefighter', 61686.38),
#  ('WIRE ROPE CABLE MAINTENANCE MECHANIC', 61685.03),
#  ('Transit Operator', 61682.94),
#  ('TRANSIT SUPERVISOR', 61660.88),
#  ('EMT/Paramedic/Firefighter', 61637.72),
#  ('Firefighter', 61627.86),
#  ('EMT/Paramedic/Firefighter', 61614.85),
#  ('Firefighter', 61594.67),
#  ('Deputy Sheriff', 61594.04),
#  ('FIREFIGHTER', 61569.8),
#  ('ELECTRICAL TRANSIT SHOP SUPERVISOR I', 61316.86),
#  ('Automotive Mechanic', 61309.72),
#  ('Police Officer 3', 61309.26),
#  ('Firefighter', 61300.67),
#  ('Transit Supervisor', 61210.15),
#  ('Station Agent, Muni Railway', 61203.64),
#  ('Sergeant, (Police Department)', 61180.7),
#  ('FIREFIGHTER', 61158.6),
#  ('TRAIN CONTROLLER', 61148.44),
#  ('Firefighter', 61133.9),
#  ('Police Officer 2', 61118.82),
#  ('Firefighter', 61035.34),
#  ('FIRE FIGHTER PARAMEDIC', 60981.91),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)', 60847.56),
#  ('Police Officer 3', 60829.43),
#  ('Senior Stationary Engineer', 60815.24),
#  ('Firefighter', 60810.89),
#  ('Electrical Transit System Mech', 60810.89),
#  ('Sergeant 3', 60754.25),
#  ('LIEUTENANT, FIRE DEPARTMENT', 60744.73),
#  ('TRANSIT OPERATOR', 60711.7),
#  ('Firefighter', 60639.26),
#  ('FIRE FIGHTER PARAMEDIC', 60627.28),
#  ('EMT/Paramedic/Firefighter', 60571.35),
#  ('FIREFIGHTER', 60502.84),
#  ('Transit Supervisor', 60477.42),
#  ('Stationary Engineer', 60354.77),
#  ('TRANSIT SUPERVISOR', 60346.73),
#  ('EMT/Paramedic/Firefighter', 60326.91),
#  ('Electrical Transit System Mech', 60312.96),
#  ('Electrical Trnst Shop Sprv 1', 60306.93),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 60288.07),
#  ('Lieutenant, Fire Suppression', 60167.63),
#  ('Transit Supervisor', 60147.3),
#  ('Police Officer 3', 60140.71),
#  ('Electrical Transit System Mech', 60048.56),
#  ('FIREFIGHTER', 60038.14),
#  ('FIREFIGHTER', 60014.31),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)', 59924.97),
#  ('EMT/Paramedic/Firefighter', 59887.97),
#  ('TRANSIT SUPERVISOR', 59854.97),
#  ('FIREFIGHTER', 59761.06),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)', 59760.9),
#  ('FIREFIGHTER', 59757.11),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 59749.51),
#  ('Firefighter', 59723.16),
#  ('Firefighter', 59715.26),
#  ('LIEUTENANT, FIRE DEPARTMENT', 59699.72),
#  ('EMT/Paramedic/Firefighter', 59674.84),
#  ('Electrical Transit System Mech', 59631.43),
#  ('Firefighter', 59600.99),
#  ('Firefighter', 59456.79),
#  ('TRANSIT OPERATOR', 59448.47),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 59404.63),
#  ('Lieutenant, Fire Suppression', 59361.68),
#  ('Police Officer 3', 59307.45),
#  ('Welder', 59215.63),
#  ('Registered Nurse', 59181.62),
#  ('TRANSIT CAR CLEANER', 59166.91),
#  ('Transit Supervisor', 59079.97),
#  ('TRANSIT OPERATOR', 59068.49),
#  ('Firefighter', 58988.73),
#  ('Electrl Trnst Mech, Asst Sprv', 58959.6),
#  ('Electrl Trnst Mech, Asst Sprv', 58943.98),
#  ('Lieutenant, Fire Suppression', 58917.87),
#  ('Transit Operator', 58914.56),
#  ('Firefighter', 58875.13),
#  ('FIREFIGHTER', 58868.78),
#  ('Electronic Maintenance Tech', 58847.97),
#  ('Stationary Engineer', 58786.13),
#  ('Firefighter', 58768.81),
#  ('Fire Safety Inspector 2', 58747.89),
#  ('Lieutenant, Fire Suppression', 58746.5),
#  ('Captain, Fire Suppression', 58745.2),
#  ('EMT/Paramedic/Firefighter', 58744.71),
#  ('Police Officer 3', 58741.39),
#  ('FIREFIGHTER', 58724.04),
#  ('LIEUTENANT, FIRE DEPARTMENT', 58660.17),
#  ('Station Agent, Muni Railway', 58651.95),
#  ('Firefighter', 58651.93),
#  ('Transit Operator', 58573.5),
#  ('FIREFIGHTER', 58550.59),
#  ('FIREFIGHTER', 58520.96),
#  ('Firefighter', 58499.87),
#  ('Firefighter', 58480.43),
#  ('FIREFIGHTER', 58392.63),
#  ('CAPTAIN, FIRE SUPPRESSION', 58354.29),
#  ('TRANSIT SUPERVISOR', 58352.5),
#  ('FIREFIGHTER', 58335.31),
#  ('TRACK MAINTENANCE WORKER SUPERVISOR I', 58283.57),
#  ('LIEUTENANT, FIRE DEPARTMENT', 58270.63),
#  ('Firefighter', 58235.37),
#  ('Sergeant 3', 58227.28),
#  ('Firefighter', 58226.91),
#  ('Firefighter', 58172.16),
#  ('DEPUTY SHERIFF', 58126.61),
#  ('Battlion Chief, Fire Suppressi', 58091.97),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)', 58084.86),
#  ('Firefighter', 58032.41),
#  ('POLICE OFFICER III', 57966.33),
#  ('Automotive Mechanic', 57885.86),
#  ('TRANSIT SUPERVISOR', 57801.1),
#  ('Electrical Transit System Mech', 57794.58),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 57785.76),
#  ('Senior Deputy Sheriff', 57773.6),
#  ('TRANSIT CAR CLEANER', 57766.87),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 57751.85),
#  ('Automotive Mechanic', 57719.51),
#  ('Firefighter', 57686.11),
#  ('Switch Repairer', 57627.39),
#  ('FIREFIGHTER', 57624.7),
#  ('CAPTAIN, FIRE SUPPRESSION', 57579.25),
#  ('Inspector 3', 57472.87),
#  ('Captain, Fire Suppression', 57470.75),
#  ('CHIEF STATIONARY ENGINEER', 57453.52),
#  ('Sergeant 3', 57416.35),
#  ('Sergeant, (Police Department)', 57387.38),
#  ('LIEUTENANT III (POLICE DEPARTMENT)', 57364.23),
#  ('Firefighter', 57351.36),
#  ('Electrical Transit System Mech', 57343.97),
#  ('Lieutenant, Fire Suppression', 57328.15),
#  ('FIREFIGHTER', 57319.91),
#  ('Transit Operations Specialist', 57305.05),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 57293.49),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 57268.58),
#  ('AUTOMOTIVE MECHANIC SUPERVISOR I', 57199.53),
#  ('FIREFIGHTER', 57157.15),
#  ('Firefighter', 57151.1),
#  ('Senior Deputy Sheriff', 57120.76),
#  ('Pharmacist', 57119.08),
#  ('Firefighter', 57100.77),
#  ('TRANSIT SUPERVISOR', 57097.56),
#  ('CLERK', 57036.75),
#  ('Firefighter', 57000.96),
#  ('Firefighter', 56951.94),
#  ('FIREFIGHTER', 56927.28),
#  ('Inspector 3', 56920.74),
#  ('FIREFIGHTER', 56919.07),
#  ('Electronic Maintenance Tech', 56845.29),
#  ('Firefighter', 56831.83),
#  ('Firefighter', 56738.8),
#  ('Station Agent, Muni Railway', 56737.41),
#  ('Firefighter', 56735.64),
#  ('MAINTENANCE MACHINIST', 56722.22),
#  ('LIEUTENANT, FIRE DEPARTMENT', 56654.78),
#  ('FIREFIGHTER', 56641.93),
#  ('EMT/Paramedic/Firefighter', 56641.46),
#  ('TRANSIT SUPERVISOR', 56601.25),
#  ('Firefighter', 56597.87),
#  ('EMT/Paramedic/Firefighter', 56566.12),
#  ('Deputy Sheriff', 56432.18),
#  ('Captain, Fire Suppression', 56411.49),
#  ('Automotive Mechanic', 56403.77),
#  ("Sheriff's Sergeant", 56383.91),
#  ('TRANSIT OPERATOR', 56337.46),
#  ('FIREFIGHTER', 56335.26),
#  ('Sergeant 3', 56320.58),
#  ('LIEUTENANT, FIRE DEPARTMENT', 56307.38),
#  ('Captain, Fire Suppression', 56291.36),
#  ('Lieutenant, Fire Suppression', 56282.48),
#  ('TRANSIT OPERATOR', 56263.98),
#  ('Transit Operator', 56238.12),
#  ('Firefighter', 56182.96),
#  ('TRANSIT CAR CLEANER', 56172.77),
#  ('Police Officer 3', 56152.11),
#  ('Transit Supervisor', 56134.08),
#  ('WIRE ROPE CABLE MAINTENANCE MECHANIC', 56120.71),
#  ('LIEUTENANT, FIRE DEPARTMENT', 56093.64),
#  ('FIREFIGHTER', 56048.71),
#  ('AUTOMOTIVE MECHANIC', 55999.77),
#  ('TRANSIT OPERATOR', 55991.09),
#  ('Invstgtor,Fire Dept', 55968.43),
#  ('TRANSIT CAR CLEANER', 55896.78),
#  ('EMT/Paramedic/Firefighter', 55849.48),
#  ('Sergeant 2', 55837.24),
#  ('Police Officer 2', 55828.0),
#  ('Deputy Sheriff', 55640.41),
#  ('FIREFIGHTER', 55635.93),
#  ('SENIOR POWER GENERATION TECHNICIAN', 55622.52),
#  ('Transit Supervisor', 55607.28),
#  ('Firefighter', 55591.2),
#  ('Transit Supervisor', 55559.75),
#  ('Firefighter', 55533.39),
#  ('Police Officer 3', 55527.47),
#  ('Sergeant 3', 55499.19),
#  ('TRANSIT SUPERVISOR', 55495.54),
#  ('FIREFIGHTER', 55439.25),
#  ('Lieutenant, Fire Suppression', 55392.47),
#  ('FIREFIGHTER', 55334.44),
#  ('Insp, Fire Dept', 55251.55),
#  ('Transit Supervisor', 55238.76),
#  ('STATION AGENT, MUNICIPAL RAILWAY', 55129.17),
#  ('Police Officer 3', 55121.59),
#  ('FIREFIGHTER', 55079.91),
#  ('FIREFIGHTER', 55041.99),
#  ('Lieutenant, Fire Suppression', 55041.92),
#  ('FIRE FIGHTER PARAMEDIC', 55004.96),
#  ('Transit Operator', 54967.78),
#  ('Firefighter', 54954.77),
#  ('FIREFIGHTER', 54931.7),
#  ('Sr Power Generation Tech', 54887.97),
#  ('LIEUTENANT, FIRE DEPARTMENT', 54870.85),
#  ('Sergeant 3', 54852.23),
#  ('Wire Rope Cable Maint Mechanic', 54851.25),
#  ('FIREFIGHTER', 54846.07),
#  ('TRANSIT OPERATOR', 54843.97),
#  ('TRANSIT SUPERVISOR', 54839.23),
#  ('FIREFIGHTER', 54835.51),
#  ('TRAIN CONTROLLER', 54830.13),
#  ('FIREFIGHTER', 54828.91),
#  ('WELDER', 54828.46),
#  ('Deputy Sheriff', 54799.97),
#  ('FIREFIGHTER', 54740.48),
#  ('Transit Supervisor', 54731.42),
#  ('EMT/Paramedic/Firefighter', 54711.98),
#  ('TRANSIT OPERATOR', 54673.77),
#  ('Captain, Emergency Med Svcs', 54613.27),
#  ('ELECTRONIC MAINTENANCE TECHNICIAN ASSISTANT SUPERV', 54599.32),
#  ('Police Officer 3', 54556.54),
#  ('Asst Chf of Dept (Fire Dept)', 54545.03),
#  ('FIRE FIGHTER PARAMEDIC', 54524.26),
#  ('Lieutenant, Fire Suppression', 54519.23),
#  ('FIREFIGHTER', 54460.76),
#  ('FIREFIGHTER', 54436.25),
#  ('Captain, Fire Suppression', 54421.93),
#  ('Lieut,Fire Prev', 54390.01),
#  ('Firefighter', 54384.82),
#  ('TRANSIT SUPERVISOR', 54360.73),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)', 54342.28),
#  ('Battlion Chief, Fire Suppressi', 54339.84),
#  ('TRANSIT OPERATOR', 54275.08),
#  ('Police Officer 3', 54235.5),
#  ('FIREFIGHTER', 54207.93),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 54198.67),
#  ('Transit Supervisor', 54190.77),
#  ('TRANSIT OPERATOR', 54187.3),
#  ('TRANSIT SUPERVISOR', 54179.33),
#  ('Sr Power Generation Tech', 54139.23),
#  ('DEPUTY SHERIFF', 54092.26),
#  ('CAPTAIN, EMERGENCYCY MEDICAL SERVICES', 54054.41),
#  ('IS Business Analyst-Principal', 54025.0),
#  ('AUTOMOTIVE MECHANIC', 54006.51),
#  ('Police Officer 3', 54003.76),
#  ('TRANSIT OPERATOR', 53917.69),
#  ('Captain, Fire Suppression', 53895.92),
#  ('Firefighter', 53884.04),
#  ('ELECTRICAL TRANSIT MECHANIC, ASSISTANT SUPERVISOR', 53819.61),
#  ('EMT/Paramedic/Firefighter', 53803.7),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 53766.21),
#  ('Firefighter', 53746.73),
#  ('TRANSIT OPERATIONS SPECIALIST', 53734.69),
#  ('Firefighter', 53698.99),
#  ('FIREFIGHTER', 53688.69),
#  ('Firefighter', 53683.92),
#  ('EMT/Paramedic/Firefighter', 53566.2),
#  ('FIREFIGHTER', 53551.86),
#  ('TRANSIT OPERATOR', 53526.63),
#  ('Police Officer 3', 53524.35),
#  ('Captain, Fire Suppression', 53486.93),
#  ('Firefighter', 53485.46),
#  ('Battlion Chief, Fire Suppressi', 53465.15),
#  ('Firefighter', 53439.75),
#  ('Firefighter', 53409.3),
#  ('TRANSIT OPERATOR', 53374.79),
#  ('Electrical Trnst Shop Sprv 1', 53317.53),
#  ('Firefighter', 53306.64),
#  ('Automotive Mechanic', 53263.72),
#  ('Firefighter', 53248.26),
#  ('CAPTAIN, EMERGENCYCY MEDICAL SERVICES', 53209.03),
#  ('Firefighter', 53195.58),
#  ('CAPTAIN, FIRE SUPPRESSION', 53146.41),
#  ('Firefighter', 53129.06),
#  ('Switch Repairer', 53117.4),
#  ('Operating Engineer, Universal', 53097.38),
#  ('Pharmacist', 53056.24),
#  ('ELECTRONIC MAINTENANCE TECHNICIAN', 53041.23),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 53021.78),
#  ('Station Agent, Muni Railway', 52978.17),
#  ('Lieutenant, Fire Suppression', 52972.81),
#  ('Lieutenant, Fire Suppression', 52967.59),
#  ('Firefighter', 52933.26),
#  ('Pharmacist', 52932.68),
#  ('Captain, Emergency Med Svcs', 52922.31),
#  ('Firefighter', 52911.57),
#  ('Sergeant 3', 52874.9),
#  ('TRANSIT SUPERVISOR', 52848.17),
#  ('SENIOR DEPUTY SHERIFF', 52848.14),
#  ('Firefighter', 52829.52),
#  ('Sergeant 3', 52827.66),
#  ('Automotive Body & Fender Wrk', 52826.23),
#  ('EMT/Paramedic/Firefighter', 52795.99),
#  ('FIREFIGHTER', 52742.53),
#  ('FIREFIGHTER', 52697.7),
#  ('LIEUTENANT III (POLICE DEPARTMENT)', 52648.92),
#  ('TRANSIT OPERATOR', 52640.53),
#  ('ASSISTANT ELECTRONIC MAINTENANCE TECHNICIAN', 52579.59),
#  ('FIREFIGHTER', 52578.13),
#  ('Police Officer 3', 52527.05),
#  ('Firefighter', 52510.81),
#  ('Firefighter', 52507.4),
#  ('FIREFIGHTER', 52505.74),
#  ('Automotive Mechanic', 52471.89),
#  ('DEPUTY SHERIFF', 52450.56),
#  ('Firefighter', 52293.09),
#  ('Electrical Transit System Mech', 52286.79),
#  ('Firefighter', 52286.06),
#  ('Electrical Transit System Mech', 52274.68),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)', 52252.02),
#  ('FIREFIGHTER', 52249.52),
#  ('Firefighter', 52229.88),
#  ('Electrical Transit System Mech', 52225.85),
#  ('Firefighter', 52145.77),
#  ('CAPTAIN, FIRE SUPPRESSION', 52095.06),
#  ('Firefighter', 52083.31),
#  ('Police Officer 3', 52041.98),
#  ('Firefighter', 52024.34),
#  ('Battlion Chief, Fire Suppressi', 51949.05),
#  ('Transit Supervisor', 51940.36),
#  ("Sheriff's Lieutenant", 51901.75),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 51879.08),
#  ('INSPECTOR III, (POLICE DEPARTMENT)', 51864.26),
#  ('Station Agent, Muni Railway', 51848.44),
#  ('CAPTAIN, FIRE SUPPRESSION', 51847.45),
#  ('TRANSIT SUPERVISOR', 51783.73),
#  ('FIREFIGHTER', 51718.69),
#  ('COUNSELOR, LOG CABIN RANCH', 51711.79),
#  ('Inspector 3', 51618.77),
#  ('Transit Operator', 51618.46),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 51593.05),
#  ('Fire Safety Inspector 2', 51574.81),
#  ('Insp, Fire Dept', 51537.84),
#  ('Lieutenant, Fire Suppression', 51514.24),
#  ('FIREFIGHTER', 51443.65),
#  ('Automotive Mechanic Asst Sprv', 51435.23),
#  ('FIREFIGHTER', 51432.24),
#  ('Firefighter', 51431.66),
#  ('Police Officer 3', 51426.52),
#  ('FIREFIGHTER', 51360.18),
#  ('Firefighter', 51331.69),
#  ('Police Officer 2', 51295.89),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 51262.84),
#  ('Police Officer', 51259.77),
#  ('FIREFIGHTER', 51240.46),
#  ('Medical Evaluations Assistant', 51207.13),
#  ('FIREFIGHTER', 51200.21),
#  ('Police Officer 3', 51188.52),
#  ('Police Officer 3', 51186.71),
#  ('Firefighter', 51148.22),
#  ('Transit Operator', 51128.54),
#  ('Sergeant, (Police Department)', 51120.56),
#  ('LIEUTENANT, FIRE DEPARTMENT', 51115.99),
#  ('TRANSIT SUPERVISOR', 51098.13),
#  ('FIREFIGHTER', 51069.08),
#  ('Transit Supervisor', 51037.27),
#  ('TRAIN CONTROLLER', 51011.01),
#  ('FIREFIGHTER', 51007.74),
#  ('Police Officer 2', 51005.64),
#  ('STATION AGENT, MUNICIPAL RAILWAY', 50989.01),
#  ('Electrical Transit System Mech', 50988.09),
#  ('Senior Deputy Sheriff', 50977.7),
#  ('FIRE FIGHTER PARAMEDIC', 50976.69),
#  ('DEPUTY SHERIFF', 50925.41),
#  ('TRANSIT OPERATOR', 50923.34),
#  ('Fire Safety Inspector 2', 50918.11),
#  ('Firefighter', 50894.29),
#  ('TRANSIT OPERATOR', 50885.94),
#  ('Deputy Sheriff', 50873.39),
#  ('Electrical Transit System Mech', 50864.83),
#  ('Lieutenant, Fire Suppression', 50864.01),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 50820.0),
#  ('Firefighter', 50760.41),
#  ('Firefighter', 50751.72),
#  ('Lieutenant, Fire Suppression', 50737.79),
#  ('FIRE FIGHTER PARAMEDIC', 50720.85),
#  ('Operating Engineer, Universal', 50718.67),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 50705.17),
#  ('Transit Operator', 50692.13),
#  ('FIRE FIGHTER PARAMEDIC', 50649.77),
#  ('Police Officer 2', 50648.03),
#  ('Deputy Sheriff', 50646.73),
#  ('WIRE ROPE CABLE MAINTENANCE MECHANIC', 50641.24),
#  ('FIREFIGHTER', 50617.11),
#  ('Firefighter', 50613.96),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 50611.73),
#  ('FIREFIGHTER', 50587.27),
#  ('FIREFIGHTER', 50581.38),
#  ('Electrical Transit System Mech', 50581.26),
#  ('STATION AGENT, MUNICIPAL RAILWAY', 50560.85),
#  ('Police Officer 3', 50558.48),
#  ('Electr Maint Tech Asst Sprv', 50550.81),
#  ('FIREFIGHTER', 50531.95),
#  ('Station Agent, Muni Railway', 50494.49),
#  ('Police Officer 2', 50474.85),
#  ('STATION AGENT, MUNICIPAL RAILWAY', 50474.2),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 50466.5),
#  ('Senior Deputy Sheriff', 50450.34),
#  ('Inspector 3', 50426.43),
#  ('SENIOR POWER GENERATION TECHNICIAN', 50358.77),
#  ('FIREFIGHTER', 50329.96),
#  ('LIEUTENANT, FIRE DEPARTMENT', 50298.75),
#  ('FIREFIGHTER', 50298.7),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 50291.68),
#  ('Insp, Fire Dept', 50290.03),
#  ('Lieut,Fire Prev', 50270.21),
#  ('Firefighter', 50256.98),
#  ('EMT/Paramedic/Firefighter', 50251.89),
#  ('DEPUTY SHERIFF', 50243.35),
#  ('Sergeant 3', 50234.38),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC', 50231.51),
#  ('INSPECTOR III, (POLICE DEPARTMENT)', 50227.61),
#  ('STATION AGENT, MUNICIPAL RAILWAY', 50191.22),
#  ('FIREFIGHTER', 50187.14),
#  ('TRANSIT OPERATOR', 50143.43),
#  ('Station Agent, Muni Railway', 50138.9),
#  ('Utility Plumber', 50135.24),
#  ('Police Officer 3', 50134.88),
#  ('Police Officer', 50133.9),
#  ('Firefighter', 50122.29),
#  ('Senior Deputy Sheriff', 50114.58),
#  ('LIEUTENANT, FIRE DEPARTMENT', 50096.28),
#  ('EMT/Paramedic/Firefighter', 50093.13),
#  ('Police Officer 3', 50060.8),
#  ('FIREFIGHTER', 50019.79)]

# %% [markdown]
# #### 3. Average base pay for all employees

# %%
# %%sql
#
# Select Round(Avg(BasePay),2) as avg_base_pay
# From salaries_data
# Out:
#  * mysql://root:***@localhost/salaries
# 1 rows affected.
# [(74758.68,)]

# %% [markdown]
# #### 4. Top 10 highest paid employees

# %%
# %%sql
#
# Select EmployeeName, JobTitle, TotalPay
# From salaries_data
# Order By TotalPay Desc
# Limit 10
# Out:
#  * mysql://root:***@localhost/salaries
# 10 rows affected.
# [('NATHANIEL FORD', 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', 567595.43),
#  ('GARY JIMENEZ', 'CAPTAIN III (POLICE DEPARTMENT)', 538909.28),
#  ('Gary Altenberg', 'Lieutenant, Fire Suppression', 362844.66),
#  ('John Goldberg', 'Captain 3', 350403.41),
#  ('Frederick Binkley', 'EMT/Paramedic/Firefighter', 337204.86),
#  ('Khoa Trinh', 'Electronic Maintenance Tech', 336393.73),
#  ('ALBERT PARDINI', 'CAPTAIN III (POLICE DEPARTMENT)', 335279.91),
#  ('CHRISTOPHER CHONG', 'WIRE ROPE CABLE MAINTENANCE MECHANIC', 332343.61),
#  ('Mark Kearney', 'Assistant Deputy Chief 2', 327689.78),
#  ('PATRICK GARDNER', 'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)', 326373.19)]

# %% [markdown]
# #### 5. All employees with BasePay < 50,000 and TotalPay > 100,000

# %%
# %%sql
#
# Select *
# From salaries_data
# Where BasePay < 50000 and TotalPay > 100000
# Out:
#  * mysql://root:***@localhost/salaries
# 58 rows affected.
# [(210, 'ROBERT SERRANO', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 25400.0, 37100.14, 142094.49, '', 204594.63, 204594.63, 2011, '', 'San Francisco', ''),
#  (1487, 'MARYANNE LOWMAN', 'INSPECTOR III, (POLICE DEPARTMENT)', 49340.0, 23771.27, 88476.88, '', 161588.15, 161588.15, 2011, '', 'San Francisco', ''),
#  (1538, 'MARK MCDONOUGH', 'INSPECTOR III, (POLICE DEPARTMENT)', 49340.01, 30756.63, 80440.06, '', 160536.7, 160536.7, 2011, '', 'San Francisco', ''),
#  (1561, 'STEPHEN CASSIDY', 'CAPTAIN, FIRE SUPPRESSION', 31848.0, 31140.37, 97031.05, '', 160019.42, 160019.42, 2011, '', 'San Francisco', ''),
#  (1631, 'ALLYN LUENOW', 'POLICE OFFICER III', 44390.4, 38987.25, 75335.48, '', 158713.13, 158713.13, 2011, '', 'San Francisco', ''),
#  (1670, 'JOSEPH TOOMEY', 'INSPECTOR III, (POLICE DEPARTMENT)', 9867.93, 62600.83, 85688.69, '', 158157.45, 158157.45, 2011, '', 'San Francisco', ''),
#  (1888, 'ANTONIO CASILLAS', 'INSPECTOR III, (POLICE DEPARTMENT)', 9868.0, 77595.99, 67354.28, '', 154818.27, 154818.27, 2011, '', 'San Francisco', ''),
#  (2075, 'ROBERT MCMILLAN', 'INSPECTOR III, (POLICE DEPARTMENT)', 39472.0, 29686.02, 83424.09, '', 152582.11, 152582.11, 2011, '', 'San Francisco', ''),
#  (2885, 'MARY PETRIE', 'LIEUTENANT III (POLICE DEPARTMENT)', 33822.02, 27527.85, 81032.11, '', 142381.98, 142381.98, 2011, '', 'San Francisco', ''),
#  (2897, 'JOHN PAYNE', 'MANAGER VII', 0.0, 0.0, 142245.22, '', 142245.22, 142245.22, 2011, '', 'San Francisco', ''),
#  (3122, 'H SHISHMANIAN', 'POLICE OFFICER III', 36112.29, 26606.26, 77152.57, '', 139871.12, 139871.12, 2011, '', 'San Francisco', ''),
#  (3264, 'LAWRENCE BADINER', 'MANAGER VI', 0.0, 0.0, 138191.99, '', 138191.99, 138191.99, 2011, '', 'San Francisco', ''),
#  (3319, 'ROBERT SUDANO', 'INSPECTOR III, (POLICE DEPARTMENT)', 42256.61, 24634.22, 70791.84, '', 137682.67, 137682.67, 2011, '', 'San Francisco', ''),
#  (3380, 'PATRICIA CORREA', 'LIEUTENANT III (POLICE DEPARTMENT)', 33822.24, 14555.83, 88737.78, '', 137115.85, 137115.85, 2011, '', 'San Francisco', ''),
#  (3489, 'TIMOTHY FOLEY', 'LIEUTENANT III (POLICE DEPARTMENT)', 5637.04, 76614.78, 53615.33, '', 135867.15, 135867.15, 2011, '', 'San Francisco', ''),
#  (3732, 'KITT CRENSHAW', 'COMMANDER III, (POLICE DEPARTMENT)', 18736.8, 7992.0, 106926.93, '', 133655.73, 133655.73, 2011, '', 'San Francisco', ''),
#  (4144, 'ANTHONY FOTINOS', 'CAPTAIN III (POLICE DEPARTMENT)', 42738.0, 47827.7, 39904.72, '', 130470.42, 130470.42, 2011, '', 'San Francisco', ''),
#  (4477, 'NEVILLE GITTENS', 'LIEUTENANT III (POLICE DEPARTMENT)', 39459.0, 6563.38, 81740.92, '', 127763.3, 127763.3, 2011, '', 'San Francisco', ''),
#  (4550, 'JAMES TERRY', 'MENTAL HEALTH TREATMENT SPECIALIST', 21378.49, 1480.05, 104669.3, '', 127527.84, 127527.84, 2011, '', 'San Francisco', ''),
#  (4956, 'AUDRY LEE', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 21804.0, 46307.75, 56392.91, '', 124504.66, 124504.66, 2011, '', 'San Francisco', ''),
#  (5734, 'MICHAEL GALLEGOS', 'SERGEANT III (POLICE DEPARTMENT)', 39472.0, 28332.95, 52457.66, '', 120262.61, 120262.61, 2011, '', 'San Francisco', ''),
#  (5754, 'JENNIFER FORRESTER', 'INSPECTOR III, (POLICE DEPARTMENT)', 13600.41, 3525.9, 103002.6, '', 120128.91, 120128.91, 2011, '', 'San Francisco', ''),
#  (5781, 'STEPHEN HARPER', 'FIREFIGHTER', 48166.0, 31299.72, 40493.13, '', 119958.85, 119958.85, 2011, '', 'San Francisco', ''),
#  (6359, 'DAVID BRITT', 'FIREFIGHTER', 49158.29, 30219.85, 37315.47, '', 116693.61, 116693.61, 2011, '', 'San Francisco', ''),
#  (6497, 'ALLEN YIP', 'POLICE OFFICER III', 34008.32, 19856.0, 62043.26, '', 115907.58, 115907.58, 2011, '', 'San Francisco', ''),
#  (6921, 'BARBARA WILLIAMS', 'PSYCHIATRIC TECHNICIAN', 28079.76, 776.7, 84954.85, '', 113811.31, 113811.31, 2011, '', 'San Francisco', ''),
#  (7886, 'EDWARD ANZORE', 'SERGEANT III (POLICE DEPARTMENT)', 39471.99, 13271.22, 55149.8, '', 107893.01, 107893.01, 2011, '', 'San Francisco', ''),
#  (7900, 'EDWARD WYNKOOP', 'INSPECTOR III, (POLICE DEPARTMENT)', 19735.84, 15879.08, 72190.89, '', 107805.81, 107805.81, 2011, '', 'San Francisco', ''),
#  (7950, 'SUNNY WONG', 'CLERK', 46386.4, 57036.75, 4106.29, '', 107529.44, 107529.44, 2011, '', 'San Francisco', ''),
#  (7978, 'CHERYL AUSTIN', 'MANAGER III', 28837.14, 0.0, 78481.43, '', 107318.57, 107318.57, 2011, '', 'San Francisco', ''),
#  (36889, 'James Harrigan', 'Chief Atty1 (Civil & Criminal)', 15158.5, 0.0, 206752.0, '14074.28', 221910.5, 235984.78, 2012, '', 'San Francisco', ''),
#  (39614, 'Frank Cardinale', 'Assistant Deputy Chief 2', 0.0, 8859.0, 175675.66, '189.79', 184534.66, 184724.45, 2012, '', 'San Francisco', ''),
#  (39844, 'Alvin Wong', 'Inspector 3', 15369.11, 72885.66, 89505.39, '4624.93', 177760.16, 182385.09, 2012, '', 'San Francisco', ''),
#  (40141, 'Michael Kearney', 'Battlion Chief, Fire Suppressi', 0.0, 31865.11, 147243.87, '216.65', 179108.98, 179325.63, 2012, '', 'San Francisco', ''),
#  (41428, 'William Scott', 'Inspector 3', 48168.73, 6414.99, 101110.46, '12936.41', 155694.18, 168630.59, 2012, '', 'San Francisco', ''),
#  (43798, 'Michael Bello', 'Captain, Fire Suppression', 15114.6, 28083.96, 104066.89, '5065.54', 147265.45, 152330.99, 2012, '', 'San Francisco', ''),
#  (44048, 'Henry Parra Jr', 'Lieutenant 3', 46808.32, 6941.5, 84403.8, '12378.72', 138153.62, 150532.34, 2012, '', 'San Francisco', ''),
#  (44455, 'Richard Parry', 'Captain 3', 22182.0, 7660.0, 113378.13, '5154.87', 143220.13, 148375.0, 2012, '', 'San Francisco', ''),
#  (45669, 'Kevin Dempsey', 'Sergeant 3', 40984.32, 979.77, 87388.14, '10952.61', 129352.23, 140304.84, 2012, '', 'San Francisco', ''),
#  (45704, 'Judy Lizardo', 'Special Nurse', 45727.08, 0.0, 63303.51, '31043.46', 109030.59, 140074.05, 2012, '', 'San Francisco', ''),
#  (46091, 'Michael Flynn', 'Lieutenant 3', 8776.56, 36372.0, 89533.49, '2535.98', 134682.05, 137218.03, 2012, '', 'San Francisco', ''),
#  (46640, 'Sunny Wong', 'Clerk', 49291.5, 49883.45, 3821.09, '31401.04', 102996.04, 134397.08, 2012, '', 'San Francisco', ''),
#  (46746, 'Gerald Scullion', 'Battlion Chief, Fire Suppressi', 0.0, 5477.62, 126303.74, '2083.86', 131781.36, 133865.22, 2012, '', 'San Francisco', ''),
#  (46788, 'Joe Cheung', 'Engineer/Architect Principal', 42523.0, 0.0, 69151.0, '21941.98', 111674.0, 133615.98, 2012, '', 'San Francisco', ''),
#  (46815, 'George Rosko', 'Sergeant 3', 10246.08, 33313.65, 86853.22, '3028.87', 130412.95, 133441.82, 2012, '', 'San Francisco', ''),
#  (46967, 'Victor Tsang', 'Lieutenant 3', 24135.54, 14518.15, 87427.37, '6427.29', 126081.06, 132508.35, 2012, '', 'San Francisco', ''),
#  (47577, 'Joseph Cuff', 'Lieut,Fire Prev', 12428.01, 2936.28, 111058.32, '3494.32', 126422.61, 129916.93, 2012, '', 'San Francisco', ''),
#  (47662, 'Glenn Mori', 'Sergeant 3', 15369.1, 32968.4, 76553.67, '4605.77', 124891.17, 129496.94, 2012, '', 'San Francisco', ''),
#  (47720, 'Joy Houlihan', 'Manager VIII, MTA', 44134.93, 0.0, 65100.57, '19990.0', 109235.5, 129225.5, 2012, '', 'San Francisco', ''),
#  (47985, 'Eileen Hirst', 'Manager VI', 12573.2, 0.0, 102046.67, '13184.42', 114619.87, 127804.29, 2012, '', 'San Francisco', ''),
#  (48243, 'Andre Boursse', 'Manager VI, MTA', 38424.68, 0.0, 67828.74, '20400.99', 106253.42, 126654.41, 2012, '', 'San Francisco', ''),
#  (48652, 'Eugene Eden Jr', 'Firefighter', 35047.04, 3796.52, 75866.32, '10083.65', 114709.88, 124793.53, 2012, '', 'San Francisco', ''),
#  (49818, 'Margaret Lynch', 'Manager IV, MTA', 34879.4, 0.0, 65262.94, '19810.2', 100142.34, 119952.54, 2012, '', 'San Francisco', ''),
#  (51353, 'Martin Bastiani Jr', 'Inspector 3', 7684.5, 39819.08, 62860.3, '2609.12', 110363.88, 112973.0, 2012, '', 'San Francisco', ''),
#  (51413, 'John Fewer', 'Sergeant, (Police Department)', 10620.01, 30403.05, 68744.77, '2969.68', 109767.83, 112737.51, 2012, '', 'San Francisco', ''),
#  (51605, 'Monica Fields', 'Dep Chf of Dept (Fire Dept)', 9640.0, 52.65, 98007.14, '4192.59', 107699.79, 111892.38, 2012, '', 'San Francisco', ''),
#  (52625, 'Kevin Phipps', 'Sergeant 3', 20492.15, 8284.04, 73273.87, '5765.88', 102050.06, 107815.94, 2012, '', 'San Francisco', ''),
#  (54371, 'Ernest Wilberg', 'Police Officer 3', 0.0, 26960.51, 75181.97, '171.41', 102142.48, 102313.89, 2012, '', 'San Francisco', '')]

# %% [markdown]
# #### 6. Total Pay Benefits of Job Title "Director"

# %%
# %%sql
#
# Select EmployeeName, JobTitle, BasePay, OtherPay, Benefits, TotalPay, TotalPayBenefits
# From salaries_data
# Where JobTitle like '%Director%'
# Order by TotalPayBenefits desc
# Out:
#  * mysql://root:***@localhost/salaries
# 256 rows affected.
# [('Monique Moyer', 'Port Director', 236334.64, 5234.0, '70781.21', 241568.64, 312349.85),
#  ('DAVID KUSHNER', 'DEPUTY DIRECTOR OF INVESTMENTS', 256576.96, 51322.5, '', 307899.46, 307899.46),
#  ('Margaret Callahan', 'Human Resources Director', 203782.02, 6498.01, '69717.9', 210280.03, 279997.93),
#  ('MONIQUE MOYER', 'PORT DIRECTOR', 233357.28, 0.0, '', 233357.28, 233357.28),
#  ('SONALI BOSE', 'DEPUTY DIRECTOR II - MUNICIPAL TRANSPORTATION AG', 224035.85, 0.0, '', 224035.85, 224035.85),
#  ('Ron Ho', 'Director, Info Tech Group', 163349.0, 0.0, '59138.37', 163349.0, 222487.37),
#  ('JOHN HALEY JR', 'DEPUTY DIRECTOR II - MUNICIPAL TRANSPORTATION AG', 220115.22, 237.0, '', 220352.22, 220352.22),
#  ('JACKSON WONG', 'DEPUTY DIRECTOR V', 219804.34, 0.0, '', 219804.34, 219804.34),
#  ('MICHAEL CARLIN', 'DEPUTY DIRECTOR V', 215180.75, 0.0, '', 215180.75, 215180.75),
#  ('DEBRA JOHNSON', 'DEPUTY DIRECTOR II - MUNICIPAL TRANSPORTATION AG', 210821.61, 0.0, '', 210821.61, 210821.61),
#  ('JAY HUISH', 'DEPUTY DIRECTOR IV', 184386.79, 15366.99, '', 199753.78, 199753.78),
#  ('TANGERINE BRIGHAM', 'DEPUTY DIRECTOR V', 185724.5, 12000.0, '', 197724.5, 197724.5),
#  ('MARGARET CALLAHAN', 'HUMAN RESOURCES DIRECTOR', 196377.99, 0.0, '', 196377.99, 196377.99),
#  ('TODD RYDSTROM', 'DEPUTY DIRECTOR V', 185724.5, 10000.0, '', 195724.5, 195724.5),
#  ('BOND YEE', 'DEPUTY DIRECTOR II - MUNICIPAL TRANSPORTATION AG', 195256.1, 408.0, '', 195664.1, 195664.1),
#  ('MONIQUE ZMUDA', 'DEPUTY DIRECTOR V', 195121.53, 0.0, '', 195121.53, 195121.53),
#  ('PAULINE MARX', 'DEPUTY DIRECTOR IV', 180612.83, 13566.18, '', 194179.01, 194179.01),
#  ('AMY BROWN', 'DEPUTY DIRECTOR III', 179860.39, 14216.14, '', 194076.53, 194076.53),
#  ('Martin Taras', 'IS Project Director', 140764.04, 2018.33, '50662.51', 142782.37, 193444.88),
#  ('MOHAMMED NURU', 'DEPUTY DIRECTOR IV', 192007.49, 760.4, '', 192767.89, 192767.89),
#  ('DEBORAH JETER', 'DEPUTY DIRECTOR IV', 192183.91, 0.0, '', 192183.91, 192183.91),
#  ('JON WALTON', 'DEPUTY DIRECTOR IV', 188218.38, 3337.83, '', 191556.21, 191556.21),
#  ('LISA HOFFMANN', 'DEPUTY DIRECTOR IV', 190617.54, 0.0, '', 190617.54, 190617.54),
#  ('TED YAMASAKI', 'DEPUTY DIRECTOR IV', 190108.91, 0.0, '', 190108.91, 190108.91),
#  ('IVAR SATERO', 'DEPUTY DIRECTOR V', 186021.06, 3140.95, '', 189162.01, 189162.01),
#  ('FUAD SWEISS', 'DEPUTY DIRECTOR IV', 188842.42, 0.0, '', 188842.42, 188842.42),
#  ('Ana Contreras', 'IS Project Director', 130728.0, 235.65, '47240.6', 141390.44, 188631.04),
#  ('Hemalatha Nekkanti', 'IS Project Director', 139896.07, 196.09, '48124.63', 140092.16, 188216.79),
#  ('Sue Wong', 'Director, Fiscal Services', 132582.01, 0.0, '55411.0', 132582.01, 187993.01),
#  ('TRYG MCCOY', 'DEPUTY DIRECTOR V', 187976.14, 0.0, '', 187976.14, 187976.14),
#  ('Kathleen Mark', 'IS Project Director', 137345.01, 2079.46, '48038.04', 139424.47, 187462.51),
#  ('CHRISTIANE HAYASHI', 'DEPUTY DIRECTOR I - MUNICIPAL TRANSPORTATION AGE', 186541.05, 0.0, '', 186541.05, 186541.05),
#  ('MARTIN GRAN', 'DIRECTOR, EMPLOYEE RELATIONS DIVISION', 186341.79, 0.0, '', 186341.79, 186341.79),
#  ('Ephrem Naizghi', 'IS Project Director', 137264.43, 289.77, '48534.55', 137554.2, 186088.75),
#  ('Maria Barteaux', 'IS Project Director', 137345.38, 289.77, '48250.81', 137635.15, 185885.96),
#  ('KANDACE BENDER', 'DEPUTY DIRECTOR V', 185724.5, 0.0, '', 185724.5, 185724.5),
#  ('LEONARDO FERMIN', 'DEPUTY DIRECTOR V', 185724.5, 0.0, '', 185724.5, 185724.5),
#  ('THERESA LEE', 'DEPUTY DIRECTOR V', 185724.5, 0.0, '', 185724.5, 185724.5),
#  ('STEVEN RITCHIE', 'DEPUTY DIRECTOR V', 185724.49, 0.0, '', 185724.49, 185724.49),
#  ('TUAMELIE MOALA', 'DEPUTY DIRECTOR V', 185724.47, 0.0, '', 185724.47, 185724.47),
#  ('BARBARA HALE', 'DEPUTY DIRECTOR V', 185541.91, 0.0, '', 185541.91, 185541.91),
#  ('Bernardita Arrieta', 'IS Project Director', 137362.23, 289.77, '47660.5', 137652.0, 185312.5),
#  ('Arthur Wong', 'IS Project Director', 134856.96, 1707.69, '47260.18', 136564.65, 183824.83),
#  ('JULIET ELLIS', 'DEPUTY DIRECTOR IV', 183038.47, 0.0, '', 183038.47, 183038.47),
#  ('Yash Sharman', 'IS Project Director', 128001.96, 7613.59, '47178.3', 135615.55, 182793.85),
#  ('Pedro Sapida', 'IS Project Director', 134397.0, 165.29, '47098.1', 134562.29, 181660.39),
#  ('Chi-Wing Wong', 'IS Project Director', 133101.01, 125.27, '47235.37', 133226.28, 180461.65),
#  ('AMIT KOTHARI', 'DEPUTY DIRECTOR I - MUNICIPAL TRANSPORTATION AGE', 179832.14, 120.0, '', 179952.14, 179952.14),
#  ('Humphrey Loe', 'IS Project Director', 130727.99, 1850.27, '46727.71', 132578.26, 179305.97),
#  ('ROBERT DUDGEON', 'DEPUTY DIRECTOR IV', 174229.38, 5000.0, '', 179229.38, 179229.38),
#  ('Jonathan Kaplan', 'IS Project Director', 130728.0, 2004.77, '46398.77', 132732.77, 179131.54),
#  ('MARCELLINA OGBU', 'DEPUTY DIRECTOR V', 174391.95, 4600.0, '', 178991.95, 178991.95),
#  ('JAMES BUICK', 'DEPUTY DIRECTOR IV', 147424.92, 30668.5, '', 178093.42, 178093.42),
#  ('John McGee', 'IS Project Director', 130728.0, 289.77, '46714.88', 131017.77, 177732.65),
#  ('Gregory Woelffer', 'IS Project Director', 130727.99, 289.77, '46539.07', 131017.76, 177556.83),
#  ('Eric Carter', 'IS Project Director', 130728.01, 263.29, '46529.4', 130991.3, 177520.7),
#  ('Gregory Braswell', 'IS Project Director', 130728.05, 289.77, '46494.87', 131017.82, 177512.69),
#  ('Fredy Dorsainvil', 'IS Project Director', 130728.0, 289.77, '46451.45', 131017.77, 177469.22),
#  ('Rosa Esquivel', 'IS Project Director', 130727.98, 289.77, '46430.89', 131017.75, 177448.64),
#  ('Brian Roberts', 'IS Project Director', 130728.0, 289.77, '46359.0', 131017.77, 177376.77),
#  ('Frank Lara', 'IS Project Director', 130728.0, 238.32, '46407.92', 130966.32, 177374.24),
#  ('Willis Kuo', 'IS Project Director', 130727.97, 289.77, '46331.54', 131017.74, 177349.28),
#  ('Robin Castiglia Jr', 'IS Project Director', 130728.01, 287.87, '46332.4', 131015.88, 177348.28),
#  ('Jose Perla', 'IS Project Director', 130728.0, 289.77, '46329.58', 131017.77, 177347.35),
#  ('Michael Hoffman', 'IS Project Director', 130727.98, 289.77, '46321.55', 131017.75, 177339.3),
#  ('Ariel Del Rosario', 'IS Project Director', 130727.99, 289.77, '46295.5', 131017.76, 177313.26),
#  ('Jeff Pera', 'IS Project Director', 130727.97, 418.37, '46162.29', 131146.34, 177308.63),
#  ('Joe Armenta', 'IS Project Director', 130728.01, 289.77, '46289.79', 131017.78, 177307.57),
#  ('Bella Fudym', 'IS Project Director', 130727.99, 169.77, '46312.41', 130897.76, 177210.17),
#  ('Jeffrey Blau', 'IS Project Director', 130727.95, 153.85, '46317.6', 130881.8, 177199.4),
#  ('Isabel Vulis', 'IS Project Director', 130727.98, 100.51, '46344.01', 130828.49, 177172.5),
#  ('Umesh Gupta', 'IS Project Director', 130728.0, 289.77, '46125.98', 131017.77, 177143.75),
#  ('Robert Bodlak', 'IS Project Director', 130727.93, 289.77, '46069.68', 131017.7, 177087.38),
#  ('Penny Venable', 'IS Project Director', 130727.99, 0.0, '46289.36', 130727.99, 177017.35),
#  ('GINA TOMLINSON', 'DEPUTY DIRECTOR III', 176086.04, 0.0, '', 176086.04, 176086.04),
#  ('DENNIS KERN', 'DEPUTY DIRECTOR IV', 174379.35, 0.0, '', 174379.35, 174379.35),
#  ('REGINALD MASON', 'DEPUTY DIRECTOR I - MUNICIPAL TRANSPORTATION AGE', 174229.39, 9.0, '', 174238.39, 174238.39),
#  ('PRISCILLA MORSE', 'DEPUTY DIRECTOR IV', 174229.59, 0.0, '', 174229.59, 174229.59),
#  ('STEVE ARCELONA', 'DEPUTY DIRECTOR IV', 174229.58, 0.0, '', 174229.58, 174229.58),
#  ('PHIL ARNOLD', 'DEPUTY DIRECTOR IV', 174229.56, 0.0, '', 174229.56, 174229.56),
#  ('ROBERT CARLSON', 'DEPUTY DIRECTOR IV', 174229.53, 0.0, '', 174229.53, 174229.53),
#  ('WILLIAM LEE', 'DEPUTY DIRECTOR IV', 174229.44, 0.0, '', 174229.44, 174229.44),
#  ('TRAVIS FOX', 'DEPUTY DIRECTOR I - MUNICIPAL TRANSPORTATION AGE', 174229.42, 0.0, '', 174229.42, 174229.42),
#  ('KATHARINE PETRUCIONE', 'DEPUTY DIRECTOR IV', 174229.39, 0.0, '', 174229.39, 174229.39),
#  ('MARY FITZPATRICK', 'DEPUTY DIRECTOR III', 172639.93, 0.0, '', 172639.93, 172639.93),
#  ('DAWN KAMALANATHAN', 'DEPUTY DIRECTOR IV', 172211.48, 0.0, '', 172211.48, 172211.48),
#  ('Toni Ratcliff-Powell', 'Director, Juvenile Hall', 121511.97, 3486.0, '42503.27', 124997.97, 167501.24),
#  ('Pablo Munoz', 'IS Project Director', 121171.9, 1791.58, '44332.47', 122963.48, 167295.95),
#  ('Cheryl Martin', 'Director, Human Resources', 116212.92, 0.0, '50686.84', 116212.92, 166899.76),
#  ('RON HO', 'DIRECTOR, INFORMATION TECHNOLOGY GROUP', 163017.24, 3209.0, '', 166226.24, 166226.24),
#  ('Ann Donlan', 'Communications Director', 115530.0, 0.0, '50634.7', 115530.0, 166164.7),
#  ('JILL BOURNE', 'DEPUTY DIRECTOR III', 160959.56, 4900.0, '', 165859.56, 165859.56),
#  ('Sarah Schumann', 'Director, Probation Services', 117654.27, 1500.0, '46437.51', 119154.27, 165591.78),
#  ('Ernest Mendieta', 'Div Director, Adult Probation', 113076.61, 4986.0, '46999.18', 118062.61, 165061.79),
#  ('Tina Gilbert', 'Div Director, Adult Probation', 113076.64, 4986.0, '46984.3', 118062.64, 165046.94),
#  ('MIRIAN SAEZ', 'DEPUTY DIRECTOR III', 164850.39, 0.0, '', 164850.39, 164850.39),
#  ('Anthony Martin', 'IS Project Director', 120060.01, 0.0, '44269.7', 120060.01, 164329.71),
#  ('KENNETH BUKOWSKI', 'DEPUTY DIRECTOR III', 163845.0, 0.0, '', 163845.0, 163845.0),
#  ('NAOMI KELLY', 'DEPUTY DIRECTOR III', 159693.53, 3928.81, '', 163622.34, 163622.34),
#  ('LINDA YEUNG', 'DEPUTY DIRECTOR III', 159693.52, 3928.82, '', 163622.34, 163622.34),
#  ('ULYSSES VINSON JR', 'DEPUTY DIRECTOR III', 163574.51, 0.0, '', 163574.51, 163574.51),
#  ('MICHELLE DURGY', 'DEPUTY DIRECTOR III', 162527.43, 0.0, '', 162527.43, 162527.43),
#  ('MARGARET STEVENSON', 'DEPUTY DIRECTOR III', 160928.82, 0.0, '', 160928.82, 160928.82),
#  ('BYRON RHETT', 'DEPUTY DIRECTOR III', 160598.73, 0.0, '', 160598.73, 160598.73),
#  ('PETER DAILEY', 'DEPUTY DIRECTOR III', 160598.72, 0.0, '', 160598.72, 160598.72),
#  ('THOMAS CARTER', 'DEPUTY DIRECTOR III', 160598.71, 0.0, '', 160598.71, 160598.71),
#  ('DONNA KOTAKE', 'DEPUTY DIRECTOR II', 152503.34, 6000.0, '', 158503.34, 158503.34),
#  ('Lee Hudson', 'Div Director, Adult Probation', 109972.07, 3764.0, '42326.89', 113736.07, 156062.96),
#  ('Cristel Tullock', 'Div Director, Adult Probation', 109972.05, 3764.0, '42210.01', 113736.05, 155946.06),
#  ('Carina Gerntke-Corsis', 'IS Project Director', 113509.23, 214.13, '42156.32', 113723.36, 155879.68),
#  ('Christine Nath', 'IS Project Director', 112367.85, 112.73, '41903.47', 112480.58, 154384.05),
#  ('EDWARD SWEENEY', 'DEPUTY DIRECTOR III', 153338.6, 648.93, '', 153987.53, 153987.53),
#  ('CARTER ROHAN', 'DEPUTY DIRECTOR II - MUNICIPAL TRANSPORTATION AG', 132253.76, 21479.9, '', 153733.66, 153733.66),
#  ('NICOLE AVRIL', 'DEPUTY DIRECTOR IV', 153305.04, 0.0, '', 153305.04, 153305.04),
#  ('SUSAN REYNOLDS', 'DEPUTY DIRECTOR III', 153070.6, 0.0, '', 153070.6, 153070.6),
#  ('CHRISTINE ANDERSON', 'DEPUTY DIRECTOR III', 153070.56, 0.0, '', 153070.56, 153070.56),
#  ('PAMELA LEVIN', 'DEPUTY DIRECTOR III', 153070.53, 0.0, '', 153070.53, 153070.53),
#  ('LEO LEVENSON', 'DEPUTY DIRECTOR III', 153070.49, 0.0, '', 153070.49, 153070.49),
#  ('NANCY ALFARO', 'DEPUTY DIRECTOR III', 153070.36, 0.0, '', 153070.36, 153070.36),
#  ('Brian Smith', 'IS Project Director', 110100.16, 1068.69, '40691.46', 111168.85, 151860.31),
#  ('Cynthia Jones', 'Director, Probate', 105430.53, 632.0, '45744.66', 106062.53, 151807.19),
#  ('COLLEEN CHAWLA', 'DEPUTY DIRECTOR V', 147934.77, 2357.32, '', 150292.09, 150292.09),
#  ('Kim Tally', 'IS Project Director', 108868.11, 289.77, '40125.44', 109157.88, 149283.32),
#  ('ANA ALVAREZ', 'DEPUTY DIRECTOR II', 138204.53, 9316.04, '', 147520.57, 147520.57),
#  ('ELAINE FORBES', 'DEPUTY DIRECTOR III', 146718.76, 0.0, '', 146718.76, 146718.76),
#  ('Fang Lu', 'IS Project Director', 106566.0, 369.0, '38408.12', 106935.0, 145343.12),
#  ('ALLISON MAGEE', 'DEPUTY DIRECTOR III', 138563.65, 5891.4, '', 144455.05, 144455.05),
#  ('NOELLE SIMMONS', 'DEPUTY DIRECTOR II', 141161.24, 3290.3, '', 144451.54, 144451.54),
#  ('Herman Brown Jr', 'IS Project Director', 106258.79, 0.0, '37814.85', 106258.79, 144073.64),
#  ('DONALD ELLISON', 'DEPUTY DIRECTOR I - MUNICIPAL TRANSPORTATION AGE', 140038.63, 1039.43, '', 141078.06, 141078.06),
#  ('MARTIN TARAS', 'IS PROJECT DIRECTOR', 137483.61, 1090.0, '', 138573.61, 138573.61),
#  ('KELLEY AMDUR', 'DEPUTY DIRECTOR II', 129196.0, 8933.44, '', 138129.44, 138129.44),
#  ('LISA GHOTBI', 'DEPUTY DIRECTOR III', 138008.2, 0.0, '', 138008.2, 138008.2),
#  ('Kellee Hom', 'IS Project Director', 98337.1, 0.0, '39306.02', 98337.1, 137643.12),
#  ('PEDRO SAPIDA', 'IS PROJECT DIRECTOR', 129441.59, 7866.31, '', 137307.9, 137307.9),
#  ('LINDA SIMON', 'DEPUTY DIRECTOR II', 132242.5, 5000.0, '', 137242.5, 137242.5),
#  ('EPHREM NAIZGHI', 'IS PROJECT DIRECTOR', 130618.27, 6320.83, '', 136939.1, 136939.1),
#  ('BOB PALACIO', 'DEPUTY DIRECTOR II', 128455.2, 7804.42, '', 136259.62, 136259.62),
#  ('JEFFERY LITTLEFIELD', 'DEPUTY DIRECTOR V', 132209.54, 3110.05, '', 135319.59, 135319.59),
#  ('KATHLEEN MARK', 'IS PROJECT DIRECTOR', 134140.6, 1095.0, '', 135235.6, 135235.6),
#  ('HEMALATHA NEKKANTI', 'IS PROJECT DIRECTOR', 134502.84, 0.0, '', 134502.84, 134502.84),
#  ('BERNARDITA ARRIETA', 'IS PROJECT DIRECTOR', 133135.35, 1143.6, '', 134278.95, 134278.95),
#  ('MARIA BARTEAUX', 'IS PROJECT DIRECTOR', 134269.77, 0.0, '', 134269.77, 134269.77),
#  ('Mir Amanath Ali', 'IS Project Director', 98239.8, 0.0, '35745.18', 98239.8, 133984.98),
#  ('DAVID ASSMANN', 'DEPUTY DIRECTOR II', 133886.58, 0.0, '', 133886.58, 133886.58),
#  ('MICHELLE LONG', 'ASSISTANT DIRECTOR OF CLINICAL SERVICES II', 132471.24, 0.0, '', 132471.24, 132471.24),
#  ('MARK LOZOVOY', 'ASSISTANT DEPUTY DIRECTOR, PORT', 132242.5, 0.0, '', 132242.5, 132242.5),
#  ('JOHN DAVEY', 'ASSISTANT DEPUTY DIRECTOR, PORT', 132242.5, 0.0, '', 132242.5, 132242.5),
#  ('THOMAS DISANTO', 'DEPUTY DIRECTOR II', 130030.51, 2112.25, '', 132142.76, 132142.76),
#  ('SUE WONG', 'DIRECTOR, FISCAL SERVICES', 131788.26, 0.0, '', 131788.26, 131788.26),
#  ('CRYSTAL CHANG', 'IS PROJECT DIRECTOR', 130875.92, 0.0, '', 130875.92, 130875.92),
#  ('ARTHUR WONG', 'IS PROJECT DIRECTOR', 127677.52, 2355.04, '', 130032.56, 130032.56),
#  ('JEANNIE WONG', 'DEPUTY DIRECTOR II', 129146.04, 309.38, '', 129455.42, 129455.42),
#  ('JONATHAN KAPLAN', 'IS PROJECT DIRECTOR', 127677.49, 1130.0, '', 128807.49, 128807.49),
#  ('HUMPHREY LOE', 'IS PROJECT DIRECTOR', 127677.49, 1095.0, '', 128772.49, 128772.49),
#  ('CHI WONG', 'IS PROJECT DIRECTOR', 127800.6, 0.0, '', 127800.6, 127800.6),
#  ('JEFF PERA', 'IS PROJECT DIRECTOR', 127677.49, 98.4, '', 127775.89, 127775.89),
#  ('UMESH GUPTA', 'IS PROJECT DIRECTOR', 127677.6, 0.0, '', 127677.6, 127677.6),
#  ('ROBIN CASTIGLIA JR', 'IS PROJECT DIRECTOR', 127677.6, 0.0, '', 127677.6, 127677.6),
#  ('JOSE PERLA', 'IS PROJECT DIRECTOR', 127677.6, 0.0, '', 127677.6, 127677.6),
#  ('ISABEL VULIS', 'IS PROJECT DIRECTOR', 127677.6, 0.0, '', 127677.6, 127677.6),
#  ('FREDY DORSAINVIL', 'IS PROJECT DIRECTOR', 127677.59, 0.0, '', 127677.59, 127677.59),
#  ('JOHN MCGEE', 'IS PROJECT DIRECTOR', 127677.59, 0.0, '', 127677.59, 127677.59),
#  ('MICHAEL HOFFMAN', 'IS PROJECT DIRECTOR', 127677.59, 0.0, '', 127677.59, 127677.59),
#  ('JOE ARMENTA', 'IS PROJECT DIRECTOR', 127677.59, 0.0, '', 127677.59, 127677.59),
#  ('JEFFREY BLAU', 'IS PROJECT DIRECTOR', 127677.58, 0.0, '', 127677.58, 127677.58),
#  ('DARRYL YEE', 'IS PROJECT DIRECTOR', 127677.57, 0.0, '', 127677.57, 127677.57),
#  ('ARIEL DEL ROSARIO', 'IS PROJECT DIRECTOR', 127677.57, 0.0, '', 127677.57, 127677.57),
#  ('RODRIGO CASTILLO', 'IS PROJECT DIRECTOR', 127677.57, 0.0, '', 127677.57, 127677.57),
#  ('GREGORY WOELFFER', 'IS PROJECT DIRECTOR', 127677.51, 0.0, '', 127677.51, 127677.51),
#  ('BRIAN ROBERTS', 'IS PROJECT DIRECTOR', 127677.47, 0.0, '', 127677.47, 127677.47),
#  ('GREGORY BRASWELL', 'IS PROJECT DIRECTOR', 127677.43, 0.0, '', 127677.43, 127677.43),
#  ('KIM TALLY', 'IS PROJECT DIRECTOR', 127416.26, 0.0, '', 127416.26, 127416.26),
#  ('ROSA ESQUIVEL', 'IS PROJECT DIRECTOR', 127185.68, 0.0, '', 127185.68, 127185.68),
#  ('FRANK LARA', 'IS PROJECT DIRECTOR', 127185.09, 0.0, '', 127185.09, 127185.09),
#  ('MADELEINE LICAVOLI', 'DEPUTY DIRECTOR II', 126048.0, 0.0, '', 126048.0, 126048.0),
#  ('BRIAN SMITH', 'IS PROJECT DIRECTOR', 124618.59, 0.0, '', 124618.59, 124618.59),
#  ('ANA CONTRERAS', 'IS PROJECT DIRECTOR', 124034.61, 395.19, '', 124429.8, 124429.8),
#  ('CHERYL MARTIN', 'DIRECTOR, HUMAN RESOURCES', 124332.41, 0.0, '', 124332.41, 124332.41),
#  ('YASH SHARMAN', 'IS PROJECT DIRECTOR', 110240.12, 13834.3, '', 124074.42, 124074.42),
#  ('WILLIS KUO', 'IS PROJECT DIRECTOR', 123588.16, 0.0, '', 123588.16, 123588.16),
#  ('TARAS MADISON', 'DEPUTY DIRECTOR II', 123290.7, 0.0, '', 123290.7, 123290.7),
#  ('BRENT LEWIS', 'DEPUTY DIRECTOR II', 123290.7, 0.0, '', 123290.7, 123290.7),
#  ('KATHLEEN BROWN', 'DEPUTY DIRECTOR II', 123290.7, 0.0, '', 123290.7, 123290.7),
#  ('KIMBERLEE KIMURA', 'DEPUTY DIRECTOR II', 123290.7, 0.0, '', 123290.7, 123290.7),
#  ('ROBERT BODLAK', 'IS PROJECT DIRECTOR', 122758.57, 0.0, '', 122758.57, 122758.57),
#  ('ERIC CARTER', 'IS PROJECT DIRECTOR', 122193.61, 0.0, '', 122193.61, 122193.61),
#  ('DEBORAH LANDIS', 'DEPUTY DIRECTOR III', 121671.78, 0.0, '', 121671.78, 121671.78),
#  ('FRANCIS NGUYEN', 'DEPUTY DIRECTOR II', 120480.49, 0.0, '', 120480.49, 120480.49),
#  ('PABLO MUNOZ', 'IS PROJECT DIRECTOR', 112679.4, 7359.08, '', 120038.48, 120038.48),
#  ('TONI RATCLIFF-POWELL', 'DIRECTOR, JUVENILE HALL', 119203.65, 0.0, '', 119203.65, 119203.65),
#  ('BELLA FUDYM', 'IS PROJECT DIRECTOR', 117182.0, 0.0, '', 117182.0, 117182.0),
#  ('WILLIAM AHERN', 'DEPUTY DIRECTOR II', 114368.76, 2340.91, '', 116709.67, 116709.67),
#  ('ERNEST MENDIETA', 'DIVISION DIRECTOR ADULT PROBATION', 110834.63, 5666.0, '', 116500.63, 116500.63),
#  ('MARY QUINN', 'DIRECTOR, PROBATE', 98179.21, 17819.15, '', 115998.36, 115998.36),
#  ('Jaime Ballesteros', 'IS Project Director', 80106.2, 4943.5, '30756.8', 85049.7, 115806.5),
#  ('ANN DONLAN', 'COMMUNICATIONS DIRECTOR', 115289.99, 0.0, '', 115289.99, 115289.99),
#  ('ARTHUR CALDEIRA III', 'DEPUTY DIRECTOR II', 114024.2, 0.0, '', 114024.2, 114024.2),
#  ('AURA MENDIETA', 'DEPUTY DIRECTOR II', 112255.25, 0.0, '', 112255.25, 112255.25),
#  ('MABEL NG', 'DEPUTY DIRECTOR I', 111825.63, 0.0, '', 111825.63, 111825.63),
#  ('CHRISTINE NATH', 'IS PROJECT DIRECTOR', 111041.5, 0.0, '', 111041.5, 111041.5),
#  ('WILMA LOUIE', 'ASSISTANT DIRECTOR OF CLINICAL SERVICES I', 108888.03, 0.0, '', 108888.03, 108888.03),
#  ('SARAH SCHUMANN', 'DIRECTOR, PROBATION SERVICES', 108645.16, 0.0, '', 108645.16, 108645.16),
#  ('JENNIFER NORRIS', 'DEPUTY DIRECTOR II', 107335.46, 0.0, '', 107335.46, 107335.46),
#  ('SANDRA ENG', 'DEPUTY DIRECTOR I', 106506.23, 0.0, '', 106506.23, 106506.23),
#  ('ROBERT COLLINS', 'DEPUTY DIRECTOR I', 106260.35, 0.0, '', 106260.35, 106260.35),
#  ('NATALIYA KUZINA', 'DEPUTY DIRECTOR I', 105742.78, 0.0, '', 105742.78, 105742.78),
#  ('LAURENCE KORNFIELD', 'DEPUTY DIRECTOR III', 70721.42, 32487.75, '', 103209.17, 103209.17),
#  ('TIMOTHY MOSES', 'EXECUTIVE DIRECTOR, SOUTHEAST COMMUNITY FACILITY', 101033.76, 0.0, '', 101033.76, 101033.76),
#  ('LAURA LENT', 'DEPUTY DIRECTOR II', 100219.8, 0.0, '', 100219.8, 100219.8),
#  ('REBEKAH KRELL', 'DEPUTY DIRECTOR I', 96924.26, 983.18, '', 97907.44, 97907.44),
#  ('CHRISTINE MAGOFFIN', 'ASSISTANT TO THE DIRECTOR, PUBLIC AFFAIRS       RS', 91398.95, 3884.4, '', 95283.35, 95283.35),
#  ('RICHARD VETTERLI', 'DEPUTY DIRECTOR II', 93361.18, 72.48, '', 94511.33, 94511.33),
#  ('TINA GILBERT', 'DIVISION DIRECTOR ADULT PROBATION', 78444.8, 12342.54, '', 90787.34, 90787.34),
#  ('TIMOTHY DIESTEL', 'ASSISTANT DIRECTOR, LOG CABIN RANCH', 80235.74, 1354.18, '', 81589.92, 81589.92),
#  ('JOSE HIPOLITO', 'DIRECTOR OF ACTIVITIES, THERAPY AND VOLUNTEER SERV', 75759.0, 1400.0, '', 77159.0, 77159.0),
#  ('MARCIA ROMERO', 'DIRECTOR OF ACTIVITIES, THERAPY AND VOLUNTEER SERV', 75029.34, 2093.42, '', 77122.76, 77122.76),
#  ('DEBORAH BARONE', 'DEPUTY DIRECTOR II', 73652.37, 0.0, '', 73652.37, 73652.37),
#  ('ALICIA JOHN BAPTISTE', 'DEPUTY DIRECTOR III', 73544.44, 0.0, '', 73544.44, 73544.44),
#  ('MAURILIO LEON', 'DEPUTY DIRECTOR II', 72490.33, 0.0, '', 72490.33, 72490.33),
#  ('ERLINDA SANTA MARIA', 'IS PROJECT DIRECTOR', 49189.96, 9129.1, '', 58319.06, 58319.06),
#  ('KATHLEEN GULBENGAY', 'DEPUTY DIRECTOR II', 57976.39, 0.0, '', 57976.39, 57976.39),
#  ('DAVID VIDRIO', 'ASSISTANT RECREATION DIRECTOR', 27087.85, 29945.25, '', 57033.1, 57033.1),
#  ('ANTHONY MARTIN', 'IS PROJECT DIRECTOR', 55973.4, 0.0, '', 55973.4, 55973.4),
#  ('DAVID CHAI', 'DEPUTY DIRECTOR II', 54137.62, 0.0, '', 54137.62, 54137.62),
#  ('JOSE CAMPOS', 'DEPUTY DIRECTOR II', 54100.65, 0.0, '', 54100.65, 54100.65),
#  ('MICHAEL DEARMAN', 'DEPUTY DIRECTOR IV', 50333.43, 0.0, '', 50333.43, 50333.43),
#  ('GLORIA CORRAL-TERRAZAS', 'DEPUTY DIRECTOR I', 47571.44, 1884.21, '', 49455.65, 49455.65),
#  ('SAM KWONG', 'IS PROJECT DIRECTOR', 49189.98, 0.0, '', 49189.98, 49189.98),
#  ('MICHAEL COHEN', 'DEPUTY DIRECTOR IV', 0.0, 39108.6, '', 39108.6, 39108.6),
#  ('STEPHEN GELMAN', 'DEPUTY DIRECTOR II', 14180.4, 11865.44, '', 26045.84, 26045.84),
#  ('PENNY VENABLE', 'IS PROJECT DIRECTOR', 24495.0, 0.0, '', 24495.0, 24495.0),
#  ('LINH DUONG TRIEU', 'IS PROJECT DIRECTOR', 22135.45, 1085.87, '', 23221.32, 23221.32),
#  ('DENNIS DOYLE', 'ASSISTANT DIRECTOR, JUVENILE HALL', 20717.65, 0.0, '', 20717.65, 20717.65),
#  ('JILL JAY', 'DEPUTY DIRECTOR II', 11705.21, 6844.04, '', 18549.25, 18549.25),
#  ('JAMES HORAN', 'DEPUTY DIRECTOR II', 17998.2, 0.0, '', 17998.2, 17998.2),
#  ('CLIFFORD BRISCOE', 'AIRPORT ASSISTANT DEPUTY DIRECTOR, OPERATIONS', 15420.0, 0.0, '', 15420.0, 15420.0),
#  ('TRACEY LOVERIDGE', 'DEPUTY DIRECTOR II', 14693.38, 0.0, '', 14693.38, 14693.38),
#  ('EDWARD MELTON', 'DEPUTY DIRECTOR II', 13225.92, 0.0, '', 13225.92, 13225.92),
#  ('TONI CORDOVA WOODRUFF', 'DEPUTY DIRECTOR II', 12867.07, 0.0, '', 12867.07, 12867.07),
#  ('HUEY THOMAS', 'RECREATION DIRECTOR', 0.0, 12315.65, '', 12541.63, 12541.63),
#  ('SCOTT GOLDE', 'RECREATION DIRECTOR', 0.0, 8562.96, '', 8562.96, 8562.96),
#  ('MICHAEL CHEATHAM', 'RECREATION DIRECTOR', 0.0, 7268.99, '', 7336.54, 7336.54),
#  ('MICHELE MODENA', 'DEPUTY DIRECTOR IV', 7279.19, 0.0, '', 7279.19, 7279.19),
#  ('JOSE LEANO', 'IS PROJECT DIRECTOR', 6693.0, 0.0, '', 6693.0, 6693.0),
#  ('MARY QUINN', 'DIRECTOR, PROBATE', 5957.53, 0.0, '', 5957.53, 5957.53),
#  ('ARA MINASIAN', 'DEPUTY DIRECTOR III', 0.0, 5281.75, '', 5281.75, 5281.75),
#  ('KEITH BURROUGHS', 'RECREATION DIRECTOR', 0.0, 4314.81, '', 4314.81, 4314.81),
#  ('PETER NARDOZA', 'AIRPORT ASSISTANT DEPUTY DIRECTOR, BUSINESS ADMINI', 1927.5, 0.0, '', 1927.5, 1927.5),
#  ('DAVID DINSLAGE', 'ASSISTANT RECREATION DIRECTOR', 0.0, 1852.28, '', 1852.28, 1852.28),
#  ('DAVETTE MINOR', 'RECREATION DIRECTOR', 0.0, 1762.94, '', 1762.94, 1762.94),
#  ('JAMES BROWN', 'RECREATION DIRECTOR', 0.0, 1761.97, '', 1761.97, 1761.97),
#  ('JERI JACKSON', 'RECREATION DIRECTOR', 0.0, 1686.4, '', 1686.4, 1686.4),
#  ('GWENDOLYN WIGGINS', 'RECREATION DIRECTOR', 0.0, 1475.6, '', 1475.6, 1475.6),
#  ('EDWARD WONG', 'RECREATION DIRECTOR', 0.0, 1269.12, '', 1269.12, 1269.12),
#  ('JANELLE PIERCE', 'RECREATION DIRECTOR', 0.0, 1139.17, '', 1139.17, 1139.17)]

# %% [markdown]
# #### 7. Total Pay Benefits of All

# %%
# %%sql
#
# Select EmployeeName, JobTitle, BasePay, OtherPay, Benefits, TotalPay, TotalPayBenefits
# From salaries_data
# Order by TotalPayBenefits desc
# limit 100
# Out:
#  * mysql://root:***@localhost/salaries
# 100 rows affected.
# [('NATHANIEL FORD', 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', 167411.18, 400184.25, '', 567595.43, 567595.43),
#  ('GARY JIMENEZ', 'CAPTAIN III (POLICE DEPARTMENT)', 155966.02, 137811.38, '', 538909.28, 538909.28),
#  ('Gary Altenberg', 'Lieutenant, Fire Suppression', 128808.87, 13126.31, '44430.12', 362844.66, 407274.78),
#  ('Gregory Suhr', 'Chief of Police', 302578.0, 18974.11, '69810.19', 321552.11, 391362.3),
#  ('Khoa Trinh', 'Electronic Maintenance Tech', 111921.0, 78057.41, '53102.29', 336393.73, 389496.02),
#  ('Joanne Hayes-White', 'Chief, Fire Department', 296943.01, 17816.59, '72047.88', 314759.6, 386807.48),
#  ('Frederick Binkley', 'EMT/Paramedic/Firefighter', 126863.19, 17917.18, '44438.25', 337204.86, 381643.11),
#  ('Amy Hart', 'Dept Head V', 271607.74, 19782.03, '84681.82', 291389.77, 376071.59),
#  ('Edward Reiskin', 'Gen Mgr, Public Trnsp Dept', 294000.17, 0.0, '82001.94', 294000.17, 376002.11),
#  ('John Martin', 'Dept Head V', 287747.89, 5274.57, '81824.37', 293022.46, 374846.83),
#  ('John Goldberg', 'Captain 3', 104404.0, 245999.41, '24287.23', 350403.41, 374690.64),
#  ('David Franklin', 'Asst Chf of Dept (Fire Dept)', 204032.52, 26193.09, '58486.1', 315728.77, 374214.87),
#  ('Brendan Ward', 'Battlion Chief, Fire Suppressi', 174822.47, 28845.78, '49648.09', 321883.83, 371531.92),
#  ('Samson Lai', 'Battlion Chief, Fire Suppressi', 174822.44, 28660.28, '53249.56', 316214.0, 369463.56),
#  ('Rudy Castellanos', 'Battlion Chief, Fire Suppressi', 176771.74, 15803.39, '52320.9', 316988.26, 369309.16),
#  ('Marty Ross', 'Battlion Chief, Fire Suppressi', 174822.41, 36522.39, '55353.92', 310968.31, 366322.23),
#  ('Mark Kearney', 'Assistant Deputy Chief 2', 124573.5, 180516.68, '32381.0', 327689.78, 360070.78),
#  ('Leda Rozier', 'Transit Manager 2', 98211.01, 200951.3, '60285.44', 299162.31, 359447.75),
#  ('Ellen Moffatt', 'Asst Med Examiner', 260528.26, 20400.0, '73017.12', 284323.16, 357340.28),
#  ('Raymond Guzman', 'Dep Chf of Dept (Fire Dept)', 244102.02, 20232.29, '64702.72', 288538.97, 353241.69),
#  ('Edward Harrington', 'Executive Contract Employee', 232815.01, 51564.01, '67667.09', 284379.02, 352046.11),
#  ('Judy Melinek', 'Asst Med Examiner', 260528.15, 18425.37, '72286.35', 279330.73, 351617.08),
#  ('Michael Morris', 'Assistant Deputy Chief 2', 223371.0, 63426.03, '56202.98', 294212.55, 350415.53),
#  ('Michael Rolovich', 'Captain, Fire Suppression', 145659.03, 30474.97, '45129.03', 302002.06, 347131.09),
#  ('James Dudley', 'Deputy Chief 3', 263426.5, 22857.87, '59265.59', 286284.37, 345549.96),
#  ('Mark Gonzales', 'Dep Chf of Dept (Fire Dept)', 252423.6, 15742.21, '68783.23', 276523.06, 345306.29),
#  ('Harlan Kelly-Jr', 'Executive Contract Employee', 249362.77, 13810.69, '80999.77', 263173.46, 344173.23),
#  ('Darryl Hunter', 'Captain, Fire Suppression', 145659.03, 32610.0, '49571.51', 293942.76, 343514.27),
#  ('Trent Rhorer', 'Dept Head V', 253649.8, 6486.0, '80660.61', 260135.8, 340796.41),
#  ('Michael Delane', 'Captain, Fire Suppression', 147069.71, 33012.58, '45978.15', 293455.23, 339433.38),
#  ('Barbara Garcia', 'Dept Head V', 253435.69, 6486.0, '79477.91', 259921.69, 339399.6),
#  ('Susan Currin', 'Adm, SFGH Medical Center', 254878.82, 9486.0, '75003.33', 264364.82, 339368.15),
#  ('Philip Stevens', 'Captain, Fire Suppression', 124573.5, 130200.4, '28907.03', 308669.82, 337576.85),
#  ('Thomas Harvey', 'Assistant Deputy Chief 2', 226475.05, 54967.53, '55722.16', 281442.58, 337164.74),
#  ('Thomas Siragusa', 'Asst Chf of Dept (Fire Dept)', 208830.92, 20726.5, '52943.62', 284102.45, 337046.07),
#  ('Benjamin Rosenfield', 'Controller', 252210.73, 3486.0, '80986.55', 255696.73, 336683.28),
#  ('Croce Casciato', 'Captain 3', 108175.03, 203471.13, '24941.13', 311646.16, 336587.29),
#  ('ALBERT PARDINI', 'CAPTAIN III (POLICE DEPARTMENT)', 212739.13, 16452.6, '', 335279.91, 335279.91),
#  ('Edwin Lee', 'Mayor', 260574.05, 0.0, '74698.5', 260574.05, 335272.55),
#  ('Stephen Tacchini', 'Captain 3', 104404.0, 204290.09, '24688.54', 308694.09, 333382.63),
#  ('David Shinn', 'Deputy Chief 3', 263426.5, 12320.8, '57576.73', 275747.3, 333324.03),
#  ('CHRISTOPHER CHONG', 'WIRE ROPE CABLE MAINTENANCE MECHANIC', 77916.0, 198306.9, '', 332343.61, 332343.61),
#  ('Kevin Cashman', 'Deputy Chief 3', 253094.51, 22206.4, '56561.05', 275300.91, 331861.96),
#  ('Joseph Driscoll', 'Captain, Fire Suppression', 145658.98, 28743.36, '42919.16', 288915.63, 331834.79),
#  ('Scott Scholzen', 'Firefighter', 109783.86, 19873.8, '41230.89', 290076.13, 331307.02),
#  ('Ai Kyung Chung', 'Anesthetist', 227221.89, 16887.9, '78554.11', 249803.78, 328357.89),
#  ('Pete Fay Jr', 'Battlion Chief, Fire Suppressi', 176515.48, 23772.0, '53207.72', 274534.1, 327741.82),
#  ('John Ehrlich', 'Captain 3', 98747.52, 203735.92, '23607.08', 303869.82, 327476.9),
#  ('PATRICK GARDNER', 'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)', 134401.6, 182234.59, '', 326373.19, 326373.19),
#  ('Venus Azar', 'Asst Med Examiner', 243271.98, 13708.15, '68106.81', 256980.13, 325086.94),
#  ('Denise Schmitt', 'Deputy Chief 3', 263390.6, 819.01, '60298.97', 264209.61, 324508.58),
#  ('Jay Huish', 'Dept Head V', 243115.1, 3486.0, '77382.62', 246601.1, 323983.72),
#  ('Gregory Stangland', 'EMT/Paramedic/Firefighter', 128091.78, 16130.24, '43913.33', 277867.44, 321780.77),
#  ('Arthur Kenney', 'Asst Chf of Dept (Fire Dept)', 204032.52, 34685.53, '53152.06', 268486.4, 321638.46),
#  ('Kevin Taylor', 'Battlion Chief, Fire Suppressi', 176515.48, 23352.06, '47455.23', 271511.43, 318966.66),
#  ('Robert Postel', 'Asst Chf of Dept (Fire Dept)', 202075.56, 12813.53, '55037.41', 263556.51, 318593.92),
#  ('Yifang Qian', 'Senior Physician Specialist', 184892.12, 72743.26, '60232.85', 257635.38, 317868.23),
#  ('Sharon McCole-Wicher', 'Nursing Supervisor Psychiatric', 202921.06, 48236.76, '66508.04', 251157.82, 317665.86),
#  ('Kirk Richardson', 'Battlion Chief, Fire Suppressi', 174822.5, 21516.98, '52568.73', 264215.01, 316783.74),
#  ('DAVID SULLIVAN', 'ASSISTANT DEPUTY CHIEF II', 118602.0, 189082.74, '', 316285.74, 316285.74),
#  ('ALSON LEE', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 92492.01, 134426.14, '', 315981.05, 315981.05),
#  ('Naomi Kelly', 'Dept Head V', 240555.97, 3486.0, '71610.31', 244041.97, 315652.28),
#  ('Kevin Burke', 'Asst Chf of Dept (Fire Dept)', 204032.52, 29831.6, '58085.97', 257378.95, 315464.92),
#  ('Lorrie Kalos', 'Battlion Chief, Fire Suppressi', 174822.48, 24255.85, '52687.8', 262194.58, 314882.38),
#  ('Robert Shaw', 'Dep Dir for Investments, Ret', 236735.52, 4877.56, '71427.77', 241613.08, 313040.85),
#  ('Leanora Militello', 'Manager VIII, MTA', 204395.73, 51225.59, '57053.94', 255621.32, 312675.26),
#  ('Monique Moyer', 'Port Director', 236334.64, 5234.0, '70781.21', 241568.64, 312349.85),
#  ('Mark Smith', 'Anesthetist', 221084.95, 9874.61, '75463.4', 234851.98, 310315.38),
#  ('James Vannucchi', 'Battlion Chief, Fire Suppressi', 174822.43, 30760.78, '49888.38', 259048.36, 308936.74),
#  ('Alvin Lau', 'Firefighter', 110847.13, 17844.19, '40823.19', 267951.41, 308774.6),
#  ('Bryan Rubenstein', 'Battlion Chief, Fire Suppressi', 174822.44, 23603.24, '52059.82', 256517.65, 308577.47),
#  ('Shelley Mitchell', 'Anesthetist', 220727.4, 10610.61, '75578.69', 232996.58, 308575.27),
#  ('Sarah Cary', 'Anesthetist', 217483.34, 13166.26, '74687.57', 233266.74, 307954.31),
#  ('DAVID KUSHNER', 'DEPUTY DIRECTOR OF INVESTMENTS', 256576.96, 51322.5, '', 307899.46, 307899.46),
#  ('Heinz Hofmann', 'Lieutenant 3', 88317.99, 183112.41, '23177.83', 282899.77, 306077.6),
#  ('Michael Thompson', 'Battlion Chief, Fire Suppressi', 176515.52, 22064.5, '52776.95', 252919.86, 305696.81),
#  ('Arnold Choy', 'Lieutenant, Fire Suppression', 127573.43, 14195.17, '42607.88', 262319.12, 304927.0),
#  ('Kevin Smith', 'Battlion Chief, Fire Suppressi', 176515.52, 27969.77, '53182.45', 250346.28, 303528.73),
#  ('MICHAEL MORRIS', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 176932.64, 40132.23, '', 303427.55, 303427.55),
#  ('Wing Chan', 'Incident Support Specialist', 120740.1, 16194.51, '42331.26', 260664.43, 302995.69),
#  ('Rex Hale', 'Battlion Chief, Fire Suppressi', 176515.49, 24503.36, '52693.66', 250021.46, 302715.12),
#  ('JOANNE HAYES-WHITE', 'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)', 285262.0, 17115.73, '', 302377.73, 302377.73),
#  ('Mike Breiling', 'EMT/Paramedic/Firefighter', 128091.78, 15375.99, '43970.93', 258081.27, 302052.2),
#  ('Christopher Happy', 'Asst Med Examiner', 220372.95, 17412.18, '63852.13', 238110.93, 301963.06),
#  ('Jose Velo', 'Assistant Deputy Chief 2', 226475.02, 16877.44, '58449.76', 243352.46, 301802.22),
#  ('Erika Hoo', 'Captain, Fire Suppression', 140183.68, 32936.23, '45854.59', 255686.58, 301541.17),
#  ('George Gascon', 'District Attorney', 227238.02, 0.0, '73883.42', 227238.02, 301121.44),
#  ('Paul Chignell', 'Captain 3', 104404.02, 172352.33, '24078.34', 276756.35, 300834.69),
#  ('Mivic Hirose', 'Manager VIII', 219285.94, 8486.0, '72127.06', 227771.94, 299899.0),
#  ('Martin Beltran', 'Firefighter', 109783.87, 19688.1, '39980.84', 259740.36, 299721.2),
#  ('ARTHUR KENNEY', 'ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)', 194999.39, 33149.9, '', 299494.17, 299494.17),
#  ('Robert Winslow', 'Lieutenant, Fire Suppression', 127573.44, 22025.46, '40696.95', 258588.89, 299285.84),
#  ('Tryg McCoy', 'Dep Dir V', 219344.41, 10595.0, '68540.05', 229939.41, 298479.46),
#  ('Jeffrey Myers', 'Emergency Medical Svcs Chief', 226475.0, 13588.5, '57982.22', 240063.5, 298045.72),
#  ('Douglas Spikes', 'EMT/Paramedic/Firefighter', 128091.81, 16011.55, '43394.92', 254527.2, 297922.12),
#  ('PATRICIA JACKSON', 'CAPTAIN III (POLICE DEPARTMENT)', 99722.0, 110804.3, '', 297608.92, 297608.92),
#  ('Ana Sampera', 'Nursing Supervisor', 195242.0, 34867.77, '67221.66', 230109.77, 297331.43),
#  ('Schlene Peet', 'Nursing Supervisor', 183307.55, 46996.4, '66455.63', 230303.95, 296759.58),
#  ('Edward Chu', 'Lieutenant, Fire Suppression', 127933.79, 15563.02, '42506.53', 253738.12, 296244.65),
#  ('John Haley Jr', 'Deputy Dir II, MTA', 224511.96, 3701.0, '68030.78', 228212.96, 296243.74)]

# %% [markdown]
# #### 8. Job Titles with average Base Pay of at least 100,000

# %%
# %%sql
#
# Select JobTitle, Round(Avg(BasePay),2) as avg_base_pay
# From salaries_data
# Group by JobTitle
# Having avg_base_pay >= 100000
# Order by avg_base_pay desc
# Out:
#  * mysql://root:***@localhost/salaries
# 403 rows affected.
# [('Chief, Fire Department', 296943.01),
#  ('Gen Mgr, Public Trnsp Dept', 294000.17),
#  ('CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)', 285262.0),
#  ('CHIEF OF POLICE', 279524.2),
#  ('Dept Head V', 258352.03),
#  ('DEPUTY DIRECTOR OF INVESTMENTS', 256576.96),
#  ('Adm, SFGH Medical Center', 254878.82),
#  ('EXECUTIVE CONTRACT EMPLOYEE', 252770.7),
#  ('Controller', 252210.73),
#  ('Deputy Chief 3', 249928.6),
#  ('Asst Med Examiner', 246175.34),
#  ('ADMINISTRATOR, SFGH MEDICAL CENTER', 245124.44),
#  ('Dep Dir for Investments, Ret', 236735.52),
#  ('PORT DIRECTOR', 234845.96),
#  ('Emergency Medical Svcs Chief', 226475.0),
#  ('DEPARTMENT HEAD V', 219958.89),
#  ('DEPUTY CHIEF III (POLICE DEPARTMENT)', 219758.73),
#  ('Cfdntal Chf Atty 2,(Cvl&Crmnl)', 214883.94),
#  ('CONFIDENTIAL CHIEF ATTORNEY II (CIVIL & CRIMINAL)', 213907.72),
#  ('CITY ATTORNEY', 212186.5),
#  ('Dept Head IV', 209707.88),
#  ('DEPARTMENT HEAD IV', 206610.33),
#  ('Asst Chf of Dept (Fire Dept)', 204506.09),
#  ('PUBLIC DEFENDER', 202835.64),
#  ('HUMAN RESOURCES DIRECTOR', 200080.0),
#  ('ASSISTANT MEDICAL EXAMINER', 199964.57),
#  ('DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)', 199852.65),
#  ('GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', 199119.15),
#  ('SHERIFF', 197233.84),
#  ('Assistant Chief Attorney 2', 196542.25),
#  ('DEPUTY DIRECTOR II - MUNICIPAL TRANSPORTATION AG', 196496.51),
#  ('Chf Prob Ofc, Juv Court', 195196.7),
#  ('Dir Emp Relations Div', 192695.98),
#  ('CHIEF PROBATION OFFICER, JUVENILE COURT', 191319.45),
#  ('Commander 3', 189744.02),
#  ('NURSING SUPERVISOR PSYCHIATRIC', 188320.12),
#  ('CAPTAIN, BUREAU OF FIRE PREVENTION AND PUBLIC SAFE', 187237.53),
#  ('DIRECTOR, EMPLOYEE RELATIONS DIVISION', 186341.79),
#  ('FORENSIC TOXICOLOGIST', 184787.91),
#  ('Dept Head III', 184586.06),
#  ('Supervising Physician Spec', 184575.01),
#  ('DEPUTY DIRECTOR V', 184015.84),
#  ('Project Manager 4', 181781.18),
#  ('Assistant Chief Attorney 1', 181666.4),
#  ('Dep Dir V', 180984.52),
#  ('COURT EXECUTIVE OFFICER', 180541.6),
#  ('DEPARTMENT HEAD III', 180252.77),
#  ('Dep Dir IV', 179234.01),
#  ('Head Atty, Civil & Criminal', 177001.61),
#  ('ASSISTANT CHIEF ATTORNEY II', 176512.53),
#  ('MAYOR', 176328.49),
#  ('ASSISTANT CHIEF ATTORNEY I', 174165.54),
#  ('MANAGER VIII', 173145.31),
#  ('DEPUTY DIRECTOR I - MUNICIPAL TRANSPORTATION AGE', 170974.13),
#  ('ATTORNEY FOR THE PUBLIC ADMINISTRATOR', 170844.78),
#  ('Deputy Dir II, MTA', 170502.82),
#  ('CAPTAIN III (POLICE DEPARTMENT)', 170183.41),
#  ('Dep Chf of Dept (Fire Dept)', 168721.87),
#  ('Captain 3', 168540.38),
#  ('Asst Chf Prob Ofc, Juv Prob', 167361.04),
#  ('COMMANDER III, (POLICE DEPARTMENT)', 167042.75),
#  ('Dept Head II', 166316.77),
#  ('HEAD ATTORNEY, CIVIL AND CRIMINAL', 166209.26),
#  ('ASSESSOR', 165217.26),
#  ('Director, Info Tech Group', 163349.0),
#  ('Special Assistant 21', 163052.17),
#  ('DIRECTOR, INFORMATION TECHNOLOGY GROUP', 163017.24),
#  ('TREASURER', 162656.79),
#  ('DEPARTMENT HEAD II', 161371.33),
#  ('Battlion Chief, Fire Suppressi', 161100.48),
#  ('ASST. CHIEF PROBATION OFFICER-JUVENILE PROBATION', 160928.86),
#  ('Manager VII, MTA', 160715.8),
#  ('Assistant Deputy Chief 2', 160178.91),
#  ('SUPERVISING PHYSICIAN SPECIALIST', 159624.96),
#  ('MANAGER VII', 159520.69),
#  ('Board Scty, MTA', 159178.16),
#  ('Engineer/Architect Principal', 158209.83),
#  ('Special Assistant 22', 158082.7),
#  ('Dep Dir III', 157624.1),
#  ('DEPUTY DIRECTOR IV', 157154.64),
#  ('Chief Atty1 (Civil & Criminal)', 156758.94),
#  ('Manager VIII, MTA', 155795.61),
#  ('IS Manager', 155566.4),
#  ('Deputy Dir I, MTA', 154825.98),
#  ('PROJECT MANAGER IV', 154754.41),
#  ('BOARD SECRETARY - MUNICIPAL TRANSPORTATION AGENC', 154690.6),
#  ('CHIEF ATTORNEY I (CIVIL & CRIMINAL)', 154114.22),
#  ('DISTRICT ATTORNEY', 153783.74),
#  ('Lieutenant 2', 152446.31),
#  ('NURSE MANAGER', 151739.4),
#  ('SUPERVISING PHARMACIST', 150204.93),
#  ('PROJECT MANAGER III', 149677.64),
#  ('ASSISTANT DEPUTY CHIEF II', 148894.93),
#  ("CHIEF DISTRICT ATTORNEY'S INVESTIGATOR", 148448.51),
#  ('MANAGER VI', 146017.5),
#  ('Captain, Emergency Med Svcs', 145947.98),
#  ('MANAGER VIII - MUNICIPAL TRANSPORTATION AGENCY', 145109.59),
#  ('DEPUTY DIRECTOR III', 144976.84),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)', 144875.11),
#  ('MANAGER VII - MUNICIPAL TRANSPORTATION AGENCY', 143580.41),
#  ('Sr Light Rail Veh Equip Eng', 143260.0),
#  ('Sr Court Staff Attorney', 142841.51),
#  ('Project Manager 3', 142679.91),
#  ('Lieutenant 3', 142291.81),
#  ('Special Assistant 19', 142276.52),
#  ('INFORMATION SERVICES MANAGER', 141559.57),
#  ('CHIEF DEPUTY SHERIFF', 141371.17),
#  ('Court Computer Sys Manager', 141108.0),
#  ('Eng/Arch/Landscape Arch Sr', 141063.17),
#  ('LIEUTENANT I, (POLICE DEPARTMENT)', 140654.87),
#  ("SHERIFF'S CAPTAIN", 139710.16),
#  ('LIEUTENANT III (POLICE DEPARTMENT)', 139491.86),
#  ('DISABILITY ACCESS COORDINATOR', 139380.79),
#  ('Lieut,Fire Prev', 138459.26),
#  ('LAW LIBRARIAN', 138388.8),
#  ('Asst Chf, Bur Clm Invest&Admin', 137874.49),
#  ('COURT COMPUTER SYSTEMS MANAGER', 137504.4),
#  ('Crime Lab Mgr', 136963.0),
#  ('CAPTAIN, FIRE SUPPRESSION', 136701.79),
#  ('SENIOR COURT STAFF ATTORNEY', 136195.89),
#  ('CLINICAL NURSE SPECIALIST', 136070.64),
#  ('Assistant Inspector 3', 135451.29),
#  ('ANESTHETIST', 135308.69),
#  ('Asst Dir Clinical Svcs 2', 135171.64),
#  ('ASST. CHIEF, BUREAU OF CLAIMS INVEST. & ADMIN', 135166.98),
#  ('Asst.Dep.Dir., Port', 134905.78),
#  ('STRUCTURAL ENGINEER', 134813.72),
#  ('LIEUTENANT, BUREAU OF FIRE PREVENTION AND PUBLIC S', 134545.76),
#  ('Invstgtor,Fire Dept', 134513.85),
#  ('CRIME LABORATORY MANAGER', 134178.0),
#  ('Manager,Employee Relations Div', 134160.77),
#  ('ATTORNEY (CIVIL/CRIMINAL)', 134017.1),
#  ('Manager V, MTA', 133993.32),
#  ('SENIOR LIGHT RAIL VEHICLE EQUIPMENT ENGINEER', 133818.4),
#  ('Assistant Inspector 2', 133544.33),
#  ('Inspector 2', 133544.21),
#  ('BUILDING PLANS ENGINEER', 133332.0),
#  ('CLINICAL PHARMACIST', 132562.58),
#  ('ASSISTANT DIRECTOR OF CLINICAL SERVICES II', 132471.24),
#  ('Special Assistant 16', 132254.27),
#  ('SPECIAL ASSISTANT XVI', 132242.5),
#  ('ASSISTANT DEPUTY DIRECTOR, PORT', 132242.5),
#  ('DIRECTOR, FISCAL SERVICES', 132185.14),
#  ('PRINCIPAL CIVIL ENGINEER', 132184.46),
#  ('CAPTAIN, EMERGENCYCY MEDICAL SERVICES', 131835.13),
#  ('ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)', 131621.05),
#  ('MARINE ENGINEER OF FIRE BOATS', 131593.76),
#  ('Sergeant 2', 131313.9),
#  ('Chf District Atty Investigator', 131252.76),
#  ('Insp, Fire Dept', 130652.19),
#  ('LANDSCAPE ARCHITECT', 130633.48),
#  ('ASSISTANT INSPECTOR III (POLICE DEPARTMENT)', 130479.95),
#  ('Sergeant 3', 130404.34),
#  ('Dept Head I', 130186.29),
#  ('Planner 5', 129303.55),
#  ('INSPECTOR, BUREAU OF FIRE PREVENTION AND PUBLIC SA', 129281.06),
#  ('Manager VI, MTA', 129186.69),
#  ('Principal Real Property Ofc', 129059.67),
#  ('Inspector 3', 128816.27),
#  ('MANAGER, EMPLOYEE RELATIONS DIV', 128518.3),
#  ('Assistant Inspector', 128367.81),
#  ('Fire Safety Inspector 2', 128347.44),
#  ('INSPECTOR II, (POLICE DEPARTMENT)', 128145.44),
#  ('ASSISTANT INSPECTOR II (POLICE DEPARTMENT)', 127866.1),
#  ('Lieutenant, Fire Suppression', 127823.0),
#  ('MANAGER V', 127805.97),
#  ('COURT REPORTER COORDINATOR', 127754.94),
#  ('SERGEANT III (POLICE DEPARTMENT)', 127600.58),
#  ('Lab Svcs Mgr', 127504.04),
#  ('Dep Dir II', 127369.39),
#  ('CHIEF ADULT PROBATION OFFICER', 127318.6),
#  ('INVESTIGATOR, BUREAU OF FIRE INVESTIGATION', 126881.31),
#  ('SERGEANT II (POLICE DEPARTMENT)', 126354.65),
#  ('SENIOR ENGINEER', 126223.56),
#  ('IS Engineer-Principal', 126123.68),
#  ('FIRE SAFETY INSPECTOR II', 125786.21),
#  ('Airport Mechanical Maint Sprv', 125626.98),
#  ('INSPECTOR, (POLICE DEPARTMENT)', 125622.16),
#  ('FIRE PROTECTION ENGINEER', 125374.25),
#  ('MAYORAL STAFF XVII', 124923.43),
#  ('Project Manager 2', 124438.15),
#  ('CHIEF ELECTRICAL INSPECTOR', 124069.32),
#  ('ADMINISTRATIVE ENGINEER', 123830.55),
#  ('CHIEF PLUMBING INSPECTOR', 123698.6),
#  ('Radiologic Tech Sprv', 123524.23),
#  ('ASSISTANT INSPECTOR (POLICE DEPARTMENT)', 123169.95),
#  ('LIEUTENANT, FIRE DEPARTMENT', 123166.48),
#  ('Supt Water Treatment Fac', 122963.44),
#  ('SENIOR PHYSICIAN SPECIALIST', 122786.02),
#  ('RADIOLOGIC TECHNOLOGIST SUPERVISOR', 122733.3),
#  ('CHIEF BUILDING INSPECTOR', 122654.34),
#  ('MANAGER IV', 122158.32),
#  ('MANAGER, UNIFIED FAMILY COURT SERVICES', 122009.29),
#  ('LABORATORY SERVICES MANAGER', 121650.96),
#  ('TRAF SIGNAL ELECTRICIAN SUP II', 121541.82),
#  ('Chief Dep Adlt Prob Of (SFERS)', 121161.81),
#  ('HEAD AIRPORT ELECTRICIAN', 120960.1),
#  ('SERGEANT I (POLICE DEPARTMENT)', 120720.92),
#  ('COURT COMMISSIONER', 120580.78),
#  ('Sergeant, (Police Department)', 120445.97),
#  ('COURT COMPUTER FACILITIES COORDINATOR', 120370.6),
#  ('DIRECTOR, JUVENILE HALL', 120357.81),
#  ('IS PROJECT DIRECTOR', 120322.35),
#  ('INSPECTOR III, (POLICE DEPARTMENT)', 120294.28),
#  ('DIRECTOR, HUMAN RESOURCES', 120272.66),
#  ('Sewage Treatment Plant Supt', 119991.58),
#  ('Public Relations Mgr', 119985.72),
#  ('DEPARTMENT HEAD I', 119735.04),
#  ('CHIEF HOUSING INSPECTOR', 119705.34),
#  ("PRINCIPAL DISTRICT ATTORNEY'S INVESTIGATOR", 119082.38),
#  ('AIRPORT MECHANICAL MAINTENANCE SUPERVISOR', 118978.52),
#  ('Senior Comm Systems Technican', 118932.0),
#  ('Water Const&Main Supt', 118736.63),
#  ('COURT ADMINISTRATOR', 118543.91),
#  ('MANAGER V - MUNICIPAL TRANSPORTATION AGENCY', 118435.86),
#  ("SHERIFF'S LIEUTENANT", 117389.3),
#  ('Landscape Architect Assoc 2', 117373.87),
#  ('ENGINEER', 117286.66),
#  ('MANAGER IV - MUNICIPAL TRANSPORTATION AGENCY', 117120.44),
#  ('CHIEF WATER SERVICE INSPECTOR', 117085.78),
#  ('NURSING SUPERVISOR', 116577.28),
#  ('IS Engineer-Senior', 116461.63),
#  ('WATER CONSTRUCTION AND MAINTENANCE SUPERINTENDENT', 115893.02),
#  ('Senior Industrial Hygienist', 115681.33),
#  ('PUBLIC RELATIONS MANAGER', 115569.42),
#  ('COMMUNICATIONS DIRECTOR', 115410.0),
#  ('Police Officer 3', 115227.34),
#  ('MANAGER VI - MUNICIPAL TRANSPORTATION AGENCY', 115115.5),
#  ('ASSISTANT SHERIFF', 115063.21),
#  ('IS Business Analyst-Principal', 114930.95),
#  ('ATTORNEY, TAX COLLECTOR', 114888.69),
#  ('SUPERINTENDENT OF WATER TREATMENT FACILITIES', 114869.68),
#  ('UNDERSHERIFF', 114761.92),
#  ('Contract Compliance Officer 2', 114665.14),
#  ('Sprv Electronic Main Tech', 114613.86),
#  ('INCIDENT SUPPORT SPECIALIST', 114356.59),
#  ('CRIMINALIST III', 114242.42),
#  ("Asst Chf Dist Atty's Invstgtor", 114098.01),
#  ('Plumber Supervisor 2', 114075.08),
#  ('Ex Asst to Ex Dir, Retirement', 114072.19),
#  ('Real Estate Devt. Mgr, SFMTA', 113982.03),
#  ('Ct Comp App Programmer', 113827.14),
#  ('PROJECT MANAGER II', 113743.22),
#  ('COURT COMPUTER APPLICATIONS PROGRAMMER', 113726.85),
#  ('DIRECTOR, PROBATION SERVICES', 113149.72),
#  ('Utility Plumber Supervisor 2', 112716.91),
#  ('SENIOR PLUMBING INSPECTOR', 112660.5),
#  ('SENIOR PHYSICAL THERAPIST', 112369.92),
#  ('SENIOR HOUSING INSPECTOR', 112327.07),
#  ('SUPERVISING ELECTRONIC MAINTENANCE TECHNICIAN', 112296.16),
#  ('SHEET METAL WORKER SUPERVISOR II', 112221.0),
#  ('SENIOR BUILDING INSPECTOR', 112130.84),
#  ('EXECUTIVE ASSISTANT TO THE GENERAL MANAGER, RETIRE', 111821.33),
#  ('Senior Electrical Inpsector', 111801.09),
#  ('Project Manager 1', 111701.7),
#  ('IS ENGINEER - PRINCIPAL', 111582.0),
#  ('Div Director, Adult Probation', 111524.34),
#  ('Electrician Supervisor 2', 111430.4),
#  ('MANAGER III', 111234.71),
#  ('EMT/Paramedic/Firefighter', 111200.72),
#  ('PRINCIPAL ENVIRONMENTAL HEALTH INSPECTOR', 110982.12),
#  ('Police Officer 2', 110877.67),
#  ('SENIOR ELECTRICAL INSPECTOR', 110805.5),
#  ('Trnst Power Line Wrk Sprv 2', 110610.42),
#  ('ARCHITECT', 110578.39),
#  ('Planner 4', 110536.12),
#  ('PLANNER V', 110520.34),
#  ('AIRPORT ECONOMIC PLANNER', 110496.18),
#  ('Supv Biologist', 110447.89),
#  ('ELECTRICAL TRANSIT SHOP SUPERVISOR I', 110386.74),
#  ('Transit Manager 2', 110218.8),
#  ('ELECTRICIAN SUPERVISOR II', 110179.2),
#  ('PILOT OF FIRE BOATS', 110167.89),
#  ("ASSISTANT CHIEF DISTRICT ATTORNEY'S INVESTIGATOR", 110152.77),
#  ('Employment & Training Spec 6', 109991.5),
#  ('WATER OPERATIONS ANALYST', 109947.73),
#  ('Manager III, MTA', 109924.57),
#  ('Asst Dir of Clinical Svcs 1', 109831.06),
#  ('OPERATING ROOM NURSE', 109803.14),
#  ('Manager IV, MTA', 109756.13),
#  ('CHIEF MICROBIOLOGIST', 109641.76),
#  ('Dep Dir I', 109640.92),
#  ('SENIOR INDUSTRIAL HYGIENIST DEPT OF PUBLIC HEALTH', 109494.3),
#  ('ASSISTANT LAW LIBRARIAN', 109349.84),
#  ('LANDSCAPE ARCHITECTURAL ASSOCIATE II', 109326.52),
#  ('RESEARCH PSYCHOLOGIST', 109067.61),
#  ('ASSISTANT DIRECTOR OF CLINICAL SERVICES I', 108888.03),
#  ('TRAF SIGNAL ELECTRICIAN SUP I', 108854.7),
#  ('SENIOR PLAN CHECKER', 108853.02),
#  ('Transit Planner 4', 108801.93),
#  ('Chf Victim/Witness Invstgtor', 108743.5),
#  ('Architectural Associate 2', 108658.65),
#  ('Steamfitter Supervisor I', 108650.13),
#  ('Govrnmt/Publ Affairs Mgr', 108420.08),
#  ('SUPERVISING BIOLOGIST', 108327.74),
#  ('Automotive Trnst Shop Sprv 1', 108251.33),
#  ('SENIOR PROPERTY MANAGER, PORT', 108022.04),
#  ('AUTOMOTIVE TRANSIT SHOP SUPERVISOR I', 107977.15),
#  ('TRANSIT POWER LINE WORKER SUPERVISOR II', 107916.0),
#  ('SUPERVISING PURCHASER', 107847.7),
#  ('Telecommunications Tech Supv', 107673.62),
#  ('IS ENGINEER - SENIOR', 107667.65),
#  ('Planner 4-Environmental Review', 107591.54),
#  ('MANAGER III - MUNICIPAL TRANSPORTATION AGENCY', 107501.98),
#  ('Supervising Mediator, UFCS', 107460.74),
#  ('Maritime Marketing Repr', 107458.0),
#  ('Prnpl Admin Analyst II', 107320.85),
#  ('Ex Asst to Admin, SFGH', 107298.76),
#  ('Assoc Engineer', 107190.76),
#  ('IS Prg Analyst-Principal', 107150.37),
#  ('IS BUSINESS ANALYST - PRINCIPAL', 107063.54),
#  ('Supv Chemist', 106997.27),
#  ('Asst Superintendent Rec', 106851.49),
#  ('CRANE MECHANIC SUPERVISOR', 106750.01),
#  ('Sr District Atty Investigator', 106647.41),
#  ('Communications Line Wrk Sprv 2', 106580.04),
#  ('Bldgs & Grounds Maint Supt', 106418.51),
#  ('POLICE OFFICER III', 106324.64),
#  ('Water Conservation Admin', 106106.51),
#  ('SUPERVISING WASTEWATER CONTROL INSPECTOR', 106105.52),
#  ('Electrical Trnst Mech Sprv 1', 106036.46),
#  ('COMMUNICATIONS LINE WORKER SUPERVISOR II', 105861.42),
#  ('TRANSIT PLANNER IV', 105837.13),
#  ('ARCHITECTURAL ADMINISTRATOR', 105741.4),
#  ('SEWAGE TREATMENT PLANT SUPERINTENDENT', 105717.0),
#  ('BUILDINGS AND GROUNDS MAINTENANCE SUPERINTENDENT', 105616.27),
#  ('IS Engineer-Journey', 105576.32),
#  ('Transmission Line Supervisor 1', 105569.39),
#  ('MANAGER II', 105542.15),
#  ('AIRPORT ELECTRICIAN SUPERVISOR', 105465.51),
#  ('Police Officer', 105456.66),
#  ('SrClaimsInvstgtor,Cty Atty Ofc', 105451.26),
#  ('CONTRACT COMPLIANCE OFFICER II', 105425.71),
#  ('CITY SHOPS ASSISTANT SUPERINTENDENT', 105362.35),
#  ('Pr Personal Property Auditor', 105263.02),
#  ('SENIOR CLAIMS INVESTIGATOR', 105193.51),
#  ('Transit Manager 1', 105084.86),
#  ('MARITIME MARKETING REPRESENTATIVE', 104903.67),
#  ('Electr Maint Tech Asst Sprv', 104877.97),
#  ('INSTITUTIONAL POLICE SERGEANT', 104779.86),
#  ('Trans Safety Specialist', 104608.88),
#  ('Sr Environmental Hlth Insp', 104559.06),
#  ('PUBLIC HEALTH NURSE', 104475.69),
#  ('TRANSIT MANAGER I', 104302.18),
#  ('PLANNER IV', 104111.23),
#  ('NURSE PRACTITIONER', 104063.47),
#  ('Pr Environmental Hlth Insp', 104038.92),
#  ('COURT COMPUTER SYSTEMS ENGINEER II', 103986.07),
#  ("SHERIFF'S SERGEANT", 103978.75),
#  ('TRANSPORTATION SAFETY SPECIALIST', 103897.99),
#  ('Sheet Metal Supervisor 1', 103872.34),
#  ('STEAMFITTER ASSISTANT SUPERVISOR', 103858.14),
#  ('Principal Mgmt Analyst', 103809.59),
#  ('Perf Analyst III Project Mgr', 103770.32),
#  ('IS Administrator-Supervisor', 103501.42),
#  ('TELECOMMUNICATIONS TECHNICIAN SUPERVISOR', 103467.62),
#  ('FIREFIGHTER', 103430.96),
#  ('POLICE OFFICER II', 103341.25),
#  ("SENIOR CLAIMS INVESTIGATOR,CITY ATTORNEY'S OFFICE", 103262.7),
#  ('Principal Environ Specialist', 103216.6),
#  ('TRANSIT MANAGER II', 102952.43),
#  ('Heating/Ventilating Inspector', 102895.1),
#  ('Ex Dir, SE Com Fac Comm', 102885.12),
#  ('UTILITY SPECIALIST', 102867.99),
#  ('FISCAL SERVICES COORDINATOR', 102835.2),
#  ('Special Assistant 15', 102799.42),
#  ('PRINCIPAL ADMINISTRATIVE ANAYLST II', 102728.31),
#  ('Ct Comp Sys Engineer II', 102580.69),
#  ('FIRE FIGHTER PARAMEDIC', 102572.56),
#  ('MANAGER II - MUNICIPAL TRANSPORTATION AGENCY', 102548.96),
#  ('Utility Plumber Supervisor 1', 102372.67),
#  ('Fiscal Services Supervisor', 102245.5),
#  ('Auditor III', 102115.86),
#  ('Electrician Supervisor 1', 102053.78),
#  ('Ct Comp App Analyst', 101974.66),
#  ('PHARMACIST', 101898.3),
#  ('UTILITY PLUMBER SUPERVISOR II', 101884.68),
#  ('POWER HOUSE ELECTRICIAN SUPERVISOR I', 101871.64),
#  ('CHIEF STATIONARY ENGINEER, WATER TREATMENT PLANT', 101811.02),
#  ('Pr Administrative Analyst', 101809.41),
#  ('AUDIOLOGIST', 101623.57),
#  ('PLUMBER SUPERVISOR I', 101348.68),
#  ('REGISTERED NURSE', 101171.11),
#  ('Electric Motor Repair Sprv 1', 101088.0),
#  ('SPECIAL ASSISTANT XXII', 101060.82),
#  ('Senior Const Inspector', 101058.74),
#  ('EXECUTIVE DIRECTOR, SOUTHEAST COMMUNITY FACILITY', 101033.76),
#  ('HEATING AND VENTILATING INSPECTOR', 100963.28),
#  ('Asst Forensic Toxicologist 1', 100815.02),
#  ('Coord, Human Rights Comm', 100771.0),
#  ('ELEVATOR AND CRANE TECHNICIAN', 100762.34),
#  ('SHEET METAL SUPERVISOR I', 100745.07),
#  ('LINE INSPECTOR', 100716.7),
#  ('SENIOR EMPLOYEE RELATIONS REPRESENTATIVE', 100687.59),
#  ('Accountant IV', 100654.45),
#  ('WATER CONSERVATION ADMINISTRATOR', 100557.76),
#  ('CHIEF VICTIM/WITNESS INVESTIGATOR', 100548.34),
#  ('UTILITY PLUMBER SUPERVISOR I', 100528.7),
#  ('Sr Community Dev Spec 2', 100527.15),
#  ('ASSISTANT SUPERINTENDENT RECREATION', 100515.4),
#  ('Chf Statnry Eng,WtrTreat Plnt', 100413.59),
#  ('SAFETY OFFICER', 100339.92),
#  ('PROJECT MANAGER I', 100197.75)]

# %% [markdown]
# ## The End!
# ## Github @ bisma-azeem-13
